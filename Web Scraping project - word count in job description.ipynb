# %%
import requests #allows programmer to send HTTP requests 
from bs4 import BeautifulSoup #imports python library that allows for scraping the web
import collections #collections provides solutions that would be tricky to implement
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer #imports Natural Language Processing functions
import pandas as pd #imports pandas, a Python library 
from operator import itemgetter #The operator modules exports a set of efficient functions corresponding to intrinsic 
#operators in python(i.e. +,-,*,etc.). Itemgetter allows programmer to retrieve something from a data structure much faster and easier
import numpy as np #imports numpy, a Python library that allows for simple and complex arithmetic calculations 
import nltk #imports natural language toolkit
from nltk.corpus import stopwords #imports stopwords function from natural language toolkit so that all stop words(i.e. and, is, but) can be filtered out
from nltk.tokenize import word_tokenize #imports word_tokenize function

# %%
page = requests.get("https://www.linkedin.com/jobs/view/791327763/") #gives you access to webpage

# %%
page
# Out:
# <Response [200]>

# %%
page.status_code #checks to see whether getting access to webpage was successful
# Out:
# 200

# %%
page.content #shows content of page
# Out:
# b'<!DOCTYPE html>\n    \n \n \n \n \n \n \n \n \n\n\n \n \n \n\n \n \n\n<!--[if lt IE 7]> <html lang="en" class="ie ie6 lte9 lte8 lte7 os-other"> <![endif]-->\n<!--[if IE 7]> <html lang="en" class="ie ie7 lte9 lte8 lte7 os-other"> <![endif]-->\n<!--[if IE 8]> <html lang="en" class="ie ie8 lte9 lte8 os-other"> <![endif]-->\n<!--[if IE 9]> <html lang="en" class="ie ie9 lte9 os-other"> <![endif]-->\n<!--[if gt IE 9]> <html lang="en" class="os-other"> <![endif]-->\n<!--[if !IE]><!--> <html lang="en" class="os-other"> <!--<![endif]-->\n\n\n  \n\n\n\n\n\n\n\n\n\n\n<head>\n<meta charset="UTF-8"/>\n\n    \n\n\n <title>Electronic Arts hiring Data Scientist in Austin, TX, US | Linkedin Jobs\n </title>\n\n\n\n  \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n\n\n \n \n \n\n \n \n\n\n\n\n\n\n\n\n\n\n\n<meta name="referrer" content="origin"/>\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n\n <meta name="pageImpressionID" content="e7ccddc3-af83-4e0f-927f-ff1c5a142da7">\n \n <meta name="appName" content="chrome">\n \n \n \n \n \n \n <meta name="pageKey" content="d_jobs_job_detail_premium_guest">\n \n\n\n <meta name="treeID" content="coEaecmRVRXgN0zzKSsAAA==">\n \n\n \n \n \n \n\n <meta name="globalTrackingUrl" content="//www.linkedin.com/mob/tracking">\n <meta name="globalTrackingAppName" content="chrome">\n <meta name="globalTrackingAppId" content="webTracking">\n \n\n \n \n \n \n \n\n\n      \n\n      \n      \n      \n      \n      \n      \n      \n    \n<!--[if lte IE 8]>\n  <link rel="shortcut icon" href="https://static.licdn.com/scds/common/u/images/logos/favicons/v1/16x16/favicon.ico">\n<![endif]-->\n<!--[if IE 9]>\n  <link rel="shortcut icon" href="https://static.licdn.com/scds/common/u/images/logos/favicons/v1/favicon.ico">\n<![endif]-->\n<link rel="icon" href="https://static.licdn.com/scds/common/u/images/logos/favicons/v1/favicon.ico">\n\n\n<link rel="apple-touch-icon-precomposed" href="https://static.licdn.com/scds/common/u/img/icon/apple-touch-icon.png">\n\n\n<meta name="msapplication-TileImage" content="https://static.licdn.com/scds/common/u/images/logos/linkedin/logo-in-win8-tile-144_v1.png"/>\n<meta name="msapplication-TileColor" content="#0077B5"/>\n<meta name="application-name" content="LinkedIn"/>\n\n\n\n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n    \n\n\n\n\n\n\n\n      \n    \n  \n  \n      \n      \n\n      \n        \n      \n\n\n\n\n\n\n\n\n\n\n\n\n      \n      \n    \n    \n  \n  \n  \n\n  \n  \n\n\n\n\n\n\n\n    \n  \n\n\n    \n  \n\n\n\n    \n      \n        \n          \n            \n                \n              \n          \n        \n      \n    \n    \n\n\n\n    \n    \n\n\n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n    \n\n\n\n\n\n\n\n\n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n      \n    \n\n\n    \n  \n      \n\n      \n      \n\n\n\n\n\n\n\n     \n      \n    \n    \n\n\n\n\n      \n    \n  \n      \n      \n\n      \n        \n      \n\n\n\n\n\n  \n\n\n\n\n\n    \n\n\n      \n                \n    \n    \n\n\n\n\n\n<meta content="https://static.licdn.com/scds/concat/common/js?v=0.1.576" name="RemoteNavJSContentBaseURL" />\n\n\n\n     \n      \n    \n    \n      \n    \n    \n\n      \n      \n    \n\n      \n      \n    \n    \n    \n    \n    \n\n  \n\n \n \n \n \n\n\n\n      \n        \n          \n            \n          \n          \n        \n      \n    \n\n      \n        \n          \n          \n        \n      \n    \n\n\n      \n      \n    \n    \n    \n    \n    \n\n      \n      \n    \n    \n    \n                    <script src="https://static.licdn.com:443/scds/common/u/lib/fizzy/fz-1.3.8-min.js" type="text/javascript"></script><script type="text/javascript">fs.config({"failureRedirect":"http:/ ...

# %%
soup = BeautifulSoup(page.content, "html.parser") #parsing webspage using HTML

# %%
print(soup.prettify()) #organizes content of webpage so that it is easier to read
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html lang="en" class="ie ie6 lte9 lte8 lte7 os-other"> <![endif]-->
# <!--[if IE 7]> <html lang="en" class="ie ie7 lte9 lte8 lte7 os-other"> <![endif]-->
# <!--[if IE 8]> <html lang="en" class="ie ie8 lte9 lte8 os-other"> <![endif]-->
# <!--[if IE 9]> <html lang="en" class="ie ie9 lte9 os-other"> <![endif]-->
# <!--[if gt IE 9]> <html lang="en" class="os-other"> <![endif]-->
# <!--[if !IE]><!-->
# <html class="os-other" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Electronic Arts hiring Data Scientist in Austin, TX, US | Linkedin Jobs
#   </title>
#   <meta content="origin" name="referrer"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="e7ccddc3-af83-4e0f-927f-ff1c5a142da7" name="pageImpressionID"/>
#   <meta content="chrome" name="appName"/>
#   <meta content="d_jobs_job_detail_premium_guest" name="pageKey"/>
#   <meta content="coEaecmRVRXgN0zzKSsAAA==" name="treeID"/>
#   <meta content="//www.linkedin.com/mob/tracking" name="globalTrackingUrl"/>
#   <meta content="chrome" name="globalTrackingAppName"/>
#   <meta content="webTracking" name="globalTrackingAppId"/>
#   <!--[if lte IE 8]>
#   <link rel="shortcut icon" href="https://static.licdn.com/scds/common/u/images/logos/favicons/v1/16x16/favicon.ico">
# <![endif]-->
#   <!--[if IE 9]>
#   <link rel="shortcut icon" href="https://static.licdn.com/scds/common/u/images/logos/favicons/v1/favicon.ico">
# <![endif]-->
#   <link href="https://static.licdn.com/scds/common/u/images/logos/favicons/v1/favicon.ico" rel="icon"/>
#   <link href="https://static.licdn.com/scds/common/u/img/icon/apple-touch-icon.png" rel="apple-touch-icon-precomposed"/>
#   <meta content="https://static.licdn.com/scds/common/u/images/logos/linkedin/logo-in-win8-tile-144_v1.png" name="msapplication-TileImage">
#    <meta content="#0077B5" name="msapplication-TileColor">
#     <meta content="LinkedIn" name="application-name">
#      <meta content="https://static.licdn.com/scds/concat/common/js?v=0.1.576" name="RemoteNavJSContentBaseURL">
#       <script src="https://static.licdn.com:443/scds/common/u/lib/fizzy/fz-1.3.8-min.js" type="text/javascript">
#       </script>
#       <script type="text/javascript">
#        fs.config({"failureRedirect":"http://www.linkedin.com/","uniEscape":true,"xhrHeaders":{"X-FS-Origin-Request":"/jobs/view/791327763/","X-FS-Page-Id":""}});
#       </script>
#       <script src="https://static.licdn.com/scds/concat/common/js?h=7vr4nuab43rzvy2pgq7yvvxjk-9qa4rfxekcw3lt2c06h7p0kmf" type="text/javascript">
#       </script>
#       <link href="https://static.licdn.com/scds/concat/common/css?h=a4kjc5uqttio53azw54aex6s3-as8kt5bqspxc01tl9cizqa37j" rel="stylesheet" type="text/css"/>
#       <script>
#       </script>
#       <!--[if IE 8]><script src="https://static.licdn.com/scds/common/u/lib/polyfill/1.0.2/ie8-polyfill.min.js"></script><![endif]-->
#       <!--[if IE 9]><script src="https://static.licdn.com/scds/common/u/lib/polyfill/1.0.2/ie9-polyfill.min.js"></script><![endif]-->
#       <meta content="https://static.licdn.com/scds/concat/common/js?h=2jds9coeh4w78ed9wblscv68v-ebbt2vixcc5qz0otts5io08xv" name="lnkd-track-json-lib"/>
#       <meta content="https://static.licdn.com/scds/concat/common/js?h=ebbt2vixcc5qz0otts5io08xv" name="lnkd-track-lib"/>
#       <meta content="/lite/ua/error?csrfToken=ajax%3A2291069490470548862" name="lnkd-track-error"/>
#       <meta content="jobs-frontend" id="appHost" name="appHost"/>
#       <meta content="1.0.1605" id="appVersion" name="appVersion"/>
#       <meta content="i001" id="appInstance" name="appInstance"/>
#       <script src="https://static.licdn.com/scds/concat/common/js?h=e2lgukqldpqool72t8g7tysag-3nuvxgwg15rbghxm1gpzfbya2-1nm61x5u7981e88m10hpaekkm-mv3v66b8q0h1hvgvd3yfjv5f-14k913qahq3mh0ac0lh0twk9v" type="text/javascript">
#       </script>
#       <script src="https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.1605/f/%2Fjobs-frontend%2Fdust%2Fdev%2Flinkedin-dust.js">
#       </script>
#       <link href="https://www.linkedin.com/jobs/view/data-scientist-at-electronic-arts-ea-791327763" rel="canonical">
#        <link href="//static.licdn.com" rel="preconnect">
#         <link href="//media.licdn.com" rel="preconnect">
#          <link href="//platform.linkedin.com" rel="preconnect"/>
#          <meta content="https://www.linkedin.com/jobs/view/data-scientist-at-electronic-arts-ea-791327763" property="og:url"/>
#          <meta content="app-id=886051313, app-argument=lijobseeker://jobPosting/791327763?smartbanner=1, affiliate-data=ct=smart_banner&amp;pt=10746" property="apple-itunes-app"/>
#          <meta content="Data Scientist, EA Customer Experience#WeAreEA and we exist to inspire the world to play. EA values creativity, pioneering, passion, determination, learning, and teamwork. We mean things like acting with curiosity, speaking up with original ideas, and committing to each other as one team.We’re looking for all the best kinds of people to make great experiences for our players. The best people want a job that inspires them, while giving them room to enjoy their lives. And we want to give them that. We celebrate diversity and inclusion by creating a place where you can come to work and be yourself.You’re a Data Scientist.You Understand That You Have 2 Basic JobsYou know how to pull all types of data from any source, be it Facebook posts, call center chats, video likes or survey results.Help our studios understand what problems players have with their games and provide insights that help optimize our call center. Both pursue the ultimate goal of providing the World’s Best Service for the World’s Best Games.You use all resources available to you to help solve a problem, be it a new algorithm, programming language or the person sitting next to you.You’re a programmer/statistician/NLP expert who is fanatic about games and Customer Experiences.You’re also a genuinely nice person who brings positive energy to an office. You’re approachable and take the time to listen so that you understand someone else’s view.This role is part of EA’s Customer Experience organization. The Customer Experience organization strives to make EA known for taking care of its players. We’re players taking care of players and people talking to people – whenever, wherever, and however they need us.We’re the Data Science team, part of the larger Customer Experience Insights team.We are surrounded by Production, BI, SEO and Market Research analysts. We’re the people who use advanced statistics and modeling to help solve business problems. We surface player problems through our text analytics offerings. We write a lot of code and talk to stakeholders from all teams and all levels. We are great team mates and trusted advisors, who provide insights to facilitate decisions and create models that change experiences.A typical day in the life of a Data Scientist:Come into the office and catch up with your team mates about last night’s gaming session or the hottest show on TV (no spoilers until 24hrs have passed – after that: anything is fair game!)Check on last night’s Jenkins script and add some code to a project you’re working onTalk to one of your coworkers on the Call Center side about how to match the right advisor to the right player – this could be your next big projectTake some time back at your desk to write up any notes and make a project plan proposalAttend a JIRA prioritization meeting to update work that’s in flight and plan for work to comeGrab coffee and read up on any stats blogs or tech news you’re subscribed toCheck out the model you deployed into production last month to see if it’s time to re-trainPull the latest changes on an NLP model you’re collaborating on from Stash and tinker with the parameters, then chat with your peer about the results of the tweaks and make plans for what to change nextSpend a couple of hours heads down/headphones on getting series with an analysis.Finish the day looking over any code you wrote today, knit any Markdowns and make sure your documentation is up to snuff.So how do Data Scientists make great experiences for players? They:Tell stories with data and interpret results for their stakeholdersPrioritize problems to solve based on the impact to the player experience while keeping overall organizational goals in mindHave a basic understanding of EA’s games and find time to play whenever they canDisplay confidence in communicating with senior management, or any audience, to ensure what they say is heard and understoodIdentify and lead collaborative efforts both inside and outside of their team; wor ...
#          <meta content="noarchive" name="robots"/>
#          <meta content="https://www.linkedin.com/jobs/view/791327763" property="lnkd-page-id"/>
#          <meta content="https://media.licdn.com/dms/image/C4D0BAQGOlVviOdDcoQ/company-logo_100_100/0?e=1545264000&amp;v=beta&amp;t=EGrgqnMi8_kYj6bn77ayn0yMarbm-COV5caOuVMnwac" property="og:image"/>
#          <meta content="Data Scientist" property="og:title"/>
#          <meta content="LinkedIn" property="og:site_name"/>
#          <meta content="yes" name="apple-mobile-web-app-capable"/>
#          <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
#          <meta content="#0077B5" name="theme-color"/>
#          <meta content="width=device-width, initial-scale=1" name="viewport"/>
#          <meta content="play streaming enabled" name="play-streaming"/>
#          <link href="https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.1605/f/%2Fjobs-frontend%2Fconcat%2Fneo-guest-style-dependencies_en_US.css" rel="stylesheet"/>
#         </link>
#        </link>
#       </link>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="js guest" dir="ltr" id="pagekey-d_jobs_job_detail_premium_guest">
#   <div id="application-body">
#    <script data-page-js-type="lix">
#     (function(n, r, a) {
#                       r = window[n] = window[n] || {};
#
#
#                             r['jsecure_injectAlert'] = 'enabled';
#
#
#
#                             r['jsecure_Dialog'] = 'control';
#
#
#                     }('__li__lix_registry__'));
#    </script>
#    <main id="layout-main" role="main">
#     <code id="__pageContext__" style="display: none;">
#      <!--{"baseScdsUrl":"https://static.licdn.com/scds","contextPath":"/jobs2","pageInstance":"urn:li:page:d_jobs_job_detail_premium_guest;gX/iI2BrS6KQfGdoTwiw5A==","isProd":true,"brotliBaseSparkUrlForHashes":"https://static.licdn.com/sc/h/br","linkedInDustJsUrl":"https://static.licdn.com/sc/h/3qk7aqkysw7gz575y2ma1e5ky","baseSparkUrlForHashes":"https://static.licdn.com/sc/h","isCsUser":false,"appName":"jobs-frontend","fizzyJsUrl":"https://static.licdn.com/scds/common/u/lib/fizzy/fz-1.3.3-min.js","mpName":"jobs-frontend","scHashesUrl":"https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.1605/f/%2Fjobs-frontend%2Fsc-hashes%2Fsc-hashes_en_US.js","dustDebug":"control","baseMediaUrl":"https://media.licdn.com/media","isBrotliEnabled":false,"useCdn":true,"locale":"en_US","version":"1.0.1605","useScHashesJs":false,"cdnUrl":"https://static.licdn.com","baseMprUrl":"https://media.licdn.com/mpr/mpr","playUtilsUrl":"https://static.licdn.com/sc/h/v0un52v653evxg2c5l1ap5la","useNativeXmsg":false,"hashesDisabledByQueryParam":false,"baseAssetsUrl":"https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.1605/f","csrfToken":"ajax:5837415231715275712","intlPolyfillUrl":"https://static.licdn.com/sc/h/1fw1ey0jfgqapy4dndtgrr7y1","serveT8WithDust":false,"disableDynamicConcat":false,"baseSparkUrlForFiles":"https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.1605/f","dustUtilsUrl":"https://static.licdn.com/sc/h/19dd5wwuyhbk7uttxpuelttdg","linkedInDustI18nJsUrl":"https://static.licdn.com/sc/h/epy983tzfexddbwygtwyxyavv","baseMediaProxyUrl":"https://media.licdn.com/media-proxy"}-->
#     </code>
#     <script src="https://static.licdn.com/sc/h/1fw1ey0jfgqapy4dndtgrr7y1">
#     </script>
#     <script src="https://static.licdn.com/sc/h/19dd5wwuyhbk7uttxpuelttdg">
#     </script>
#     <script>
#      (function(root){
# var jsRoutes = {}; (function(_root){
# var _nS = function(c,f,b){var e=c.split(f||"."),g=b||_root,d,a;for(d=0,a=e.length;d<a;d++){g=g[e[d]]=g[e[d]]||{}}return g}
# var _qS = function(items){var qs = ''; for(var i=0;i<items.length;i++) {if(items[i]) qs += (qs ? '&' : '') + items[i]}; return qs ? ('?' + qs) : ''}
# var _s = function(p,s){return p+((s===true||(s&&s.secure))?'s':'')+'://'}
# var _wA = function(r){return {ajax:function(c){c=c||{};c.url=r.url;c.type=r.method;return jQuery.ajax(c)}, method:r.method,type:r.method,url:r.url,absoluteURL: function(s){return _s('http',s)+'www.linkedin.com'+r.url},webSocketURL: function(s){return _s('ws',s)+'www.linkedin.com'+r.url}}}
# _nS('controllers.ViewJobController'); _root.controllers.ViewJobController.saveJob =
#         function(id) {
#           return _wA({method:"POST", url:"/" + "jobs/view/actions/saveJob/" + (function(k,v) {return v})("id", id)})
#         }
#
# _nS('controllers.ViewJobController'); _root.controllers.ViewJobController.unsaveJob =
#         function(id) {
#           return _wA({method:"POST", url:"/" + "jobs/view/actions/unsaveJob/" + (function(k,v) {return v})("id", id)})
#         }
#
# _nS('controllers.ViewJobController'); _root.controllers.ViewJobController.followCompany =
#         function(id) {
#           return _wA({method:"POST", url:"/" + "jobs/view/actions/followCompany/" + (function(k,v) {return v})("id", id)})
#         }
#
# _nS('controllers.ViewJobController'); _root.controllers.ViewJobController.unfollowCompany =
#         function(id) {
#           return _wA({method:"POST", url:"/" + "jobs/view/actions/unfollowCompany/" + (function(k,v) {return v})("id", id)})
#         }
#
# _nS('controllers.ViewJobController'); _root.controllers.ViewJobController.viewApplyModal =
#         function(id,spSrc,trk,refId) {
#           return _wA({method:"GET", url:"/" + "jobs/view/applyFlow/" + (function(k,v) {return v})("id", id) + _qS([(function(k,v){return v!=null?(function(k,v) {return encodeURIComponent(k)+'='+encodeURIComponent(v)})(k,v):''})("spSrc", spSrc), (function(k,v){return v!=null?(function(k,v) {return encodeURIComponent(k)+'='+encodeURIComponent(v)})(k,v):''})("trk", trk), (function(k,v){return v!=null?(function(k,v) {return encodeURIComponent(k)+'='+encodeURIComponent(v)})(k,v):''})("refId", refId)])})
#         }
#
# _nS('controllers.ViewJobController'); _root.controllers.ViewJobController.submitJobApplication =
#         function() {
#           return _wA({method:"POST", url:"/" + "jobs/submitJobApplication"})
#         }
#
# _nS('controllers.ViewJobController'); _root.controllers.ViewJobController.sendMessage =
#         function() {
#           return _wA({method:"POST", url:"/" + "jobs/view/actions/sendMessage/"})
#         }
#
# _nS('controllers.ViewJobController'); _root.controllers.ViewJobController.createInternalApplyClickEvent =
#         function(id,spSrc,trk,refId) {
#           return _wA({method:"GET", url:"/" + "jobs/view/applyFlow/click/" + (function(k,v) {return v})("id", id) + _qS([(function(k,v){return v!=null?(function(k,v) {return encodeURIComponent(k)+'='+encodeURIComponent(v)})(k,v):''})("spSrc", spSrc), (function(k,v){return v!=null?(function(k,v) {return encodeURIComponent(k)+'='+encodeURIComponent(v)})(k,v):''})("trk", trk), (function(k,v){return v!=null?(function(k,v) {return encodeURIComponent(k)+'='+encodeURIComponent(v)})(k,v):''})("refId", refId)])})
#         }
#
# _nS('controllers.JobAlertController'); _root.controllers.JobAlertController.createAlert =
#         function() {
#           return _wA({method:"POST", url:"/" + "jobs/jobAlert"})
#         }
#
# _nS('controllers.salary.SalaryController'); _root.controllers.salary.SalaryController.collection =
#         function(path,sidToken) {
#           return _wA({method:"GET", url:"/salary/" + "collection" + (function(k,v) {return v})("path", path) + _qS([(function(k,v){return v!=null?(function(k,v) {return encodeURIComponent(k)+'='+encodeURIComponent(v)})(k,v):''})("sidToken", sidToken)])})
#         }
#
# _nS('controllers.salary.SalaryController'); _root.controllers.salary.SalaryController.insights =
#         function(path,sidToken) {
#           return _wA({method:"GET", url:"/salary/" + "insights" + (function(k,v) {return v})("path", path) + _qS([(function(k,v){return v!=null?(function(k,v) {return encodeURIComponent(k)+'='+encodeURIComponent(v)})(k,v):''})("sidToken", sidToken)])})
#         }
#
# _nS('controllers.OffsiteJobApplicantsController'); _root.controllers.OffsiteJobApplicantsController.savePreference =
#         function(preference) {
#           return _wA({method:"PUT", url:"/" + "jobs2/offsiteApplicant/save" + _qS([(function(k,v){return k+'='+(!!v)})("preference", preference)])})
#         }
#
# _nS('controllers.OffsiteJobApplicantsController'); _root.controllers.OffsiteJobApplicantsController.share =
#         function(jobPostingId) {
#           return _wA({method:"PUT", url:"/" + "jobs2/offsiteApplicant/share/" + (function(k,v) {return v})("jobPostingId", jobPostingId)})
#         }
#
# _nS('controllers.OffsiteJobApplicantsController'); _root.controllers.OffsiteJobApplicantsController.undoShare =
#         function(jobPostingId) {
#           return _wA({method:"DELETE", url:"/" + "jobs2/offsiteApplicant/undoShare/" + (function(k,v) {return v})("jobPostingId", jobPostingId)})
#         }
#
# _nS('controllers.OffsiteJobApplicantsController'); _root.controllers.OffsiteJobApplicantsController.savePreferenceAndMaybeDoShare =
#         function(preference,jobPostingId) {
#           return _wA({method:"PUT", url:"/" + "jobs2/offsiteApplicant/saveAndShare" + _qS([(function(k,v){return k+'='+(!!v)})("preference", preference), (function(k,v){return v!=null?(function(k,v) {return encodeURIComponent(k)+'='+encodeURIComponent(v)})(k,v):''})("jobPostingId", jobPostingId)])})
#         }
#
# })(jsRoutes)
#     ;
# root.play = root.play || {};
# root.play.jsRoutes = root.play.jsRoutes || {};
# var extend = function (original, context) {
#   for (key in context)
#     if (context.hasOwnProperty(key))
#       if (Object.prototype.toString.call(context[key]) === '[object Object]')
#         original[key] = extend(original[key] || {}, context[key]);
#       else
#         original[key] = context[key];
#   return original;
# };
# root.play.jsRoutes = extend(root.play.jsRoutes, jsRoutes);
# })(this);
#     </script>
#     <div class="dev-nav nav-container" id="navigation-container">
#     </div>
#     <div id="content-outlet">
#     </div>
#     <!-- content that will be stream to browser after early flush the content before it -->
#    </main>
#    <script src="https://static.licdn.com/scds/concat/common/js?h=7dt162oar7uci911egb332w3g-44hhbxag3hinac547ym9vby09-5jratctnqzzuc1057yivxswgf-9zz2lhu3eq1epk7sq1t8cdb5s-eound1d1xhqm86h7g2p57b94l-edgsl2z4e4gk56cy2m5kbpp1q-acgipb6zomeaovod456pb7yjs-bctwwqj7p01tcj2smshz2bboe-88ec8b078z4fzj5q3z4qowg63-bftaa82sjwcbrohoe28skni7b-58m2n4boqb1vxfd6hgd34auwd-82i5b2jv41vqmfkb5brdajvv-e7xlsv13j9f9fgq7i82f6mifw-di2107u61yb11ttimo0s2qyh2-oj1awm2qygfeios7s2x0fa61-5ms6g95rjk28v6utub7tqsm6p-57rtjqe4t3konsfn7bdgz1k9y-ep4eby7oah63xbtrubx5la06x-57lg2yf3jfayguexsnkdcuf6b-79615c4mj6otmcf44qijztqe6-3k0zrzmwcnxm0ws6nd668nh27-5n3swaprsuzx5tzjb766zsd0a-9u02huxx231jnju6devou27km-6zjqq8r01lawj679i43jm042q-dw2b2bmrlx7m31av10jvin21k-4z7y569rucgjkitpdzpd0lr56-d10ox4iv2fu2pcnng02u8mlmn-dksuef1kjeuyovuvqowr79mf0-cfabcg4u1cj0em4yissh5mfxu" type="text/javascript">
#    </script>
#    <footer class="layout-header-or-footer wide-footer" id="layout-footer" role="contentinfo">
#     <div class="wrapper">
#      <nav aria-label="Footer Navigation" role="navigation">
#       <ul class="nav-footer" role="menubar">
#        <li role="menuitem">
#         <a href="https://www.linkedin.com/help/linkedin?lang=en" title="Help Center">
#          Help Center
#         </a>
#        </li>
#        <li id="li-about" role="menuitem">
#         <a href="//press.linkedin.com/about-linkedin" id="li-about-trigger">
#          About
#         </a>
#         <ul id="li-about-options">
#          <li role="menuitem">
#           <a href="http://www.linkedin.com/redir/redirect?url=https%3A%2F%2Fpress%2Elinkedin%2Ecom%2F&amp;urlhash=uTdA" target="_blank">
#            Press
#           </a>
#          </li>
#          <li role="menuitem">
#           <a href="http://www.linkedin.com/redir/redirect?url=https%3A%2F%2Fblog%2Elinkedin%2Ecom%2F&amp;urlhash=bplK" target="_blank">
#            Blog
#           </a>
#          </li>
#          <li role="menuitem">
#           <a href="http://www.linkedin.com/redir/redirect?url=https%3A%2F%2Fdeveloper%2Elinkedin%2Ecom&amp;urlhash=Qc8-" target="_blank">
#            Developers
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li role="menuitem">
#         <a href="https://www.linkedin.com/company-beta/linkedin/jobs?trk=hb_ft_work">
#          Careers
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="/advertising?src=en-all-el-li-hb_ft_ads&amp;trk=hb_ft_ads">
#          Advertising
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="http://www.linkedin.com/redir/redirect?url=http%3A%2F%2Fbusiness%2Elinkedin%2Ecom%2Ftalent-solutions%3Fsrc%3Dli-footer&amp;urlhash=f9Nj" target="_blank">
#          Talent Solutions
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="http://www.linkedin.com/redir/redirect?url=http%3A%2F%2Fbusiness%2Elinkedin%2Ecom%2Fsales-solutions%3Fsrc%3Dli-footer%26trk%3Dlss_linkedin_footer_link2micro%26utm_source%3Dfooter%26utm_medium%3Dlinkedin%26utm_campaign%3Dlinkedin-footer&amp;urlhash=_ibI" target="_blank">
#          Sales Solutions
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="http://www.linkedin.com/redir/redirect?url=https%3A%2F%2Fsmallbusiness%2Elinkedin%2Ecom%2F%3Ftrk%3Dlnkd_footer%26utm_source%3Dlinkedin%26utm_medium%3Dfooter%26utm_content%3D%26utm_campaign%3Dlifooter&amp;urlhash=lFQo" target="_blank">
#          Small Business
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="//mobile.linkedin.com" target="_blank">
#          Mobile
#         </a>
#        </li>
#        <li id="nav-utility-lang" role="menuitem">
#         <a href="/secure/settings">
#          Language
#         </a>
#         <form accept-charset="UTF-8" action="https://www.linkedin.com/psettings/update-language" method="POST" name="languageSelectorForm" novalidate="novalidate">
#          <ul id="lang-list" role="menu">
#           <li class="in" role="menuitem">
#            <a href="/secure/settings" lang="in_ID">
#             <span>
#              Bahasa Indonesia
#             </span>
#            </a>
#           </li>
#           <li class="ms" role="menuitem">
#            <a href="/secure/settings" lang="ms_MY">
#             <span>
#              Bahasa Malaysia
#             </span>
#            </a>
#           </li>
#           <li class="cs" role="menuitem">
#            <a href="/secure/settings" lang="cs_CZ">
#             <span>
#              Čeština
#             </span>
#            </a>
#           </li>
#           <li class="da" role="menuitem">
#            <a href="/secure/settings" lang="da_DK">
#             <span>
#              Dansk
#             </span>
#            </a>
#           </li>
#           <li class="de" role="menuitem">
#            <a href="/secure/settings" lang="de_DE">
#             <span>
#              Deutsch
#             </span>
#            </a>
#           </li>
#           <li class="selected en" role="menuitem">
#            <a href="/secure/settings" lang="en_US">
#             <strong>
#              English
#             </strong>
#            </a>
#           </li>
#           <li class="es" role="menuitem">
#            <a href="/secure/settings" lang="es_ES">
#             <span>
#              Español
#             </span>
#            </a>
#           </li>
#           <li class="zh" role="menuitem">
#            <a href="/secure/settings" lang="zh_TW">
#             <span>
#              繁體中文
#             </span>
#            </a>
#           </li>
#           <li class="fr" role="menuitem">
#            <a href="/secure/settings" lang="fr_FR">
#             <span>
#              Français
#             </span>
#            </a>
#           </li>
#           <li class="ko" role="menuitem">
#            <a href="/secure/settings" lang="ko_KR">
#             <span>
#              한국어
#             </span>
#            </a>
#           </li>
#           <li class="it" role="menuitem">
#            <a href="/secure/settings" lang="it_IT">
#             <span>
#              Italiano
#             </span>
#            </a>
#           </li>
#           <li class="zh" role="menuitem">
#            <a href="/secure/settings" lang="zh_CN">
#             <span>
#              简体中文
#             </span>
#            </a>
#           </li>
#           <li class="nl" role="menuitem">
#            <a href="/secure/settings" lang="nl_NL">
#             <span>
#              Nederlands
#             </span>
#            </a>
#           </li>
#           <li class="ja" role="menuitem">
#            <a href="/secure/settings" lang="ja_JP">
#             <span>
#              日本語
#             </span>
#            </a>
#           </li>
#           <li class="no" role="menuitem">
#            <a href="/secure/settings" lang="no_NO">
#             <span>
#              Norsk
#             </span>
#            </a>
#           </li>
#           <li class="pl" role="menuitem">
#            <a href="/secure/settings" lang="pl_PL">
#             <span>
#              Polski
#             </span>
#            </a>
#           </li>
#           <li class="pt" role="menuitem">
#            <a href="/secure/settings" lang="pt_BR">
#             <span>
#              Português
#             </span>
#            </a>
#           </li>
#           <li class="ro" role="menuitem">
#            <a href="/secure/settings" lang="ro_RO">
#             <span>
#              Română
#             </span>
#            </a>
#           </li>
#           <li class="ru" role="menuitem">
#            <a href="/secure/settings" lang="ru_RU">
#             <span>
#              Русский
#             </span>
#            </a>
#           </li>
#           <li class="sv" role="menuitem">
#            <a href="/secure/settings" lang="sv_SE">
#             <span>
#              Svenska
#             </span>
#            </a>
#           </li>
#           <li class="tl" role="menuitem">
#            <a href="/secure/settings" lang="tl_PH">
#             <span>
#              Tagalog
#             </span>
#            </a>
#           </li>
#           <li class="th" role="menuitem">
#            <a href="/secure/settings" lang="th_TH">
#             <span>
#              ภาษาไทย
#             </span>
#            </a>
#           </li>
#           <li class="tr" role="menuitem">
#            <a href="/secure/settings" lang="tr_TR">
#             <span>
#              Türkçe
#             </span>
#            </a>
#           </li>
#           <li class="ar" role="menuitem">
#            <a href="/secure/settings" lang="ar_AE">
#             <span>
#              العربية
#             </span>
#            </a>
#           </li>
#          </ul>
#          <input name="locale" type="hidden" value=""/>
#          <input name="csrfToken" type="hidden" value="ajax:2291069490470548862"/>
#         </form>
#        </li>
#        <li role="menuitem">
#         <a href="/learning/?trk=li_footer_learning" target="_blank">
#          Online Learning
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="/profinder?trk=hb_ft_profinder">
#          ProFinder
#         </a>
#        </li>
#       </ul>
#      </nav>
#      <nav aria-label="Footer Directory Menu" role="navigation">
#       <ul class="nav-footer li-links" role="menubar">
#        <li role="menuitem">
#         <a href="https://www.linkedin.com/jobs?trk=hb_ft_jobs">
#          Search Jobs
#         </a>
#        </li>
#       </ul>
#       <ul class="nav-footer directories" role="menubar">
#        <li>
#         Directories
#        </li>
#        <li role="menuitem">
#         <a href="https://www.linkedin.com/directory/people-a?trk=hb_ft_peopledir">
#          Members
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="https://www.linkedin.com/directory/pulse">
#          Pulse
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="https://www.linkedin.com/directory/companies">
#          Companies
#         </a>
#        </li>
#        <li role="menuitem">
#         <a href="https://www.linkedin.com/directory/universities">
#          Universities
#         </a>
#        </li>
#       </ul>
#      </nav>
#      <p class="copyright guest">
#       <span>
#        LinkedIn Corporation
#       </span>
#       <em>
#        © 2018
#       </em>
#      </p>
#      <ul aria-label="Footer Legal Menu" class="nav-legal" role="navigation">
#       <li role="menuitem">
#        <a href="/legal/user-agreement?trk=hb_ft_userag">
#         User Agreement
#        </a>
#       </li>
#       <li role="menuitem">
#        <a href="/legal/privacy-policy?trk=hb_ft_priv">
#         Privacy Policy
#        </a>
#       </li>
#       <li role="menuitem">
#        <a href="https://www.linkedin.com/help/linkedin/answer/34593?lang=en">
#         Community Guidelines
#        </a>
#       </li>
#       <li role="menuitem">
#        <a href="/legal/cookie-policy?trk=hb_ft_cookie">
#         Cookie Policy
#        </a>
#       </li>
#       <li role="menuitem">
#        <a href="/legal/copyright-policy?trk=hb_ft_copy">
#         Copyright Policy
#        </a>
#       </li>
#       <li role="menuitem">
#        <a href="/psettings/guest-email-unsubscribe?trk=hb_ft_gunsub" rel="nofollow">
#         Unsubscribe
#        </a>
#       </li>
#      </ul>
#     </div>
#    </footer>
#    <script data-page-js-type="config">
#     (function(n, r, a) {
#                       r = window[n] = window[n] || {};
#
#
#
#                                 a = r['WebTracking'] = r['WebTracking'] || {};
#                                 a['URLs'] = {'saveWebActionTrackURL':'\/lite\/secure-web-action-track?csrfToken=ajax%3A2291069490470548862'};
#
#
#
#                     }('__li__config_registry__'));
#    </script>
#    <script data-page-js-type="lix">
#     (function(n, r, a) {
#                       r = window[n] = window[n] || {};
#
#
#                             r['global_bsp_notice_type'] = 'warning';
#
#
#
#                             r['global_bsp_notice_autoHide'] = 'false';
#
#
#
#                             r['global_bsp_view_threshold'] = 'c5';
#
#
#                     }('__li__lix_registry__'));
#    </script>
#    <script data-page-js-type="i18n">
#     (function(n, r, a) {
#                       r = window[n] = window[n] || {};
#
#
#                             r['global_browser_unsupported_notice'] = 'Looks like you\'re using a browser that\'s not supported. <a target=\"_blank\" href=\"https:\/\/www.linkedin.com\/help\/linkedin\/answer\/4135?lang=en\">Learn more about browsers you can use.<\/a>';
#
#
#                     }('__li__i18n_registry__'));
#    </script>
#    <script data-page-js-type="config">
#     (function(n, r, a) {
#                       r = window[n] = window[n] || {};
#
#
#
#                                 r['LoggedOutBadging'] = {url: '\/chrome\/logged-out-badging?csrfToken=ajax%3A2291069490470548862'};
#
#
#
#
#
#                                 a = r['global:browserSupportPolicy'] = r['global:browserSupportPolicy'] || {};
#                                 a['supportedBrowserMinVersions'] = {      ie:             'control',      firefox:        'v38',      opera:          'control',      safari:         'v6.1',      chrome:         'v42',      mobileSafari:   'v7',      android:        'v2.3',      androidChrome:  'v0'    };
#
#
#
#                     }('__li__config_registry__'));
#    </script>
#    <script src="https://static.licdn.com/scds/concat/common/js?h=3kp2aedn5pmamdr4dk4n8atur-3ti5bgrnb6idjtk0w4chaigxe-5hqr1i1uoezoj0z1s5gcxojf2-71o37tcjwl0ishto9izvyml3i-3bbdjshpw5ov0rwa8xe08tp97-cayct4cirf7n0f9z1xsg84g0q-dktkawxk7k8pixuh5g8z5ku32-213zbp2wzp99lviwl8g2cvq6i-1lknwtftishpdmobzm413yc7u-bcxa0v9ke411pjpmz4s239f9b-3ti7256qpio9gkb1m7ftci4rt-c6ct0moql4p4ngtzltmf8l3ly-2s77lcl0ztx2c5fzyqvglptj1-1o1jaeb56loy3vv8018s13dno-8h514j3fiwnzuwkt66sbxsu8f-di2z9sra5co9la7ogqyesywin" type="text/javascript">
#    </script>
#    <code id="viewJobMetaTagModule">
#     <!--{"description":"Posted 17 days ago. Data Scientist, EA Customer Experience#WeAreEA and we exist to inspire the world to play. EA value...See this and similar jobs on LinkedIn."}-->
#    </code>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("viewJobMetaTagModule");},false);})()
#    </script>
#    <code id="companyDescriptionModule">
#     <!--{"following":false,"companyDescription":"\u003cp\u003eElectronic Arts Inc. is a leading global interactive entertainment software company. EA delivers games, content and online services for Internet-connected consoles, personal computers, mobile phones and tablets.\u003c/p\u003e","companyName":"Electronic Arts","canFollow":false,"companyId":"1449"}-->
#    </code>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("companyDescriptionModule");},false);})()
#    </script>
#    <code id="guestApplyModalModule">
#     <!--{"memberJobDetailsPageUrlFromGuestApply":"https://www.linkedin.com/jobs/view/791327763?trk=job_view_land_on_member_page_from_guest_apply","showGuestApplyModal":false,"guestApplySignInUrl":"https://www.linkedin.com/uas/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fview%2F791327763&emailAddress=&fromSignIn=","wwwJobDetailsPageUrlFromSubdomain":"https://www.linkedin.com/jobs/view/791327763?trk=job_view_land_on_member_page_from_guest_apply&showGuestApplyModal=true","uploadInfo":"HSUrvtt1QQBrMIBk52r7wVUHv3lcyszwoOG5mZmPS8ucTU5SoOB5Jz1yuZ_WPOZSkObAq9mk55ifjIelTjgxZ1mP47udgbTvI0r4Olmh4qFcfDzOHgElOBoc1FucNGTv2nUllhUQOZ_WosazNjLXJQLc-PAq7n5o80yueYLnlY3cTm5S_ppOLWUQx57RQrA5c-ESM3EP4WAhdmew70m5MQ-Qq3"}-->
#    </code>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("guestApplyModalModule");},false);})()
#    </script>
#    <code id="impressionTrackingDisplayModule">
#     <!--{"trackingCode":"","memberUrn":"urn:li:member:0","clientRequestId":"6cd1c1e3-3b8b-4a8b-b086-71847e08411a","requestHeader":{"trackingCode":"","path":"/jobs/view/791327763/","userAgent":"python-requests/2.18.4","locale":"","pageKey":"d_jobs_job_detail_premium_guest","referer":""},"referenceId":"","header":{"service":"jobs-frontend","time":1537295142433},"jobUrn":"urn:li:jobPosting:791327763","isSponsored":false}-->
#    </code>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("impressionTrackingDisplayModule");},false);})()
#    </script>
#    <code id="jobDescriptionModule">
#     <!--{"description":"Data Scientist, EA Customer Experience\u003cbr\u003e\u003cbr\u003e#WeAreEA and we exist to inspire the world to play. EA values creativity, pioneering, passion, determination, learning, and teamwork. We mean things like acting with curiosity, speaking up with original ideas, and committing to each other as one team.\u003cbr\u003e\u003cbr\u003eWe’re looking for all the best kinds of people to make great experiences for our players. The best people want a job that inspires them, while giving them room to enjoy their lives. And we want to give them that. We celebrate diversity and inclusion by creating a place where you can come to work and be yourself.\u003cbr\u003e\u003cbr\u003eYou’re a Data Scientist.\u003cbr\u003e\u003cbr\u003e\u003cstrong\u003e\u003cu\u003eYou Understand That You Have 2 Basic Jobs\u003cbr\u003e\u003cbr\u003e\u003c/u\u003e\u003c/strong\u003eYou know how to pull all types of data from any source, be it Facebook posts, call center chats, video likes or survey results.\u003cbr\u003e\u003cbr\u003eHelp our studios understand what problems players have with their games and provide insights that help optimize our call center. Both pursue the ultimate goal of providing the World’s Best Service for the World’s Best Games.\u003cbr\u003e\u003cbr\u003eYou use all resources available to you to help solve a problem, be it a new algorithm, programming language or the person sitting next to you.\u003cbr\u003e\u003cbr\u003eYou’re a programmer/statistician/NLP expert who is fanatic about games and Customer Experiences.\u003cbr\u003e\u003cbr\u003eYou’re also a genuinely nice person who brings positive energy to an office. You’re approachable and take the time to listen so that you understand someone else’s view.\u003cbr\u003e\u003cbr\u003eThis role is part of EA’s Customer Experience organization. The Customer Experience organization strives to make EA known for taking care of its players. We’re players taking care of players and people talking to people – whenever, wherever, and however they need us.\u003cbr\u003e\u003cbr\u003eWe’re the Data Science team, part of the larger Customer Experience Insights team.\u003cbr\u003e\u003cbr\u003eWe are surrounded by Production, BI, SEO and Market Research analysts. We’re the people who use advanced statistics and modeling to help solve business problems. We surface player problems through our text analytics offerings. We write a lot of code and talk to stakeholders from all teams and all levels. We are great team mates and trusted advisors, who provide insights to facilitate decisions and create models that change experiences.\u003cbr\u003e\u003cbr\u003eA typical day in the life of a Data Scientist:\u003cbr\u003e\u003cul\u003e\u003cli\u003eCome into the office and catch up with your team mates about last night’s gaming session or the hottest show on TV (no spoilers until 24hrs have passed – after that: anything is fair game!)\u003c/li\u003e\u003cli\u003eCheck on last night’s Jenkins script and add some code to a project you’re working on\u003c/li\u003e\u003cli\u003eTalk to one of your coworkers on the Call Center side about how to match the right advisor to the right player – this could be your next big project\u003c/li\u003e\u003cli\u003eTake some time back at your desk to write up any notes and make a project plan proposal\u003c/li\u003e\u003cli\u003eAttend a JIRA prioritization meeting to update work that’s in flight and plan for work to come\u003c/li\u003e\u003cli\u003eGrab coffee and read up on any stats blogs or tech news you’re subscribed to\u003c/li\u003e\u003cli\u003eCheck out the model you deployed into production last month to see if it’s time to re-train\u003c/li\u003e\u003cli\u003ePull the latest changes on an NLP model you’re collaborating on from Stash and tinker with the parameters, then chat with your peer about the results of the tweaks and make plans for what to change next\u003c/li\u003e\u003cli\u003eSpend a couple of hours heads down/headphone ...
#    </code>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("jobDescriptionModule");},false);})()
#    </script>
#    <code id="companyTargetedMediaModule">
#     <!--{"mediaType":"IMAGE","companySubtitle":"Media","moduleName":"ABOUT_COMPANY","text":"With over 300 million players around the world playing our games, there has never been a more exciting time to be a part of Electronic Arts. \n\nCreating transformational experiences requires constant innovation and brilliant, passionate people. We are developing extraordinary new games by bringing together great teams that combine creativity, technology and expertise to deliver new ways to play.\n\nConnect your future to ours. Inspire. Dream. Play.","mediaUrl":"https://media.licdn.com/media/AAMB_wFAAAkAAQAAAAAAAAkFAAAAJDIxZDRiZDdkLTdmYzYtNDBhYS1iOWU2LTMzZWNjYWQ4YjM4ZQ.jpg","links":[{"anchorText":"Search EA Careers","link":"http://www.linkedin.com/redir/redirect?url=http%3A%2F%2Fcareers%2Eea%2Ecom&urlhash=OC8Z"},{"anchorText":"Join Inside EA's LinkedIn group","link":"http://www.linkedin.com/redir/redirect?url=http%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fgroups%3Fhome%3D%26gid%3D722827%26trk%3Danet_ug_hm&urlhash=-iLH"}],"media":"urn:li:media:/AAMB_wFAAAkAAQAAAAAAAAkFAAAAJDIxZDRiZDdkLTdmYzYtNDBhYS1iOWU2LTMzZWNjYWQ4YjM4ZQ.jpg","title":"Media"}-->
#    </code>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("companyTargetedMediaModule");},false);})()
#    </script>
#    <code id="globalVariableModule">
#     <!--{"currentTime":1537295142426,"isCrawler":false,"isMobilePhone":false,"isTablet":false,"pageKey":"d_jobs_job_detail_premium_guest","isPremium":false,"applyLogin":false,"isLoggedIn":false,"isDesktop":true}-->
#    </code>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("globalVariableModule");},false);})()
#    </script>
#    <code id="UILixModule">
#     <!--{"disableRobotsFollowNoindexTag":true,"isClassmatesCoworkersModalEnabled":false,"showJobPosterInfo":true,"rightRailLearningCopy":"control","shouldUseVectorCompanyLogo":true,"isStickySearchEnabled":false,"isRelatedJserpLinkInJobDetailsEnabled":true,"postApplyVisualDisplay":"right_gray","isMobileTopcardUpdateEnabled":false,"isSeedAboveTheFoldEnabled":false,"showBannerImage":false,"isJobAlertInJobDetailEnabled":true,"isSPANavigationEnabled":false,"isGuestApplyFlowEnabled":false,"isJobsGuestChromeEnabled":true,"enableDerivedLocation":false,"showTopRelevantJobsInSimilarJobs":true,"lyndaLearningUpsell":{"treatment":"control","upsellType":"default","url":"http://www.linkedin.com/premium/products?family=jss&trk=job_view_insights_upsell_control_neo_premium_listing"},"isRedirectToSimilarJobsOnExternalApplyEnabled":true,"isTrackingTwoEnabled":false,"isSeedEnabled":false,"areVideosEnabled":true,"isGuestApplyCollapseOptionalEnabled":false,"isInterestedCandidatesEnabled":true,"shouldRedirectToReg":false,"isSearchHistoryTypeaheadEnabled":false,"isApplyStarterEnabledForJobSeeker":true,"experimentalTwoBoxTypeaheadEndpoint":false,"showTagsForJobCards":false,"isRemoteJobsSchemaEnabled":true,"isGuestApplyStickyHeaderFooterEnabled":false,"isJobDetailStickyCTAEnabled":true,"isMeetTheTeamEnabled":true,"isApplyStarterModalNewMessageEnabled":true,"isViewJobConsumer2Enabled":true,"isMobileSeedTopCardEnabled":false,"hideFlavorLinks":false,"isProjectMoonshotEnabled":true,"isLoadTransitionEnabled":false,"showStickyNav":false,"rightRailUpsell":"below","showTopPremiumJobsInSimilarJobs":true}-->
#    </code>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("UILixModule");},false);})()
#    </script>
#    <code id="posterInformationModule">
#     <!--{}-->
#    </code>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("posterInformationModule");},false);})()
#    </script>
#    <code id="shareModule">
#     <!--{"jobPosting":{"companyName":"Electronic Arts","title":"Data Scientist"},"hostname":"linkedin.com","bottom":"true","pageUrl":"https://www.linkedin.com/jobs2/view/791327763","locale":"en_US","lang":"en","protocol":"https://"}-->
#    </code>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("shareModule");},false);})()
#    </script>
#    <code id="decoratedJobPostingModule">
# ...
#    </code>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("peopleAlsoViewedModule");},false);})()
#    </script>
#    <code id="otherJobsAtCompanyModule">
#     <!--{"jobs":[{"decoratedJobPosting":{"jobPosting":{"listDate":1537261552000,"functions":["ENG","IT"],"companyName":"Electronic Arts","jobState":"LISTED","postalCode":"94059","listingType":"PREMIUM","title":"Software Engineer (University Grad)","countryCode":"us","company":"urn:li:company:1449","id":769994244,"applicationRouting":"COMPANY_WEBSITE"},"companyName":"Electronic Arts","formattedLocation":"Redwood City, CA, US","formattedIndustries":["Computer Games","Information Technology and Services","Computer Software"],"derivedLocation":"San Francisco Bay Area","decoratedCompany":{"company":{"companyId":1449,"names":[{"name":"Electronic Arts (EA)","active":true,"locale":"en_US","type":"CANONICAL"},{"name":"EA","active":true,"locale":"en_US","type":"ALTERNATE"},{"name":"EA SPORTS","active":true,"locale":"en_US","type":"ALTERNATE"},{"name":"美国艺电公司","active":true,"locale":"zh_CN","type":"ALTERNATE"},{"name":"美商藝電","active":true,"locale":"zh_TW","type":"ALTERNATE"}],"logo":"urn:li:media:/AAMAAgQIAAkAAQAAAAAAAA4EAAAAJDZkNzQyZDZiLTQ0ZTEtNDE0NC1hYWEyLTE5Yjc2ZTYyMjVlMQ.bin"},"companyLogo":{"urn":"urn:li:media:/AAMAAgQIAAkAAQAAAAAAAA4EAAAAJDZkNzQyZDZiLTQ0ZTEtNDE0NC1hYWEyLTE5Yjc2ZTYyMjVlMQ.bin","logoType":"SQUARE_LOGO_V2","link":"https://media.licdn.com/dms/image/C4D0BAQGOlVviOdDcoQ/company-logo_100_100/0?e=1545264000&v=beta&t=EGrgqnMi8_kYj6bn77ayn0yMarbm-COV5caOuVMnwac"},"heroImageLink":"https://media.licdn.com/dms/image/C4D1BAQFrF33j9ymdxA/company-background_10000/0?e=1537383600&v=beta&t=lItHe2FeW2gzJO7VxIwrj1VMOEmvHBzKy0IhTR9mjZA","squareLogoMediaLink":"https://media.licdn.com/dms/image/C4D0BAQGOlVviOdDcoQ/company-logo_100_100/0?e=1545264000&v=beta&t=EGrgqnMi8_kYj6bn77ayn0yMarbm-COV5caOuVMnwac","logoMediaLink":"https://media.licdn.com/dms/image/C4D0BAQGOlVviOdDcoQ/company-logo_100_100/0?e=1545264000&v=beta&t=EGrgqnMi8_kYj6bn77ayn0yMarbm-COV5caOuVMnwac","canonicalName":"Electronic Arts (EA)"},"hasDecoratedCompany":true,"formattedExperience":"Not Applicable","formattedJobFunctions":["Engineering","Information Technology"],"formattedEmploymentStatus":"Full-time","formattedPostedDaysAgo":"Posted 9 hours ago","formattedPostedDaysAgoSlim":"9 hours ago","formattedPostedDaysAgoShort":"9h","formattedListDate":"September 18, 2018","offsiteApply":true,"newJob":true,"jobPostingLocalizedCompanyName":"Electronic Arts (EA)","applicationSetting":{"jobPosting":"urn:li:jobPosting:769994244","applyMethod":{"com.linkedin.jobs.OffsiteApply":{}},"lastEligibilityCheckAt":1537270570354}},"viewJobUrl":"https://www.linkedin.com/jobs/view/software-engineer-university-grad-at-electronic-arts-ea-769994244?trk=job_view_company_other_jobs"},{"decoratedJobPosting":{"jobPosting":{"listDate":1537175129000,"functions":["STRA","ANLS","IT"],"companyName":"Electronic Arts","jobState":"LISTED","postalCode":"94059","listingType":"PREMIUM","title":"Data Scientist I","countryCode":"us","company":"urn:li:company:1449","id":751036024,"applicationRouting":"COMPANY_WEBSITE"},"companyName":"Electronic Arts","formattedLocation":"Redwood City, CA, US","formattedIndustries":["Computer Games","Information Technology and Services","Computer Software"],"derivedLocation":"San Francisco Bay Area","decoratedCompany":{"company":{"companyId":1449,"names":[{"name":"Electronic Arts (EA)","active":true,"locale":"en_US","type":"CANONICAL"},{"name":"EA","active":true,"locale":"en_US","type":"ALTERNATE"},{"name":"EA SPORTS","active":true,"locale":"en_US","type":"ALTERNATE"},{"name":"美国艺电公司","active":true,"locale":"zh_CN","type":"ALTERNATE"},{"name":"美商藝電","active":true,"locale":"zh_TW","type":"ALTERNATE"}],"logo":"urn:li:media:/AAMAAgQIAAkAAQAAAAAAAA4EAAAAJDZkNzQyZDZiLTQ0ZTEtNDE0NC1hYWEyLTE5Yjc2ZTYyMjVlMQ.bin"},"companyLogo":{"urn":"urn:li:media:/AAMAAgQIAAkAAQAAAAAAAA4EAAAAJDZkNzQyZDZiLTQ0ZTEtNDE0NC1hYWEyLTE5Yjc2ZTYyMjVlMQ.bin","logoType":"SQUARE_LOGO_V2","link":"https://media.licdn.com/dms/image/C4D0BAQGOlVviOdDcoQ/company-logo_100_100/0?e=1545264000&v=beta&t=EGrgqnMi8_kYj6bn77ayn0yMarbm-COV ...
#    </code>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("otherJobsAtCompanyModule");},false);})()
#    </script>
#    <code id="meetTheTeamDisplayModule">
#     <!--{"registrationUrl":"https://www.linkedin.com/start/join?session_redirect=http%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fsearch%2Fresults%2Fpeople%2F%3FfacetCurrentCompany%3D1449%26title%3Dscientist%26trk%3Djobs_job_detail_meet_the_team_see_all%26bypassMobileRedirects%3Dfalse&source=jobs_registration&trk=jobs_job_detail_meet_the_team_see_all","debugInfo":{"standardizedTitle":"scientist","numberOfPeopleToDecorate":1,"numberOfPeopleToShow":1},"decoratedProfiles":[{"decoratedProfile":{"initials":"HC","fullName":"Harold Chaput","memberId":284328,"skills":[{"name":"Technical Direction"},{"name":"Machine Learning"},{"name":"Game Development"},{"name":"Software Development"},{"name":"Artificial Intelligence"},{"name":"Online Gaming"},{"name":"Computer Science"},{"name":"Team Leadership"},{"name":"Distributed Team Management"},{"name":"University Teaching"},{"name":"Cognitive Development"},{"name":"Mobile Robotics"},{"name":"R&D"},{"name":"Software Patents"},{"name":"Video Games"},{"name":"Non-profit Administration"},{"name":"Computer Games"},{"name":"Volunteer Management"},{"name":"Grant Writing"},{"name":"C++"},{"name":"Java"},{"name":"PS4"},{"name":"Xbox One"},{"name":"Game Programming"},{"name":"PS3"},{"name":"Xbox 360"},{"name":"Perforce"},{"name":"Game Design"},{"name":"Gameplay"},{"name":"Gameplay Programming"},{"name":"Multiplayer"},{"name":"Mobile Games"},{"name":"Web Service Development"},{"name":"Artificial Neural Networks"}],"degreeDistance":"OUT_OF_NETWORK","firstName":"Harold","lastName":"Chaput","vanityName":"hchaput","industry":"Computer Games","pictureLink":"https://media.licdn.com/dms/image/C4E03AQGNdrpmF7BS7A/profile-displayphoto-shrink_800_800/0?e=1542844800&v=beta&t=MpcqDmB48GzKqFTjR0Ey-uimShutX2_NORjBaEBy83g","picture":"C4E03AQGNdrpmF7BS7A","formattedLocation":"Belmont, California","memberWithAuthKey":"284328,name,kqZb","positionsWithCompany":[{"profilePositionId":1065759632,"title":"AI Scientist","standardizedTitle":"Scientist","suggestedStandardizedTitles":[{"displayName":"Scientist","titleId":197,"isVague":false}],"companyName":"Electronic Arts (EA)","company":"urn:li:company:1449","startMonthYear":{"month":9,"year":2017},"durationString":"1 year 1 month","localizedLocationName":"Redwood City, California","companyLogoImage":"urn:li:media:/AAMAAgQIAAkAAQAAAAAAAA4EAAAAJDZkNzQyZDZiLTQ0ZTEtNDE0NC1hYWEyLTE5Yjc2ZTYyMjVlMQ.bin","companyLogoImageLink":"https://media.licdn.com/dms/image/C4D0BAQGOlVviOdDcoQ/company-logo_400_400/0?e=1545264000&v=beta&t=ggbkV6W_zFegr6d5C1qzWmW6OP_5_dcXlzyXM38mSN0","companyHeroImage":"urn:li:media:/AAEAAQAAAAAAAATJAAAAJDA0NmNlMWJmLTg3ZjctNDZlYi05MDk1LWFiZDdiZTczNDBiOA.png","companyHeroImageLink":"https://media.licdn.com/dms/image/C4D1BAQFrF33j9ymdxA/company-background_10000/0?e=1537383600&v=beta&t=lItHe2FeW2gzJO7VxIwrj1VMOEmvHBzKy0IhTR9mjZA","companyCanonicalName":"Electronic Arts (EA)"},{"profilePositionId":231148594,"title":"Technical Director","standardizedTitle":"Technical Director","suggestedStandardizedTitles":[{"displayName":"Technical Director","titleId":200,"isVague":false}],"companyName":"Bioware","company":"urn:li:company:162717","startMonthYear":{"month":11,"year":2011},"endMonthYear":{"month":9,"year":2017},"durationString":"5 years 11 months","localizedLocationName":"Montreal, QC, Canada","companyLogoImage":"urn:li:media:/AAMAAgQIAAkAAQAAAAAAABG9AAAAJDFjNDEzZjE0LTFiZDctNDgyNy05OGU1LWRkNTNkMDNmMmRlMA.bin","companyLogoImageLink":"https://media.licdn.com/dms/image/C4D0BAQHaML5RX8MY5Q/company-logo_400_400/0?e=1545264000&v=beta&t=9q6Vn8Y1SpIfGs_ECLLIoEr5dMoiw-UZ_IGEG5xFJlk","companyCanonicalName":"Bioware"},{"profilePositionId":1081464,"title":"Technical Director","standardizedTitle":"Technical Director","suggestedStandardizedTitles":[{"displayName":"Technical Director","titleId":200,"isVague":false}],"formattedLocation":"Vancouver, Canada Area","companyName":"Electronic Arts (EA)","company":"urn:li:company:1449","startMonthYear":{"month":12,"year":2008},"endMonthYear":{"month":11,"ye ...
#    </code>
#    <script>
#     (function(){document.addEventListener('flushReady',function(){window.__LI_JOBS_DS__.flushModule("meetTheTeamDisplayModule");},false);})()
#    </script>
#    <script type="text/javascript">
#     (function () {
#     var config;
#     if (!window.__li__config_registry__) {
#       window.__li__config_registry__ = {};
#     }
#
#     config = window.__li__config_registry__;
#
#     if (!config.jobs) {
#       config.jobs = {};
#     }
#
#     config.jobs.embeddedContentIds = {
#       decoratedJob: 'decoratedJobPostingModule',
#       jobPosting: 'topCardV2Module',
#       shareModule: 'shareModule',
#       jobSummary: 'jobDescriptionModule',
#       posterInfo: 'posterInformationModule',
#       browseMap: 'peopleAlsoViewedModule',
#       similarJobs: 'similarJobsModule',
#       reasonToCare: 'reasonToCareDisplayModule',
#       whatsYourIn: 'yourInDisplayModule',
#       companyPremiumInsights: 'compressedCompanyInsightsModule',
#       applicantsPremiumInsights: 'compressedApplicantAnalyticsModule',
#       globalVariable: 'globalVariableModule',
#       lixModule: 'UILixModule',
#       peopleAlsoSearched: 'peopleAlsoSearchedDisplayModule',
#       guestChrome: 'guestChromeDisplayModule',
#       companyOtherJobs: 'otherJobsAtCompanyModule',
#       companyDescription: 'companyDescriptionModule',
#       companyMedia: 'companyTargetedMediaModule',
#       jobSalary: 'jobSalaryDisplayModule',
#       jobSalaryV2: 'jobSalaryV2DisplayModule',
#       jobSalaryBraavos: 'jobSalaryBraavosDisplayModule',
#       companyRecentUpdates: 'companyRecentUpdatesModule',
#       meetTheTeam: 'meetTheTeamDisplayModule',
#       errorModule: 'errorModule',
#       postJob: 'postJobModule',
#       lyndaDisplay: 'lyndaDisplayModule',
#       interestedCandidates: 'interestedCandidatesModule',
#       helpCenter: 'helpCenterModule',
#       upsellModule: 'upsellDisplayModule',
#       seoModule: 'seoModule',
#       careerSubnav: 'jobCareerSubnavModule',
#       impressionTrackingDisplayModule: 'impressionTrackingDisplayModule',
#       standardizedLocation: 'standardizedLocationModule',
#       googleAnalyticsModule: 'googleAnalyticsModule',
#       jserpBadgeCreate: 'jserpBadgeCreateModule',
#       jobLocationDisplay: 'jobLocationDisplayModule',
#       viewJobMetaTagModule: 'viewJobMetaTagModule',
#       guestApplyModalModule: 'guestApplyModalModule',
#       relatedJserps: 'relatedJserpsDisplayModule'
#     };
#    }());
#    </script>
#    <script src="https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.1605/f/%2Fjobs-frontend%2Fconcat%2Freg-fe-client-dependencies_en_US.js" type="text/javascript">
#    </script>
#    <script src="https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.1605/f/%2Fjobs-frontend%2Fconcat%2Fapp-dist_en_US.js" type="text/javascript">
#    </script>
#    <script src="https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.1605/f/%2Fjobs-frontend%2Fconcat%2Fmarionette-templates_en_US.js" type="text/javascript">
#    </script>
#    <script>
#     (function () {
#    document.addEventListener('flushReady', function () {
#       window.__LI_JOBS_DS__.flushCompleted();
#      }, false);
#   })();
#    </script>
#    <meta content="//platform.linkedin.com/js/px.js" name="detectAdBlock">
#     <script async="" defer="" src="https://static.licdn.com/scds/concat/common/js?h=69w33ou4umkyupw2uqgn7za7w">
#     </script>
#     <script class="comscore-tracking">
#      (function(_e, _r) {
#  var isNielsenDisabled = true;
#  var providers = {
#  'COMSCORE': {
#  'treatment': 'control'
#  }
#  };
#  if (!isNielsenDisabled) {
#  providers['NIELSEN'] = {
#  'treatment': 'control'
#  };
#  }
#
#  var fireComscore = function() {
#  var comScore = window.COMSCORE;
#  if (comScore) {
#  comScore.beacon({ c1: 2, c2: 6402952, c3: '', c4: '', c5: '', c6: '', c15: '' });
#  }
#  };
#
#  var uc = window.encodeURIComponent, timeStamp = (new Date()).getTime();
#  var fireExternalTracking = function(et) {
#  if (typeof et.trackPageChromeInit === 'function') {
#  et.trackPageChromeInit(providers);
#  } else {
#  // Default treatment if not read from LIX.
#  et.setTreatment('enabled_1.0');
#  et.trackWithComScoreForChromeInit();
#  if (!isNielsenDisabled) {
#  var img = new Image(1, 1);
#  img.onerror = img.onload = function () {
#  img.onerror = img.onload = null;
#  };
#  img.src = [
#  "//secure-gl.imrworldwide.com/cgi-bin/m?ci=au-linkedin&cc=1&si=",
#  uc(window.location.href),
#  "&rp=", uc(document.referrer), "&ts=compact&rnd=", timeStamp
#  ].join('');
#  }
#  }
#  };
#  var track = function() {
#  var et;
#  if (_e) {
#  fireExternalTracking(_e);
#  } else if (_r && typeof _r.ensure === 'function') {
#  try {
#  _r.ensure(['externalTracking'], function (require) {
#  try {
#  et = require('externalTracking');
#  fireExternalTracking(et);
#  } catch (e) {
#  fireComscore();
#  }
#  });
#  } catch (e) {
#  fireComscore();
#  }
#  } else if (_r && _r._is_li) {
#  try {
#  et = require('externalTracking');
#  fireExternalTracking(et);
#  } catch (e) {
#  fireComscore();
#  }
#  } else {
#  fireComscore();
#  }
#  };
#  window.addEventListener('load', track);
#  }(window.externalTracking, window.require));
#     </script>
#     <noscript>
#      <img alt="" height="0" src="https://sb.scorecardresearch.com/b?c1=2&amp;c2=6402952&amp;c3=&amp;c4=&amp;c5=&amp;c6=&amp;c15=&amp;cv=1.3&amp;cj=1" style="display:none" width="0"/>
#     </noscript>
#     <script type="text/javascript">
#      (function(d) {
#  function go() {
#  var a = d.createElement('iframe');
#  a.style.display = 'none';
#  a.setAttribute('sandbox', 'allow-scripts allow-same-origin');
#  a.src = '//radar.cedexis.com/1/11326/radar.html';
#  if (d.body) {
#  d.body.appendChild(a);
#  }
#  }
#
#  if (window.addEventListener) {
#  window.addEventListener('load', go, false);
#  } else if (window.addEvent) {
#  window.addEvent('onload', go);
#  }
#  }(document));
#     </script>
#    </meta>
#   </div>
#  </body>
# </html>

# %%
soup.find_all('meta') #finds all text within web page with the meta tag
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="origin" name="referrer"/>,
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>,
#  <meta content="e7ccddc3-af83-4e0f-927f-ff1c5a142da7" name="pageImpressionID"/>,
#  <meta content="chrome" name="appName"/>,
#  <meta content="d_jobs_job_detail_premium_guest" name="pageKey"/>,
#  <meta content="coEaecmRVRXgN0zzKSsAAA==" name="treeID"/>,
#  <meta content="//www.linkedin.com/mob/tracking" name="globalTrackingUrl"/>,
#  <meta content="chrome" name="globalTrackingAppName"/>,
#  <meta content="webTracking" name="globalTrackingAppId"/>,
#  <meta content="https://static.licdn.com/scds/common/u/images/logos/linkedin/logo-in-win8-tile-144_v1.png" name="msapplication-TileImage">
#  <meta content="#0077B5" name="msapplication-TileColor">
#  <meta content="LinkedIn" name="application-name">
#  <meta content="https://static.licdn.com/scds/concat/common/js?v=0.1.576" name="RemoteNavJSContentBaseURL">
#  <script src="https://static.licdn.com:443/scds/common/u/lib/fizzy/fz-1.3.8-min.js" type="text/javascript"></script><script type="text/javascript">fs.config({"failureRedirect":"http://www.linkedin.com/","uniEscape":true,"xhrHeaders":{"X-FS-Origin-Request":"/jobs/view/791327763/","X-FS-Page-Id":""}});</script><script src="https://static.licdn.com/scds/concat/common/js?h=7vr4nuab43rzvy2pgq7yvvxjk-9qa4rfxekcw3lt2c06h7p0kmf" type="text/javascript"></script>
#  <link href="https://static.licdn.com/scds/concat/common/css?h=a4kjc5uqttio53azw54aex6s3-as8kt5bqspxc01tl9cizqa37j" rel="stylesheet" type="text/css"/>
#  <script></script>
#  <!--[if IE 8]><script src="https://static.licdn.com/scds/common/u/lib/polyfill/1.0.2/ie8-polyfill.min.js"></script><![endif]-->
#  <!--[if IE 9]><script src="https://static.licdn.com/scds/common/u/lib/polyfill/1.0.2/ie9-polyfill.min.js"></script><![endif]-->
#  <meta content="https://static.licdn.com/scds/concat/common/js?h=2jds9coeh4w78ed9wblscv68v-ebbt2vixcc5qz0otts5io08xv" name="lnkd-track-json-lib"/>
#  <meta content="https://static.licdn.com/scds/concat/common/js?h=ebbt2vixcc5qz0otts5io08xv" name="lnkd-track-lib"/>
#  <meta content="/lite/ua/error?csrfToken=ajax%3A2291069490470548862" name="lnkd-track-error"/>
#  <meta content="jobs-frontend" id="appHost" name="appHost"/>
#  <meta content="1.0.1605" id="appVersion" name="appVersion"/>
#  <meta content="i001" id="appInstance" name="appInstance"/>
#  <script src="https://static.licdn.com/scds/concat/common/js?h=e2lgukqldpqool72t8g7tysag-3nuvxgwg15rbghxm1gpzfbya2-1nm61x5u7981e88m10hpaekkm-mv3v66b8q0h1hvgvd3yfjv5f-14k913qahq3mh0ac0lh0twk9v" type="text/javascript"></script>
#  <script src="https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.1605/f/%2Fjobs-frontend%2Fdust%2Fdev%2Flinkedin-dust.js"></script>
#  <link href="https://www.linkedin.com/jobs/view/data-scientist-at-electronic-arts-ea-791327763" rel="canonical">
#  <link href="//static.licdn.com" rel="preconnect">
#  <link href="//media.licdn.com" rel="preconnect">
#  <link href="//platform.linkedin.com" rel="preconnect"/>
#  <meta content="https://www.linkedin.com/jobs/view/data-scientist-at-electronic-arts-ea-791327763" property="og:url"/>
#  <meta content="app-id=886051313, app-argument=lijobseeker://jobPosting/791327763?smartbanner=1, affiliate-data=ct=smart_banner&amp;pt=10746" property="apple-itunes-app"/>
#  <meta content="Data Scientist, EA Customer Experience#WeAreEA and we exist to inspire the world to play. EA values creativity, pioneering, passion, determination, learning, and teamwork. We mean things like acting with curiosity, speaking up with original ideas, and committing to each other as one team.We’re looking for all the best kinds of people to make great experiences for our players. The best people want a job that inspires them, while giving them room to enjoy their lives. And we want to give them that. We celebrate diversity and inclusion by creating a place where you can come to work and be yourself.You’re a Data Scientist.You Understand That You Have 2 Basic JobsYou know how to pull all types of data from any source, be it Facebook posts, call center chats, video likes or survey results.Help our studios understand what problems players have with their games and provide insights that help optimize our call center. Both pursue the ultimate goal of providing the World’s Best Service for the World’s Best Games.You use all resources available to you to help solve a problem, be it a new algorithm, programming language or the person sitting next to you.You’re a programmer/statistician/NLP expert who is fanatic about games and Customer Experiences.You’re also a genuinely nice person who brings positive energy to an office. You’re approachable and take the time to listen so that you understand someone else’s view.This role is part of EA’s Customer Experience organization. The Customer Experience organization strives to make EA known for taking care of its players. We’re players taking care of players and people talking to people – whenever, wherever, and however they need us.We’re the Data Science team, part of the larger Customer Experience Insights team.We are surrounded by Production, BI, SEO and Market Research analysts. We’re the people who use advanced statistics and modeling to help solve business problems. We surface player problems through our text analytics offerings. We write a lot of code and talk to stakeholders from all teams and all levels. We are great team mates and trusted advisors, who provide insights to facilitate decisions and create models that change experiences.A typical day in the life of a Data Scientist:Come into the office and catch up with your team mates about last night’s gaming session or the hottest show on TV (no spoilers until 24hrs have passed – after that: anything is fair game!)Check on last night’s Jenkins script and add some code to a project you’re working onTalk to one of your coworkers on the Call Center side about how to match the right advisor to the right player – this could be your next big projectTake some time back at your desk to write up any notes and make a project plan proposalAttend a JIRA prioritization meeting to update work that’s in flight and plan for work to comeGrab coffee and read up on any stats blogs or tech news you’re subscribed toCheck out the model you deployed into production last month to see if it’s time to re-trainPull the latest changes on an NLP model you’re collaborating on from Stash and tinker with the parameters, then chat with your peer about the results of the tweaks and make plans for what to change nextSpend a couple of hours heads down/headphones on getting series with an analysis.Finish the day looking over any code you wrote today, knit any Markdowns and make sure your documentation is up to snuff.So how do Data Scientists make great experiences for players? They:Tell stories with data and interpret results for their stakeholdersPrioritize problems to solve based on the impact to the player experience while keeping overall organizational goals in mindHave a basic understanding of EA’s games and find time to play whenever they canDisplay confidence in communicating with senior management, or any audience, to ensure what they say is heard and understoodIdentify and lead collaborative efforts both inside and outside of their team; working wit ...
#  <meta content="noarchive" name="robots"/>
#  <meta content="https://www.linkedin.com/jobs/view/791327763" property="lnkd-page-id"/>
#  <meta content="https://media.licdn.com/dms/image/C4D0BAQGOlVviOdDcoQ/company-logo_100_100/0?e=1545264000&amp;v=beta&amp;t=EGrgqnMi8_kYj6bn77ayn0yMarbm-COV5caOuVMnwac" property="og:image"/>
#  <meta content="Data Scientist" property="og:title"/>
#  <meta content="LinkedIn" property="og:site_name"/>
#  <meta content="yes" name="apple-mobile-web-app-capable"/>
#  <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
#  <meta content="#0077B5" name="theme-color"/>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <meta content="play streaming enabled" name="play-streaming"/>
#  <link href="https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.1605/f/%2Fjobs-frontend%2Fconcat%2Fneo-guest-style-dependencies_en_US.css" rel="stylesheet"/>
#  </link></link></link></meta></meta></meta></meta>,
#  <meta content="#0077B5" name="msapplication-TileColor">
#  <meta content="LinkedIn" name="application-name">
#  <meta content="https://static.licdn.com/scds/concat/common/js?v=0.1.576" name="RemoteNavJSContentBaseURL">
#  <script src="https://static.licdn.com:443/scds/common/u/lib/fizzy/fz-1.3.8-min.js" type="text/javascript"></script><script type="text/javascript">fs.config({"failureRedirect":"http://www.linkedin.com/","uniEscape":true,"xhrHeaders":{"X-FS-Origin-Request":"/jobs/view/791327763/","X-FS-Page-Id":""}});</script><script src="https://static.licdn.com/scds/concat/common/js?h=7vr4nuab43rzvy2pgq7yvvxjk-9qa4rfxekcw3lt2c06h7p0kmf" type="text/javascript"></script>
#  <link href="https://static.licdn.com/scds/concat/common/css?h=a4kjc5uqttio53azw54aex6s3-as8kt5bqspxc01tl9cizqa37j" rel="stylesheet" type="text/css"/>
#  <script></script>
#  <!--[if IE 8]><script src="https://static.licdn.com/scds/common/u/lib/polyfill/1.0.2/ie8-polyfill.min.js"></script><![endif]-->
#  <!--[if IE 9]><script src="https://static.licdn.com/scds/common/u/lib/polyfill/1.0.2/ie9-polyfill.min.js"></script><![endif]-->
#  <meta content="https://static.licdn.com/scds/concat/common/js?h=2jds9coeh4w78ed9wblscv68v-ebbt2vixcc5qz0otts5io08xv" name="lnkd-track-json-lib"/>
#  <meta content="https://static.licdn.com/scds/concat/common/js?h=ebbt2vixcc5qz0otts5io08xv" name="lnkd-track-lib"/>
#  <meta content="/lite/ua/error?csrfToken=ajax%3A2291069490470548862" name="lnkd-track-error"/>
#  <meta content="jobs-frontend" id="appHost" name="appHost"/>
#  <meta content="1.0.1605" id="appVersion" name="appVersion"/>
#  <meta content="i001" id="appInstance" name="appInstance"/>
#  <script src="https://static.licdn.com/scds/concat/common/js?h=e2lgukqldpqool72t8g7tysag-3nuvxgwg15rbghxm1gpzfbya2-1nm61x5u7981e88m10hpaekkm-mv3v66b8q0h1hvgvd3yfjv5f-14k913qahq3mh0ac0lh0twk9v" type="text/javascript"></script>
#  <script src="https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.1605/f/%2Fjobs-frontend%2Fdust%2Fdev%2Flinkedin-dust.js"></script>
#  <link href="https://www.linkedin.com/jobs/view/data-scientist-at-electronic-arts-ea-791327763" rel="canonical">
#  <link href="//static.licdn.com" rel="preconnect">
#  <link href="//media.licdn.com" rel="preconnect">
#  <link href="//platform.linkedin.com" rel="preconnect"/>
#  <meta content="https://www.linkedin.com/jobs/view/data-scientist-at-electronic-arts-ea-791327763" property="og:url"/>
#  <meta content="app-id=886051313, app-argument=lijobseeker://jobPosting/791327763?smartbanner=1, affiliate-data=ct=smart_banner&amp;pt=10746" property="apple-itunes-app"/>
#  <meta content="Data Scientist, EA Customer Experience#WeAreEA and we exist to inspire the world to play. EA values creativity, pioneering, passion, determination, learning, and teamwork. We mean things like acting with curiosity, speaking up with original ideas, and committing to each other as one team.We’re looking for all the best kinds of people to make great experiences for our players. The best people want a job that inspires them, while giving them room to enjoy their lives. And we want to give them that. We celebrate diversity and inclusion by creating a place where you can come to work and be yourself.You’re a Data Scientist.You Understand That You Have 2 Basic JobsYou know how to pull all types of data from any source, be it Facebook posts, call center chats, video likes or survey results.Help our studios understand what problems players have with their games and provide insights that help optimize our call center. Both pursue the ultimate goal of providing the World’s Best Service for the World’s Best Games.You use all resources available to you to help solve a problem, be it a new algorithm, programming language or the person sitting next to you.You’re a programmer/statistician/NLP expert who is fanatic about games and Customer Experiences.You’re also a genuinely nice person who brings positive energy to an office. You’re approachable and take the time to listen so that you understand someone else’s view.This role is part of EA’s Customer Experience organization. The Customer Experience organization strives to make EA known for taking care of its players. We’re players taking care of players and people talking to people – whenever, wherever, and however they need us.We’re the Data Science team, part of the larger Customer Experience Insights team.We are surrounded by Production, BI, SEO and Market Research analysts. We’re the people who use advanced statistics and modeling to help solve business problems. We surface player problems through our text analytics offerings. We write a lot of code and talk to stakeholders from all teams and all levels. We are great team mates and trusted advisors, who provide insights to facilitate decisions and create models that change experiences.A typical day in the life of a Data Scientist:Come into the office and catch up with your team mates about last night’s gaming session or the hottest show on TV (no spoilers until 24hrs have passed – after that: anything is fair game!)Check on last night’s Jenkins script and add some code to a project you’re working onTalk to one of your coworkers on the Call Center side about how to match the right advisor to the right player – this could be your next big projectTake some time back at your desk to write up any notes and make a project plan proposalAttend a JIRA prioritization meeting to update work that’s in flight and plan for work to comeGrab coffee and read up on any stats blogs or tech news you’re subscribed toCheck out the model you deployed into production last month to see if it’s time to re-trainPull the latest changes on an NLP model you’re collaborating on from Stash and tinker with the parameters, then chat with your peer about the results of the tweaks and make plans for what to change nextSpend a couple of hours heads down/headphones on getting series with an analysis.Finish the day looking over any code you wrote today, knit any Markdowns and make sure your documentation is up to snuff.So how do Data Scientists make great experiences for players? They:Tell stories with data and interpret results for their stakeholdersPrioritize problems to solve based on the impact to the player experience while keeping overall organizational goals in mindHave a basic understanding of EA’s games and find time to play whenever they canDisplay confidence in communicating with senior management, or any audience, to ensure what they say is heard and understoodIdentify and lead collaborative efforts both inside and outside of their team; working wit ...
#  <meta content="noarchive" name="robots"/>
#  <meta content="https://www.linkedin.com/jobs/view/791327763" property="lnkd-page-id"/>
#  <meta content="https://media.licdn.com/dms/image/C4D0BAQGOlVviOdDcoQ/company-logo_100_100/0?e=1545264000&amp;v=beta&amp;t=EGrgqnMi8_kYj6bn77ayn0yMarbm-COV5caOuVMnwac" property="og:image"/>
#  <meta content="Data Scientist" property="og:title"/>
#  <meta content="LinkedIn" property="og:site_name"/>
#  <meta content="yes" name="apple-mobile-web-app-capable"/>
#  <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
#  <meta content="#0077B5" name="theme-color"/>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <meta content="play streaming enabled" name="play-streaming"/>
#  <link href="https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.1605/f/%2Fjobs-frontend%2Fconcat%2Fneo-guest-style-dependencies_en_US.css" rel="stylesheet"/>
#  </link></link></link></meta></meta></meta>,
#  <meta content="LinkedIn" name="application-name">
#  <meta content="https://static.licdn.com/scds/concat/common/js?v=0.1.576" name="RemoteNavJSContentBaseURL">
#  <script src="https://static.licdn.com:443/scds/common/u/lib/fizzy/fz-1.3.8-min.js" type="text/javascript"></script><script type="text/javascript">fs.config({"failureRedirect":"http://www.linkedin.com/","uniEscape":true,"xhrHeaders":{"X-FS-Origin-Request":"/jobs/view/791327763/","X-FS-Page-Id":""}});</script><script src="https://static.licdn.com/scds/concat/common/js?h=7vr4nuab43rzvy2pgq7yvvxjk-9qa4rfxekcw3lt2c06h7p0kmf" type="text/javascript"></script>
#  <link href="https://static.licdn.com/scds/concat/common/css?h=a4kjc5uqttio53azw54aex6s3-as8kt5bqspxc01tl9cizqa37j" rel="stylesheet" type="text/css"/>
#  <script></script>
#  <!--[if IE 8]><script src="https://static.licdn.com/scds/common/u/lib/polyfill/1.0.2/ie8-polyfill.min.js"></script><![endif]-->
#  <!--[if IE 9]><script src="https://static.licdn.com/scds/common/u/lib/polyfill/1.0.2/ie9-polyfill.min.js"></script><![endif]-->
#  <meta content="https://static.licdn.com/scds/concat/common/js?h=2jds9coeh4w78ed9wblscv68v-ebbt2vixcc5qz0otts5io08xv" name="lnkd-track-json-lib"/>
#  <meta content="https://static.licdn.com/scds/concat/common/js?h=ebbt2vixcc5qz0otts5io08xv" name="lnkd-track-lib"/>
#  <meta content="/lite/ua/error?csrfToken=ajax%3A2291069490470548862" name="lnkd-track-error"/>
#  <meta content="jobs-frontend" id="appHost" name="appHost"/>
#  <meta content="1.0.1605" id="appVersion" name="appVersion"/>
#  <meta content="i001" id="appInstance" name="appInstance"/>
#  <script src="https://static.licdn.com/scds/concat/common/js?h=e2lgukqldpqool72t8g7tysag-3nuvxgwg15rbghxm1gpzfbya2-1nm61x5u7981e88m10hpaekkm-mv3v66b8q0h1hvgvd3yfjv5f-14k913qahq3mh0ac0lh0twk9v" type="text/javascript"></script>
#  <script src="https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.1605/f/%2Fjobs-frontend%2Fdust%2Fdev%2Flinkedin-dust.js"></script>
#  <link href="https://www.linkedin.com/jobs/view/data-scientist-at-electronic-arts-ea-791327763" rel="canonical">
#  <link href="//static.licdn.com" rel="preconnect">
#  <link href="//media.licdn.com" rel="preconnect">
#  <link href="//platform.linkedin.com" rel="preconnect"/>
#  <meta content="https://www.linkedin.com/jobs/view/data-scientist-at-electronic-arts-ea-791327763" property="og:url"/>
#  <meta content="app-id=886051313, app-argument=lijobseeker://jobPosting/791327763?smartbanner=1, affiliate-data=ct=smart_banner&amp;pt=10746" property="apple-itunes-app"/>
#  <meta content="Data Scientist, EA Customer Experience#WeAreEA and we exist to inspire the world to play. EA values creativity, pioneering, passion, determination, learning, and teamwork. We mean things like acting with curiosity, speaking up with original ideas, and committing to each other as one team.We’re looking for all the best kinds of people to make great experiences for our players. The best people want a job that inspires them, while giving them room to enjoy their lives. And we want to give them that. We celebrate diversity and inclusion by creating a place where you can come to work and be yourself.You’re a Data Scientist.You Understand That You Have 2 Basic JobsYou know how to pull all types of data from any source, be it Facebook posts, call center chats, video likes or survey results.Help our studios understand what problems players have with their games and provide insights that help optimize our call center. Both pursue the ultimate goal of providing the World’s Best Service for the World’s Best Games.You use all resources available to you to help solve a problem, be it a new algorithm, programming language or the person sitting next to you.You’re a programmer/statistician/NLP expert who is fanatic about games and Customer Experiences.You’re also a genuinely nice person who brings positive energy to an office. You’re approachable and take the time to listen so that you understand someone else’s view.This role is part of EA’s Customer Experience organization. The Customer Experience organization strives to make EA known for taking care of its players. We’re players taking care of players and people talking to people – whenever, wherever, and however they need us.We’re the Data Science team, part of the larger Customer Experience Insights team.We are surrounded by Production, BI, SEO and Market Research analysts. We’re the people who use advanced statistics and modeling to help solve business problems. We surface player problems through our text analytics offerings. We write a lot of code and talk to stakeholders from all teams and all levels. We are great team mates and trusted advisors, who provide insights to facilitate decisions and create models that change experiences.A typical day in the life of a Data Scientist:Come into the office and catch up with your team mates about last night’s gaming session or the hottest show on TV (no spoilers until 24hrs have passed – after that: anything is fair game!)Check on last night’s Jenkins script and add some code to a project you’re working onTalk to one of your coworkers on the Call Center side about how to match the right advisor to the right player – this could be your next big projectTake some time back at your desk to write up any notes and make a project plan proposalAttend a JIRA prioritization meeting to update work that’s in flight and plan for work to comeGrab coffee and read up on any stats blogs or tech news you’re subscribed toCheck out the model you deployed into production last month to see if it’s time to re-trainPull the latest changes on an NLP model you’re collaborating on from Stash and tinker with the parameters, then chat with your peer about the results of the tweaks and make plans for what to change nextSpend a couple of hours heads down/headphones on getting series with an analysis.Finish the day looking over any code you wrote today, knit any Markdowns and make sure your documentation is up to snuff.So how do Data Scientists make great experiences for players? They:Tell stories with data and interpret results for their stakeholdersPrioritize problems to solve based on the impact to the player experience while keeping overall organizational goals in mindHave a basic understanding of EA’s games and find time to play whenever they canDisplay confidence in communicating with senior management, or any audience, to ensure what they say is heard and understoodIdentify and lead collaborative efforts both inside and outside of their team; working wit ...
#  <meta content="noarchive" name="robots"/>
#  <meta content="https://www.linkedin.com/jobs/view/791327763" property="lnkd-page-id"/>
#  <meta content="https://media.licdn.com/dms/image/C4D0BAQGOlVviOdDcoQ/company-logo_100_100/0?e=1545264000&amp;v=beta&amp;t=EGrgqnMi8_kYj6bn77ayn0yMarbm-COV5caOuVMnwac" property="og:image"/>
#  <meta content="Data Scientist" property="og:title"/>
#  <meta content="LinkedIn" property="og:site_name"/>
#  <meta content="yes" name="apple-mobile-web-app-capable"/>
#  <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
#  <meta content="#0077B5" name="theme-color"/>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <meta content="play streaming enabled" name="play-streaming"/>
#  <link href="https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.1605/f/%2Fjobs-frontend%2Fconcat%2Fneo-guest-style-dependencies_en_US.css" rel="stylesheet"/>
#  </link></link></link></meta></meta>,
#  <meta content="https://static.licdn.com/scds/concat/common/js?v=0.1.576" name="RemoteNavJSContentBaseURL">
#  <script src="https://static.licdn.com:443/scds/common/u/lib/fizzy/fz-1.3.8-min.js" type="text/javascript"></script><script type="text/javascript">fs.config({"failureRedirect":"http://www.linkedin.com/","uniEscape":true,"xhrHeaders":{"X-FS-Origin-Request":"/jobs/view/791327763/","X-FS-Page-Id":""}});</script><script src="https://static.licdn.com/scds/concat/common/js?h=7vr4nuab43rzvy2pgq7yvvxjk-9qa4rfxekcw3lt2c06h7p0kmf" type="text/javascript"></script>
#  <link href="https://static.licdn.com/scds/concat/common/css?h=a4kjc5uqttio53azw54aex6s3-as8kt5bqspxc01tl9cizqa37j" rel="stylesheet" type="text/css"/>
#  <script></script>
#  <!--[if IE 8]><script src="https://static.licdn.com/scds/common/u/lib/polyfill/1.0.2/ie8-polyfill.min.js"></script><![endif]-->
#  <!--[if IE 9]><script src="https://static.licdn.com/scds/common/u/lib/polyfill/1.0.2/ie9-polyfill.min.js"></script><![endif]-->
#  <meta content="https://static.licdn.com/scds/concat/common/js?h=2jds9coeh4w78ed9wblscv68v-ebbt2vixcc5qz0otts5io08xv" name="lnkd-track-json-lib"/>
#  <meta content="https://static.licdn.com/scds/concat/common/js?h=ebbt2vixcc5qz0otts5io08xv" name="lnkd-track-lib"/>
#  <meta content="/lite/ua/error?csrfToken=ajax%3A2291069490470548862" name="lnkd-track-error"/>
#  <meta content="jobs-frontend" id="appHost" name="appHost"/>
#  <meta content="1.0.1605" id="appVersion" name="appVersion"/>
#  <meta content="i001" id="appInstance" name="appInstance"/>
#  <script src="https://static.licdn.com/scds/concat/common/js?h=e2lgukqldpqool72t8g7tysag-3nuvxgwg15rbghxm1gpzfbya2-1nm61x5u7981e88m10hpaekkm-mv3v66b8q0h1hvgvd3yfjv5f-14k913qahq3mh0ac0lh0twk9v" type="text/javascript"></script>
#  <script src="https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.1605/f/%2Fjobs-frontend%2Fdust%2Fdev%2Flinkedin-dust.js"></script>
#  <link href="https://www.linkedin.com/jobs/view/data-scientist-at-electronic-arts-ea-791327763" rel="canonical">
#  <link href="//static.licdn.com" rel="preconnect">
#  <link href="//media.licdn.com" rel="preconnect">
#  <link href="//platform.linkedin.com" rel="preconnect"/>
#  <meta content="https://www.linkedin.com/jobs/view/data-scientist-at-electronic-arts-ea-791327763" property="og:url"/>
#  <meta content="app-id=886051313, app-argument=lijobseeker://jobPosting/791327763?smartbanner=1, affiliate-data=ct=smart_banner&amp;pt=10746" property="apple-itunes-app"/>
#  <meta content="Data Scientist, EA Customer Experience#WeAreEA and we exist to inspire the world to play. EA values creativity, pioneering, passion, determination, learning, and teamwork. We mean things like acting with curiosity, speaking up with original ideas, and committing to each other as one team.We’re looking for all the best kinds of people to make great experiences for our players. The best people want a job that inspires them, while giving them room to enjoy their lives. And we want to give them that. We celebrate diversity and inclusion by creating a place where you can come to work and be yourself.You’re a Data Scientist.You Understand That You Have 2 Basic JobsYou know how to pull all types of data from any source, be it Facebook posts, call center chats, video likes or survey results.Help our studios understand what problems players have with their games and provide insights that help optimize our call center. Both pursue the ultimate goal of providing the World’s Best Service for the World’s Best Games.You use all resources available to you to help solve a problem, be it a new algorithm, programming language or the person sitting next to you.You’re a programmer/statistician/NLP expert who is fanatic about games and Customer Experiences.You’re also a genuinely nice person who brings positive energy to an office. You’re approachable and take the time to listen so that you understand someone else’s view.This role is part of EA’s Customer Experience organization. The Customer Experience organization strives to make EA known for taking care of its players. We’re players taking care of players and people talking to people – whenever, wherever, and however they need us.We’re the Data Science team, part of the larger Customer Experience Insights team.We are surrounded by Production, BI, SEO and Market Research analysts. We’re the people who use advanced statistics and modeling to help solve business problems. We surface player problems through our text analytics offerings. We write a lot of code and talk to stakeholders from all teams and all levels. We are great team mates and trusted advisors, who provide insights to facilitate decisions and create models that change experiences.A typical day in the life of a Data Scientist:Come into the office and catch up with your team mates about last night’s gaming session or the hottest show on TV (no spoilers until 24hrs have passed – after that: anything is fair game!)Check on last night’s Jenkins script and add some code to a project you’re working onTalk to one of your coworkers on the Call Center side about how to match the right advisor to the right player – this could be your next big projectTake some time back at your desk to write up any notes and make a project plan proposalAttend a JIRA prioritization meeting to update work that’s in flight and plan for work to comeGrab coffee and read up on any stats blogs or tech news you’re subscribed toCheck out the model you deployed into production last month to see if it’s time to re-trainPull the latest changes on an NLP model you’re collaborating on from Stash and tinker with the parameters, then chat with your peer about the results of the tweaks and make plans for what to change nextSpend a couple of hours heads down/headphones on getting series with an analysis.Finish the day looking over any code you wrote today, knit any Markdowns and make sure your documentation is up to snuff.So how do Data Scientists make great experiences for players? They:Tell stories with data and interpret results for their stakeholdersPrioritize problems to solve based on the impact to the player experience while keeping overall organizational goals in mindHave a basic understanding of EA’s games and find time to play whenever they canDisplay confidence in communicating with senior management, or any audience, to ensure what they say is heard and understoodIdentify and lead collaborative efforts both inside and outside of their team; working wit ...
#  <meta content="noarchive" name="robots"/>
#  <meta content="https://www.linkedin.com/jobs/view/791327763" property="lnkd-page-id"/>
#  <meta content="https://media.licdn.com/dms/image/C4D0BAQGOlVviOdDcoQ/company-logo_100_100/0?e=1545264000&amp;v=beta&amp;t=EGrgqnMi8_kYj6bn77ayn0yMarbm-COV5caOuVMnwac" property="og:image"/>
#  <meta content="Data Scientist" property="og:title"/>
#  <meta content="LinkedIn" property="og:site_name"/>
#  <meta content="yes" name="apple-mobile-web-app-capable"/>
#  <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
#  <meta content="#0077B5" name="theme-color"/>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <meta content="play streaming enabled" name="play-streaming"/>
#  <link href="https://static.licdn.com/sc/p/com.linkedin.jobs-frontend%3Ajobs-frontend-static-content%2B1.0.1605/f/%2Fjobs-frontend%2Fconcat%2Fneo-guest-style-dependencies_en_US.css" rel="stylesheet"/>
#  </link></link></link></meta>,
#  <meta content="https://static.licdn.com/scds/concat/common/js?h=2jds9coeh4w78ed9wblscv68v-ebbt2vixcc5qz0otts5io08xv" name="lnkd-track-json-lib"/>,
#  <meta content="https://static.licdn.com/scds/concat/common/js?h=ebbt2vixcc5qz0otts5io08xv" name="lnkd-track-lib"/>,
#  <meta content="/lite/ua/error?csrfToken=ajax%3A2291069490470548862" name="lnkd-track-error"/>,
#  <meta content="jobs-frontend" id="appHost" name="appHost"/>,
#  <meta content="1.0.1605" id="appVersion" name="appVersion"/>,
#  <meta content="i001" id="appInstance" name="appInstance"/>,
#  <meta content="https://www.linkedin.com/jobs/view/data-scientist-at-electronic-arts-ea-791327763" property="og:url"/>,
#  <meta content="app-id=886051313, app-argument=lijobseeker://jobPosting/791327763?smartbanner=1, affiliate-data=ct=smart_banner&amp;pt=10746" property="apple-itunes-app"/>,
#  <meta content="Data Scientist, EA Customer Experience#WeAreEA and we exist to inspire the world to play. EA values creativity, pioneering, passion, determination, learning, and teamwork. We mean things like acting with curiosity, speaking up with original ideas, and committing to each other as one team.We’re looking for all the best kinds of people to make great experiences for our players. The best people want a job that inspires them, while giving them room to enjoy their lives. And we want to give them that. We celebrate diversity and inclusion by creating a place where you can come to work and be yourself.You’re a Data Scientist.You Understand That You Have 2 Basic JobsYou know how to pull all types of data from any source, be it Facebook posts, call center chats, video likes or survey results.Help our studios understand what problems players have with their games and provide insights that help optimize our call center. Both pursue the ultimate goal of providing the World’s Best Service for the World’s Best Games.You use all resources available to you to help solve a problem, be it a new algorithm, programming language or the person sitting next to you.You’re a programmer/statistician/NLP expert who is fanatic about games and Customer Experiences.You’re also a genuinely nice person who brings positive energy to an office. You’re approachable and take the time to listen so that you understand someone else’s view.This role is part of EA’s Customer Experience organization. The Customer Experience organization strives to make EA known for taking care of its players. We’re players taking care of players and people talking to people – whenever, wherever, and however they need us.We’re the Data Science team, part of the larger Customer Experience Insights team.We are surrounded by Production, BI, SEO and Market Research analysts. We’re the people who use advanced statistics and modeling to help solve business problems. We surface player problems through our text analytics offerings. We write a lot of code and talk to stakeholders from all teams and all levels. We are great team mates and trusted advisors, who provide insights to facilitate decisions and create models that change experiences.A typical day in the life of a Data Scientist:Come into the office and catch up with your team mates about last night’s gaming session or the hottest show on TV (no spoilers until 24hrs have passed – after that: anything is fair game!)Check on last night’s Jenkins script and add some code to a project you’re working onTalk to one of your coworkers on the Call Center side about how to match the right advisor to the right player – this could be your next big projectTake some time back at your desk to write up any notes and make a project plan proposalAttend a JIRA prioritization meeting to update work that’s in flight and plan for work to comeGrab coffee and read up on any stats blogs or tech news you’re subscribed toCheck out the model you deployed into production last month to see if it’s time to re-trainPull the latest changes on an NLP model you’re collaborating on from Stash and tinker with the parameters, then chat with your peer about the results of the tweaks and make plans for what to change nextSpend a couple of hours heads down/headphones on getting series with an analysis.Finish the day looking over any code you wrote today, knit any Markdowns and make sure your documentation is up to snuff.So how do Data Scientists make great experiences for players? They:Tell stories with data and interpret results for their stakeholdersPrioritize problems to solve based on the impact to the player experience while keeping overall organizational goals in mindHave a basic understanding of EA’s games and find time to play whenever they canDisplay confidence in communicating with senior management, or any audience, to ensure what they say is heard and understoodIdentify and lead collaborative efforts both inside and outside of their team; working wit ...
#  <meta content="noarchive" name="robots"/>,
#  <meta content="https://www.linkedin.com/jobs/view/791327763" property="lnkd-page-id"/>,
#  <meta content="https://media.licdn.com/dms/image/C4D0BAQGOlVviOdDcoQ/company-logo_100_100/0?e=1545264000&amp;v=beta&amp;t=EGrgqnMi8_kYj6bn77ayn0yMarbm-COV5caOuVMnwac" property="og:image"/>,
#  <meta content="Data Scientist" property="og:title"/>,
#  <meta content="LinkedIn" property="og:site_name"/>,
#  <meta content="yes" name="apple-mobile-web-app-capable"/>,
#  <meta content="default" name="apple-mobile-web-app-status-bar-style"/>,
#  <meta content="#0077B5" name="theme-color"/>,
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>,
#  <meta content="play streaming enabled" name="play-streaming"/>,
#  <meta content="//platform.linkedin.com/js/px.js" name="detectAdBlock">
#  <script async="" defer="" src="https://static.licdn.com/scds/concat/common/js?h=69w33ou4umkyupw2uqgn7za7w"></script>
#  <script class="comscore-tracking">
#   (function(_e, _r) {
#   var isNielsenDisabled = true;
#   var providers = {
#   'COMSCORE': {
#   'treatment': 'control'
#   }
#   };
#   if (!isNielsenDisabled) {
#   providers['NIELSEN'] = {
#   'treatment': 'control'
#   };
#   }
#
#   var fireComscore = function() {
#   var comScore = window.COMSCORE;
#   if (comScore) {
#   comScore.beacon({ c1: 2, c2: 6402952, c3: '', c4: '', c5: '', c6: '', c15: '' });
#   }
#   };
#
#   var uc = window.encodeURIComponent, timeStamp = (new Date()).getTime();
#   var fireExternalTracking = function(et) {
#   if (typeof et.trackPageChromeInit === 'function') {
#   et.trackPageChromeInit(providers);
#   } else {
#   // Default treatment if not read from LIX.
#   et.setTreatment('enabled_1.0');
#   et.trackWithComScoreForChromeInit();
#   if (!isNielsenDisabled) {
#   var img = new Image(1, 1);
#   img.onerror = img.onload = function () {
#   img.onerror = img.onload = null;
#   };
#   img.src = [
#   "//secure-gl.imrworldwide.com/cgi-bin/m?ci=au-linkedin&cc=1&si=",
#   uc(window.location.href),
#   "&rp=", uc(document.referrer), "&ts=compact&rnd=", timeStamp
#   ].join('');
#   }
#   }
#   };
#   var track = function() {
#   var et;
#   if (_e) {
#   fireExternalTracking(_e);
#   } else if (_r && typeof _r.ensure === 'function') {
#   try {
#   _r.ensure(['externalTracking'], function (require) {
#   try {
#   et = require('externalTracking');
#   fireExternalTracking(et);
#   } catch (e) {
#   fireComscore();
#   }
#   });
#   } catch (e) {
#   fireComscore();
#   }
#   } else if (_r && _r._is_li) {
#   try {
#   et = require('externalTracking');
#   fireExternalTracking(et);
#   } catch (e) {
#   fireComscore();
#   }
#   } else {
#   fireComscore();
#   }
#   };
#   window.addEventListener('load', track);
#   }(window.externalTracking, window.require));
#  </script>
#  <noscript>
#  <img alt="" height="0" src="https://sb.scorecardresearch.com/b?c1=2&amp;c2=6402952&amp;c3=&amp;c4=&amp;c5=&amp;c6=&amp;c15=&amp;cv=1.3&amp;cj=1" style="display:none" width="0"/>
#  </noscript>
#  <script type="text/javascript">
#   (function(d) {
#   function go() {
#   var a = d.createElement('iframe');
#   a.style.display = 'none';
#   a.setAttribute('sandbox', 'allow-scripts allow-same-origin');
#   a.src = '//radar.cedexis.com/1/11326/radar.html';
#   if (d.body) {
#   d.body.appendChild(a);
#   }
#   }
#
#   if (window.addEventListener) {
#   window.addEventListener('load', go, false);
#   } else if (window.addEvent) {
#   window.addEvent('onload', go);
#   }
#   }(document));
#   </script>
#  </meta>]

# %%
len(soup.find_all('meta')) #calculates the number of tags with the meta tag
# Out:
# 34

# %%
text = soup.find_all('meta')[22] #stores the contents of the 22nd tag with the meta tag

# %%
text #shows the content of text
# Out:
# <meta content="Data Scientist, EA Customer Experience#WeAreEA and we exist to inspire the world to play. EA values creativity, pioneering, passion, determination, learning, and teamwork. We mean things like acting with curiosity, speaking up with original ideas, and committing to each other as one team.We’re looking for all the best kinds of people to make great experiences for our players. The best people want a job that inspires them, while giving them room to enjoy their lives. And we want to give them that. We celebrate diversity and inclusion by creating a place where you can come to work and be yourself.You’re a Data Scientist.You Understand That You Have 2 Basic JobsYou know how to pull all types of data from any source, be it Facebook posts, call center chats, video likes or survey results.Help our studios understand what problems players have with their games and provide insights that help optimize our call center. Both pursue the ultimate goal of providing the World’s Best Service for the World’s Best Games.You use all resources available to you to help solve a problem, be it a new algorithm, programming language or the person sitting next to you.You’re a programmer/statistician/NLP expert who is fanatic about games and Customer Experiences.You’re also a genuinely nice person who brings positive energy to an office. You’re approachable and take the time to listen so that you understand someone else’s view.This role is part of EA’s Customer Experience organization. The Customer Experience organization strives to make EA known for taking care of its players. We’re players taking care of players and people talking to people – whenever, wherever, and however they need us.We’re the Data Science team, part of the larger Customer Experience Insights team.We are surrounded by Production, BI, SEO and Market Research analysts. We’re the people who use advanced statistics and modeling to help solve business problems. We surface player problems through our text analytics offerings. We write a lot of code and talk to stakeholders from all teams and all levels. We are great team mates and trusted advisors, who provide insights to facilitate decisions and create models that change experiences.A typical day in the life of a Data Scientist:Come into the office and catch up with your team mates about last night’s gaming session or the hottest show on TV (no spoilers until 24hrs have passed – after that: anything is fair game!)Check on last night’s Jenkins script and add some code to a project you’re working onTalk to one of your coworkers on the Call Center side about how to match the right advisor to the right player – this could be your next big projectTake some time back at your desk to write up any notes and make a project plan proposalAttend a JIRA prioritization meeting to update work that’s in flight and plan for work to comeGrab coffee and read up on any stats blogs or tech news you’re subscribed toCheck out the model you deployed into production last month to see if it’s time to re-trainPull the latest changes on an NLP model you’re collaborating on from Stash and tinker with the parameters, then chat with your peer about the results of the tweaks and make plans for what to change nextSpend a couple of hours heads down/headphones on getting series with an analysis.Finish the day looking over any code you wrote today, knit any Markdowns and make sure your documentation is up to snuff.So how do Data Scientists make great experiences for players? They:Tell stories with data and interpret results for their stakeholdersPrioritize problems to solve based on the impact to the player experience while keeping overall organizational goals in mindHave a basic understanding of EA’s games and find time to play whenever they canDisplay confidence in communicating with senior management, or any audience, to ensure what they say is heard and understoodIdentify and lead collaborative efforts both inside and outside of their team; working with ...

# %%
my_text = soup.find('meta', property='og:description') #finds section of text with meta tag and property = 'og:description'

# %%
mega_text = my_text.get("content") #gets the content of that meta tag and stores it in mega_text

# %%
mega_text #shows content of mega_text
# Out:
# 'Data Scientist, EA Customer Experience#WeAreEA and we exist to inspire the world to play. EA values creativity, pioneering, passion, determination, learning, and teamwork. We mean things like acting with curiosity, speaking up with original ideas, and committing to each other as one team.We’re looking for all the best kinds of people to make great experiences for our players. The best people want a job that inspires them, while giving them room to enjoy their lives. And we want to give them that. We celebrate diversity and inclusion by creating a place where you can come to work and be yourself.You’re a Data Scientist.You Understand That You Have 2 Basic JobsYou know how to pull all types of data from any source, be it Facebook posts, call center chats, video likes or survey results.Help our studios understand what problems players have with their games and provide insights that help optimize our call center. Both pursue the ultimate goal of providing the World’s Best Service for the World’s Best Games.You use all resources available to you to help solve a problem, be it a new algorithm, programming language or the person sitting next to you.You’re a programmer/statistician/NLP expert who is fanatic about games and Customer Experiences.You’re also a genuinely nice person who brings positive energy to an office. You’re approachable and take the time to listen so that you understand someone else’s view.This role is part of EA’s Customer Experience organization. The Customer Experience organization strives to make EA known for taking care of its players. We’re players taking care of players and people talking to people – whenever, wherever, and however they need us.We’re the Data Science team, part of the larger Customer Experience Insights team.We are surrounded by Production, BI, SEO and Market Research analysts. We’re the people who use advanced statistics and modeling to help solve business problems. We surface player problems through our text analytics offerings. We write a lot of code and talk to stakeholders from all teams and all levels. We are great team mates and trusted advisors, who provide insights to facilitate decisions and create models that change experiences.A typical day in the life of a Data Scientist:Come into the office and catch up with your team mates about last night’s gaming session or the hottest show on TV (no spoilers until 24hrs have passed – after that: anything is fair game!)Check on last night’s Jenkins script and add some code to a project you’re working onTalk to one of your coworkers on the Call Center side about how to match the right advisor to the right player – this could be your next big projectTake some time back at your desk to write up any notes and make a project plan proposalAttend a JIRA prioritization meeting to update work that’s in flight and plan for work to comeGrab coffee and read up on any stats blogs or tech news you’re subscribed toCheck out the model you deployed into production last month to see if it’s time to re-trainPull the latest changes on an NLP model you’re collaborating on from Stash and tinker with the parameters, then chat with your peer about the results of the tweaks and make plans for what to change nextSpend a couple of hours heads down/headphones on getting series with an analysis.Finish the day looking over any code you wrote today, knit any Markdowns and make sure your documentation is up to snuff.So how do Data Scientists make great experiences for players? They:Tell stories with data and interpret results for their stakeholdersPrioritize problems to solve based on the impact to the player experience while keeping overall organizational goals in mindHave a basic understanding of EA’s games and find time to play whenever they canDisplay confidence in communicating with senior management, or any audience, to ensure what they say is heard and understoodIdentify and lead collaborative efforts both inside and outside of their team; working with key influence ...

# %% [markdown]
# ### Creating empty dictionary so that the word and its word count in main body of job description can be stored in this dictionary. The problem with this approach is that there are way too many duplilcates in dictionary plus there are numerous stop words with the highest word counts in job description that will need to be removed

# %%
word_dict = {} #initializes empty dictionary 
for i in mega_text.split(): #loops through each word in mega_text
    print(i, mega_text.count(i)) #prints word and its word count in mega_text 
    word_dict[i] = mega_text.count(i) #stores word and word count in word_dict dictionary
# Out:
# Data 7
# Scientist, 1
# EA 8
# Customer 6
# Experience#WeAreEA 1
# and 57
# we 15
# exist 1
# to 68
# inspire 2
# the 58
# world 3
# to 68
# play. 1
# EA 8
# values 1
# creativity, 1
# pioneering, 1
# passion, 1
# determination, 1
# learning, 1
# and 57
# teamwork. 1
# We 18
# mean 1
# things 3
# like 4
# acting 1
# with 16
# curiosity, 1
# speaking 1
# up 12
# with 16
# original 1
# ideas, 1
# and 57
# committing 1
# to 68
# each 4
# other 5
# as 24
# one 7
# team.We’re 1
# looking 3
# for 14
# all 11
# the 58
# best 3
# kinds 1
# of 27
# people 7
# to 68
# make 7
# great 4
# experiences 4
# for 14
# our 24
# players. 2
# The 3
# best 3
# people 7
# want 3
# a 492
# job 1
# that 14
# inspires 1
# them, 1
# while 2
# giving 1
# them 3
# room 1
# to 68
# enjoy 1
# their 6
# lives. 1
# And 2
# we 15
# want 3
# to 68
# give 1
# them 3
# that. 1
# We 18
# celebrate 1
# diversity 1
# and 57
# inclusion 1
# by 2
# creating 1
# a 492
# place 1
# where 2
# you 33
# can 8
# come 2
# to 68
# work 12
# and 57
# be 13
# yourself.You’re 1
# a 492
# Data 7
# Scientist.You 1
# Understand 1
# That 1
# You 14
# Have 2
# 2 2
# Basic 1
# JobsYou 1
# know 4
# how 8
# to 68
# pull 1
# all 11
# types 1
# of 27
# data 3
# from 5
# any 11
# source, 1
# be 13
# it 47
# Facebook 1
# posts, 1
# call 2
# center 2
# chats, 1
# video 1
# likes 1
# or 64
# survey 1
# results.Help 1
# our 24
# studios 1
# understand 6
# what 5
# problems 4
# players 7
# have 2
# with 16
# their 6
# games 6
# and 57
# provide 2
# insights 2
# that 14
# help 4
# optimize 1
# our 24
# call 2
# center. 1
# Both 1
# pursue 1
# the 58
# ultimate 1
# goal 2
# of 27
# providing 2
# the 58
# World’s 2
# Best 2
# Service 1
# for 14
# the 58
# World’s 2
# Best 2
# Games.You 1
# use 4
# all 11
# resources 1
# available 1
# to 68
# you 33
# to 68
# help 4
# solve 3
# a 492
# problem, 1
# be 13
# it 47
# a 492
# new 3
# algorithm, 1
# programming 1
# language 3
# or 64
# the 58
# person 4
# sitting 1
# next 4
# to 68
# you.You’re 1
# a 492
# programmer/statistician/NLP 1
# expert 3
# who 4
# is 30
# fanatic 2
# about 9
# games 6
# and 57
# Customer 6
# Experiences.You’re 1
# also 1
# a 492
# genuinely 1
# nice 1
# person 4
# who 4
# brings 1
# positive 1
# energy 1
# to 68
# an 117
# office. 1
# You’re 5
# approachable 1
# and 57
# take 6
# the 58
# time 4
# to 68
# listen 1
# so 23
# that 14
# you 33
# understand 6
# someone 1
# else’s 1
# view.This 1
# role 2
# is 30
# part 4
# of 27
# EA’s 2
# Customer 6
# Experience 7
# organization. 1
# The 3
# Customer 6
# Experience 7
# organization 3
# strives 1
# to 68
# make 7
# EA 8
# known 1
# for 14
# taking 2
# care 5
# of 27
# its 1
# players. 2
# We’re 4
# players 7
# taking 2
# care 5
# of 27
# players 7
# and 57
# people 7
# talking 1
# to 68
# people 7
# – 12
# whenever, 1
# wherever, 1
# and 57
# however 1
# they 4
# need 3
# us.We’re 1
# the 58
# Data 7
# Science 4
# team, 1
# part 4
# of 27
# the 58
# larger 1
# Customer 6
# Experience 7
# Insights 1
# team.We 2
# are 13
# surrounded 1
# by 2
# Production, 1
# BI, 1
# SEO 1
# and 57
# Market 1
# Research 2
# analysts. 1
# We’re 4
# the 58
# people 7
# who 4
# use 4
# advanced 1
# statistics 1
# and 57
# modeling 1
# to 68
# help 4
# solve 3
# business 1
# problems. 1
# We 18
# surface 1
# player 10
# problems 4
# through 1
# our 24
# text 1
# analytics 1
# offerings. 1
# We 18
# write 2
# a 492
# lot 2
# of 27
# code 5
# and 57
# talk 2
# to 68
# stakeholders 2
# from 5
# all 11
# teams 2
# and 57
# all 11
# levels. 1
# We 18
# are 13
# great 4
# team 10
# mates 2
# and 57
# trusted 1
# advisors, 1
# who 4
# provide 2
# insights 2
# to 68
# facilitate 1
# decisions 1
# and 57
# create 2
# models 2
# that 14
# change 5
# experiences.A 1
# typical 1
# day 4
# in 103
# the 58
# life 1
# of 27
# a 492
# Data 7
# Scientist:Come 1
# into 3
# the 58
# office 2
# and 57
# catch 1
# up 12
# with 16
# your 10
# team 10
# mates 2
# about 9
# last 5
# night’s 2
# gaming 1
# session 1
# or 64
# the 58
# hottest 1
# show 1
# on 68
# TV 1
# (no 1
# spoilers 1
# until 1
# 24hrs 1
# have 2
# passed 1
# – 12
# after 1
# that: 1
# anything 1
# is 30
# fair 1
# game!)Check 1
# on 68
# last 5
# night’s 2
# Jenkins 1
# script 1
# and 57
# add 1
# some 6
# code 5
# to 68
# a 492
# project 4
# you’re 5
# working 2
# onTalk 1
# to 68
# one 7
# of 27
# your 10
# coworkers 1
# on 68
# the 58
# Call 1
# Center 1
# side 4
# about 9
# how 8
# to 68
# match 2
# the 58
# right 5
# advisor 2
# to 68
# the 58
# right 5
# player 10
# – 12
# this 2
# could 1
# be 13
# your 10
# next 4
# big 2
# projectTake 1
# some 6
# time 4
# back 1
# at 92
# your 10
# desk 1
# to 68
# write 2
# up 12
# any 11
# notes 1
# and 57
# make 7
# a 492
# project 4
# plan 4
# proposalAttend 1
# a 492
# JIRA 2
# prioritization 1
# meeting 1
# to 68
# update 1
# work 12
# that’s 2
# in 103
# flight 1
# and 57
# plan 4
# for 14
# work 12
# to 68
# comeGrab 1
# coffee 1
# and 57
# read 2
# up 12
# on 68
# any 11
# stats 1
# blogs 1
# or 64
# tech 3
# news 1
# you’re 5
# subscribed 1
# toCheck 1
# out 11
# the 58
# model 5
# you 33
# deployed 1
# into 3
# production 1
# last 5
# month 2
# to 68
# see 1
# if 5
# it’s 1
# time 4
# to 68
# re-trainPull 1
# the 58
# latest 1
# changes 1
# on 68
# an 117
# NLP 4
# model 5
# you’re 5
# collaborating 1
# on 68
# from 5
# Stash 2
# and 57
# tinker 1
# with 16
# the 58
# parameters, 1
# then 1
# chat 3
# with 16
# your 10
# peer 1
# about 9
# the 58
# results 3
# of 27
# the 58
# tweaks 1
# and 57
# make 7
# plans 1
# for 14
# what 5
# to 68
# change 5
# nextSpend 1
# a 492
# couple 1
# of 27
# hours 1
# heads 1
# down/headphones 1
# on 68
# getting 1
# series 1
# with 16
# an 117
# analysis.Finish 1
# the 58
# day 4
# looking 3
# over 4
# any 11
# code 5
# you 33
# wrote 1
# today, 1
# knit 1
# any 11
# Markdowns 1
# and 57
# make 7
# sure 2
# your 10
# documentation 2
# is 30
# up 12
# to 68
# snuff.So 1
# how 8
# do 10
# Data 7
# Scientists 1
# make 7
# great 4
# experiences 4
# for 14
# players? 1
# They:Tell 1
# stories 1
# with 16
# data 3
# and 57
# interpret 1
# results 3
# for 14
# their 6
# stakeholdersPrioritize 1
# problems 4
# to 68
# solve 3
# based 1
# on 68
# the 58
# impact 1
# to 68
# the 58
# player 10
# experience 9
# while 2
# keeping 1
# overall 1
# organizational 1
# goals 1
# in 103
# mindHave 1
# a 492
# basic 1
# understanding 1
# of 27
# EA’s 2
# games 6
# and 57
# find 3
# time 4
# to 68
# play 14
# whenever 2
# they 4
# canDisplay 1
# confidence 1
# in 103
# communicating 1
# with 16
# senior 1
# management, 1
# or 64
# any 11
# audience, 2
# to 68
# ensure 1
# what 5
# they 4
# say 1
# is 30
# heard 1
# and 57
# understoodIdentify 1
# and 57
# lead 2
# collaborative 1
# efforts 1
# both 1
# inside 1
# and 57
# outside 1
# of 27
# their 6
# team; 1
# working 2
# with 16
# key 1
# influencers 1
# to 68
# effect 1
# changeTailor 1
# communications 1
# to 68
# their 6
# audience, 2
# providing 2
# either 1
# in-depth 1
# expertise 1
# or 64
# a 492
# high-level 1
# summary 1
# depending 1
# on 68
# the 58
# situationUse 1
# models 2
# and 57
# techniques 1
# that 14
# win 3
# on 68
# performance 1
# and 57
# understandability 1
# vs. 1
# sophisticationYou’ll 1
# need 3
# to 68
# be 13
# awesome 1
# at 92
# wearing 1
# these 2
# hats:Customer 1
# Advocate 1
# – 12
# You 14
# care 5
# what 5
# kind 2
# of 27
# experience 9
# our 24
# players 7
# are 13
# having 1
# when 5
# their 6
# games 6
# or 64
# services 2
# don’t 2
# work 12
# and 57
# you 33
# want 3
# to 68
# be 13
# an 117
# active 2
# participant 1
# in 103
# improving 2
# itProgrammer 1
# – 12
# You’re 5
# an 117
# expert 3
# at 92
# writing 1
# functions 1
# and 57
# identifying 1
# the 58
# right 5
# language 3
# for 14
# the 58
# right 5
# situationPeople 1
# Analyst 1
# – 12
# You 14
# understand 6
# that 14
# your 10
# work 12
# contributes 1
# to 68
# improving 2
# people’s 1
# lives 2
# not 2
# predict 1
# when 5
# a 492
# machine 1
# is 30
# going 2
# to 68
# break 1
# downLearner 1
# – 12
# You 14
# are 13
# a 492
# regular 1
# on 68
# Stack 1
# Overflow, 1
# know 4
# how 8
# to 68
# take 6
# apart 1
# a 492
# Vignette 1
# and 57
# are 13
# always 1
# looking 3
# for 14
# a 492
# new 3
# project 4
# that 14
# allows 1
# you 33
# to 68
# put 3
# that 14
# cutting 1
# edge 2
# technique 2
# to 68
# good 1
# use 4
# you 33
# read 2
# about 9
# last 5
# monthDocumentation 1
# Expert 2
# – 12
# you 33
# know 4
# just 2
# the 58
# right 5
# level 3
# of 27
# documentation 2
# to 68
# help 4
# yourself 2
# and 57
# the 58
# next 4
# person 4
# understand 6
# what 5
# you 33
# did, 1
# when 5
# and 57
# whyTeacher 1
# – 12
# you’re 5
# patient 1
# and 57
# can 8
# field 2
# questions 1
# from 5
# the 58
# rest 2
# of 27
# the 58
# team 10
# around 1
# better 1
# coding 1
# practicesExperiment 1
# Designer 1
# – 12
# You 14
# can 8
# create 2
# up 12
# an 117
# A/B 2
# test 4
# in 103
# your 10
# sleep, 1
# but 3
# you 33
# don’t 2
# let 3
# a 492
# less 1
# than 1
# ideal 1
# A/B 2
# test 4
# set 1
# up 12
# stop 1
# you 33
# from 5
# finding 2
# some 6
# answersNLP 1
# fanatic 2
# – 12
# you 33
# can 8
# turn 1
# language 3
# into 3
# math??? 1
# Yeah 1
# – 12
# that’s 2
# the 58
# stuff 1
# you 33
# love!A 1
# few 1
# last 5
# things 3
# about 9
# how 8
# we 15
# work, 1
# because 1
# they’re 1
# super 1
# important:We 1
# chat 3
# to 68
# each 4
# other 5
# in 103
# SlackWe 1
# email 1
# each 4
# other 5
# about 9
# things 3
# that 14
# can 8
# wait 1
# or 64
# are 13
# just 2
# FYIWe 1
# store 1
# all 11
# our 24
# code 5
# on 68
# Stash, 1
# how-to’s 1
# on 68
# Confluence 1
# and 57
# complete 1
# analyses 1
# on 68
# the 58
# Knowledge 1
# RepoWe 1
# document 3
# our 24
# code 5
# like 4
# we’re 1
# going 2
# to 68
# win 3
# the 58
# lottery 1
# tomorrow 1
# and 57
# somebody 1
# else 2
# has 1
# to 68
# take 6
# overWe 1
# plan 4
# and 57
# track 1
# our 24
# work 12
# in 103
# JIRA 2
# so 23
# we 15
# can 8
# avoid 1
# duplication 1
# with 16
# other 5
# teamsWe 1
# collaborate 1
# with 16
# Data 7
# Science 4
# at 92
# HQ 1
# to 68
# share 1
# best 3
# practices 2
# and 57
# exchange 1
# findingsIf 1
# you’re 5
# interested 1
# in 103
# this 2
# role, 1
# you’ll 1
# need 3
# these 2
# skills 1
# or 64
# experiences:3 1
# to 68
# 5 1
# years’ 1
# experience 9
# in 103
# Data 7
# Science 4
# with 16
# focus 1
# on 68
# NLPMaster’s 1
# in 103
# Computer 1
# Science, 1
# Statistics, 1
# Operations 1
# Research 2
# or 64
# related 1
# field 2
# (we 1
# will 1
# consider 1
# a 492
# Bachelor’s 1
# degree 1
# with 16
# significant 1
# relevant 1
# experience)Expert 1
# in 103
# at 92
# least 1
# one 7
# Statistical 1
# Programming 1
# Language 1
# such 1
# as 24
# R 6
# or 64
# PythonExperience 1
# with 16
# relational 1
# and 57
# distributed 1
# databasesExperience 1
# with 16
# any 11
# of 27
# the 58
# following 1
# is 30
# a 492
# big 2
# plus: 1
# PySpark, 1
# Scala, 1
# Zepplin 1
# Notebooks, 1
# Spark 2
# and 57
# MLlib 1
# as 24
# well 1
# as 24
# application 1
# development 1
# using 1
# AWS, 1
# Virtual 1
# Machines, 1
# or 64
# DockerGaming 1
# industry 1
# and 57
# customer 1
# support 1
# experience 9
# a 492
# plusWhat’s 1
# in 103
# it 47
# for 14
# you? 1
# Glad 1
# you 33
# asked!We 1
# love 2
# to 68
# brag 1
# about 9
# our 24
# great 4
# perks 2
# like 4
# comprehensive 1
# health 1
# and 57
# benefit 1
# packages, 1
# tuition 1
# reimbursement, 1
# 401k 1
# company 2
# match 2
# and, 1
# of 27
# course, 1
# many 1
# other 5
# perks! 1
# And 2
# since 1
# we 15
# realize 1
# it 47
# takes 1
# world-class 2
# people 7
# to 68
# make 7
# world-class 2
# games, 2
# we 15
# offer 2
# competitive 1
# compensation 1
# packages 2
# and 57
# a 492
# culture 1
# that 14
# thrives 1
# off 6
# of 27
# creativity 2
# and 57
# individuality. 1
# At 2
# EA, 1
# we 15
# live 4
# the 58
# “work 1
# hard/play 1
# hard” 1
# credo 1
# every 1
# day. 1
# More 1
# about 9
# our 24
# location:https://www.ea.com/careers/careers-overview/austinElectronic 1
# Arts 1
# Inc. 1
# is 30
# a 492
# leading 1
# global 1
# interactive 1
# entertainment 1
# software 1
# company. 1
# EA 8
# delivers 1
# games, 2
# content 1
# and 57
# online 1
# services 2
# for 14
# Internet-connected 1
# consoles, 1
# personal 1
# computers, 1
# mobile 1
# phones 2
# and 57
# tablets. 1

# %%
word_dict #prints contents of dictionary
# Out:
# {'Data': 7,
#  'Scientist,': 1,
#  'EA': 8,
#  'Customer': 6,
#  'Experience#WeAreEA': 1,
#  'and': 57,
#  'we': 15,
#  'exist': 1,
#  'to': 68,
#  'inspire': 2,
#  'the': 58,
#  'world': 3,
#  'play.': 1,
#  'values': 1,
#  'creativity,': 1,
#  'pioneering,': 1,
#  'passion,': 1,
#  'determination,': 1,
#  'learning,': 1,
#  'teamwork.': 1,
#  'We': 18,
#  'mean': 1,
#  'things': 3,
#  'like': 4,
#  'acting': 1,
#  'with': 16,
#  'curiosity,': 1,
#  'speaking': 1,
#  'up': 12,
#  'original': 1,
#  'ideas,': 1,
#  'committing': 1,
#  'each': 4,
#  'other': 5,
#  'as': 24,
#  'one': 7,
#  'team.We’re': 1,
#  'looking': 3,
#  'for': 14,
#  'all': 11,
#  'best': 3,
#  'kinds': 1,
#  'of': 27,
#  'people': 7,
#  'make': 7,
#  'great': 4,
#  'experiences': 4,
#  'our': 24,
#  'players.': 2,
#  'The': 3,
#  'want': 3,
#  'a': 492,
#  'job': 1,
#  'that': 14,
#  'inspires': 1,
#  'them,': 1,
#  'while': 2,
#  'giving': 1,
#  'them': 3,
#  'room': 1,
#  'enjoy': 1,
#  'their': 6,
#  'lives.': 1,
#  'And': 2,
#  'give': 1,
#  'that.': 1,
#  'celebrate': 1,
#  'diversity': 1,
#  'inclusion': 1,
#  'by': 2,
#  'creating': 1,
#  'place': 1,
#  'where': 2,
#  'you': 33,
#  'can': 8,
#  'come': 2,
#  'work': 12,
#  'be': 13,
#  'yourself.You’re': 1,
#  'Scientist.You': 1,
#  'Understand': 1,
#  'That': 1,
#  'You': 14,
#  'Have': 2,
#  '2': 2,
#  'Basic': 1,
#  'JobsYou': 1,
#  'know': 4,
#  'how': 8,
#  'pull': 1,
#  'types': 1,
#  'data': 3,
#  'from': 5,
#  'any': 11,
#  'source,': 1,
#  'it': 47,
#  'Facebook': 1,
#  'posts,': 1,
#  'call': 2,
#  'center': 2,
#  'chats,': 1,
#  'video': 1,
#  'likes': 1,
#  'or': 64,
#  'survey': 1,
#  'results.Help': 1,
#  'studios': 1,
#  'understand': 6,
#  'what': 5,
#  'problems': 4,
#  'players': 7,
#  'have': 2,
#  'games': 6,
#  'provide': 2,
#  'insights': 2,
#  'help': 4,
#  'optimize': 1,
#  'center.': 1,
#  'Both': 1,
#  'pursue': 1,
#  'ultimate': 1,
#  'goal': 2,
#  'providing': 2,
#  'World’s': 2,
#  'Best': 2,
#  'Service': 1,
#  'Games.You': 1,
#  'use': 4,
#  'resources': 1,
#  'available': 1,
#  'solve': 3,
#  'problem,': 1,
#  'new': 3,
#  'algorithm,': 1,
#  'programming': 1,
#  'language': 3,
#  'person': 4,
#  'sitting': 1,
#  'next': 4,
#  'you.You’re': 1,
#  'programmer/statistician/NLP': 1,
#  'expert': 3,
#  'who': 4,
#  'is': 30,
#  'fanatic': 2,
#  'about': 9,
#  'Experiences.You’re': 1,
#  'also': 1,
#  'genuinely': 1,
#  'nice': 1,
#  'brings': 1,
#  'positive': 1,
#  'energy': 1,
#  'an': 117,
#  'office.': 1,
#  'You’re': 5,
#  'approachable': 1,
#  'take': 6,
#  'time': 4,
#  'listen': 1,
#  'so': 23,
#  'someone': 1,
#  'else’s': 1,
#  'view.This': 1,
#  'role': 2,
#  'part': 4,
#  'EA’s': 2,
#  'Experience': 7,
#  'organization.': 1,
#  'organization': 3,
#  'strives': 1,
#  'known': 1,
#  'taking': 2,
#  'care': 5,
#  'its': 1,
#  'We’re': 4,
#  'talking': 1,
#  '–': 12,
#  'whenever,': 1,
#  'wherever,': 1,
#  'however': 1,
#  'they': 4,
#  'need': 3,
#  'us.We’re': 1,
#  'Science': 4,
#  'team,': 1,
#  'larger': 1,
#  'Insights': 1,
#  'team.We': 2,
#  'are': 13,
#  'surrounded': 1,
#  'Production,': 1,
#  'BI,': 1,
#  'SEO': 1,
#  'Market': 1,
#  'Research': 2,
#  'analysts.': 1,
#  'advanced': 1,
#  'statistics': 1,
#  'modeling': 1,
#  'business': 1,
#  'problems.': 1,
#  'surface': 1,
#  'player': 10,
#  'through': 1,
#  'text': 1,
#  'analytics': 1,
#  'offerings.': 1,
#  'write': 2,
#  'lot': 2,
#  'code': 5,
#  'talk': 2,
#  'stakeholders': 2,
#  'teams': 2,
#  'levels.': 1,
#  'team': 10,
#  'mates': 2,
#  'trusted': 1,
#  'advisors,': 1,
#  'facilitate': 1,
#  'decisions': 1,
#  'create': 2,
#  'models': 2,
#  'change': 5,
#  'experiences.A': 1,
#  'typical': 1,
#  'day': 4,
#  'in': 103,
#  'life': 1,
#  'Scientist:Come': 1,
#  'into': 3,
#  'office': 2,
#  'catch': 1,
#  'your': 10,
#  'last': 5,
#  'night’s': 2,
#  'gaming': 1,
#  'session': 1,
#  'hottest': 1,
#  'show': 1,
#  'on': 68,
#  'TV': 1,
#  '(no': 1,
#  'spoilers': 1,
#  'until': 1,
#  '24hrs': 1,
#  'passed': 1,
#  'after': 1,
#  'that:': 1,
#  'anything': 1,
#  'fair': 1,
#  'game!)Check': 1,
#  'Jenkins': 1,
#  'script': 1,
#  'add': 1,
#  'some': 6,
#  'project': 4,
#  'you’re': 5,
#  'working': 2,
#  'onTalk': 1,
#  'coworkers': 1,
#  'Call': 1,
#  'Center': 1,
#  'side': 4,
#  'match': 2,
#  'right': 5,
#  'advisor': 2,
#  'this': 2,
#  'could': 1,
#  'big': 2,
#  'projectTake': 1,
#  'back': 1,
#  'at': 92,
#  'desk': 1,
#  'notes': 1,
#  'plan': 4,
#  'proposalAttend': 1,
#  'JIRA': 2,
#  'prioritization': 1,
#  'meeting': 1,
#  'update': 1,
#  'that’s': 2,
#  'flight': 1,
#  'comeGrab': 1,
#  'coffee': 1,
#  'read': 2,
#  'stats': 1,
#  'blogs': 1,
#  'tech': 3,
#  'news': 1,
#  'subscribed': 1,
#  'toCheck': 1,
#  'out': 11,
#  'model': 5,
#  'deployed': 1,
#  'production': 1,
#  'month': 2,
#  'see': 1,
#  'if': 5,
#  'it’s': 1,
#  're-trainPull': 1,
#  'latest': 1,
#  'changes': 1,
#  'NLP': 4,
#  'collaborating': 1,
#  'Stash': 2,
#  'tinker': 1,
#  'parameters,': 1,
#  'then': 1,
#  'chat': 3,
#  'peer': 1,
#  'results': 3,
#  'tweaks': 1,
#  'plans': 1,
#  'nextSpend': 1,
#  'couple': 1,
#  'hours': 1,
#  'heads': 1,
#  'down/headphones': 1,
#  'getting': 1,
#  'series': 1,
#  'analysis.Finish': 1,
#  'over': 4,
#  'wrote': 1,
#  'today,': 1,
#  'knit': 1,
#  'Markdowns': 1,
#  'sure': 2,
#  'documentation': 2,
#  'snuff.So': 1,
#  'do': 10,
#  'Scientists': 1,
#  'players?': 1,
#  'They:Tell': 1,
#  'stories': 1,
#  'interpret': 1,
#  'stakeholdersPrioritize': 1,
#  'based': 1,
#  'impact': 1,
#  'experience': 9,
#  'keeping': 1,
#  'overall': 1,
#  'organizational': 1,
#  'goals': 1,
#  'mindHave': 1,
#  'basic': 1,
#  'understanding': 1,
#  'find': 3,
#  'play': 14,
#  'whenever': 2,
#  'canDisplay': 1,
#  'confidence': 1,
#  'communicating': 1,
#  'senior': 1,
#  'management,': 1,
#  'audience,': 2,
#  'ensure': 1,
#  'say': 1,
#  'heard': 1,
#  'understoodIdentify': 1,
#  'lead': 2,
#  'collaborative': 1,
#  'efforts': 1,
#  'both': 1,
#  'inside': 1,
#  'outside': 1,
#  'team;': 1,
#  'key': 1,
#  'influencers': 1,
#  'effect': 1,
#  'changeTailor': 1,
#  'communications': 1,
#  'either': 1,
#  'in-depth': 1,
#  'expertise': 1,
#  'high-level': 1,
#  'summary': 1,
#  'depending': 1,
#  'situationUse': 1,
#  'techniques': 1,
#  'win': 3,
#  'performance': 1,
#  'understandability': 1,
#  'vs.': 1,
#  'sophisticationYou’ll': 1,
#  'awesome': 1,
#  'wearing': 1,
#  'these': 2,
#  'hats:Customer': 1,
#  'Advocate': 1,
#  'kind': 2,
#  'having': 1,
#  'when': 5,
#  'services': 2,
#  'don’t': 2,
#  'active': 2,
#  'participant': 1,
#  'improving': 2,
#  'itProgrammer': 1,
#  'writing': 1,
#  'functions': 1,
#  'identifying': 1,
#  'situationPeople': 1,
#  'Analyst': 1,
#  'contributes': 1,
#  'people’s': 1,
#  'lives': 2,
#  'not': 2,
#  'predict': 1,
#  'machine': 1,
#  'going': 2,
#  'break': 1,
#  'downLearner': 1,
#  'regular': 1,
#  'Stack': 1,
#  'Overflow,': 1,
#  'apart': 1,
#  'Vignette': 1,
#  'always': 1,
#  'allows': 1,
#  'put': 3,
#  'cutting': 1,
#  'edge': 2,
#  'technique': 2,
#  'good': 1,
#  'monthDocumentation': 1,
#  'Expert': 2,
#  'just': 2,
#  'level': 3,
#  'yourself': 2,
#  'did,': 1,
#  'whyTeacher': 1,
#  'patient': 1,
#  'field': 2,
#  'questions': 1,
#  'rest': 2,
#  'around': 1,
#  'better': 1,
#  'coding': 1,
#  'practicesExperiment': 1,
#  'Designer': 1,
#  'A/B': 2,
#  'test': 4,
#  'sleep,': 1,
#  'but': 3,
#  'let': 3,
#  'less': 1,
#  'than': 1,
#  'ideal': 1,
#  'set': 1,
#  'stop': 1,
#  'finding': 2,
#  'answersNLP': 1,
#  'turn': 1,
#  'math???': 1,
#  'Yeah': 1,
#  'stuff': 1,
#  'love!A': 1,
#  'few': 1,
#  'work,': 1,
#  'because': 1,
#  'they’re': 1,
#  'super': 1,
#  'important:We': 1,
#  'SlackWe': 1,
#  'email': 1,
#  'wait': 1,
#  'FYIWe': 1,
#  'store': 1,
#  'Stash,': 1,
#  'how-to’s': 1,
#  'Confluence': 1,
#  'complete': 1,
#  'analyses': 1,
#  'Knowledge': 1,
#  'RepoWe': 1,
#  'document': 3,
#  'we’re': 1,
#  'lottery': 1,
#  'tomorrow': 1,
#  'somebody': 1,
#  'else': 2,
#  'has': 1,
#  'overWe': 1,
#  'track': 1,
#  'avoid': 1,
#  'duplication': 1,
#  'teamsWe': 1,
#  'collaborate': 1,
#  'HQ': 1,
#  'share': 1,
#  'practices': 2,
#  'exchange': 1,
#  'findingsIf': 1,
#  'interested': 1,
#  'role,': 1,
#  'you’ll': 1,
#  'skills': 1,
#  'experiences:3': 1,
#  '5': 1,
#  'years’': 1,
#  'focus': 1,
#  'NLPMaster’s': 1,
#  'Computer': 1,
#  'Science,': 1,
#  'Statistics,': 1,
#  'Operations': 1,
#  'related': 1,
#  '(we': 1,
#  'will': 1,
#  'consider': 1,
#  'Bachelor’s': 1,
#  'degree': 1,
#  'significant': 1,
#  'relevant': 1,
#  'experience)Expert': 1,
#  'least': 1,
#  'Statistical': 1,
#  'Programming': 1,
#  'Language': 1,
#  'such': 1,
#  'R': 6,
#  'PythonExperience': 1,
#  'relational': 1,
#  'distributed': 1,
#  'databasesExperience': 1,
#  'following': 1,
#  'plus:': 1,
#  'PySpark,': 1,
#  'Scala,': 1,
#  'Zepplin': 1,
#  'Notebooks,': 1,
#  'Spark': 2,
#  'MLlib': 1,
#  'well': 1,
#  'application': 1,
#  'development': 1,
#  'using': 1,
#  'AWS,': 1,
#  'Virtual': 1,
#  'Machines,': 1,
#  'DockerGaming': 1,
#  'industry': 1,
#  'customer': 1,
#  'support': 1,
#  'plusWhat’s': 1,
#  'you?': 1,
#  'Glad': 1,
#  'asked!We': 1,
#  'love': 2,
#  'brag': 1,
#  'perks': 2,
#  'comprehensive': 1,
#  'health': 1,
#  'benefit': 1,
#  'packages,': 1,
#  'tuition': 1,
#  'reimbursement,': 1,
#  '401k': 1,
#  'company': 2,
#  'and,': 1,
#  'course,': 1,
#  'many': 1,
#  'perks!': 1,
#  'since': 1,
#  'realize': 1,
#  'takes': 1,
#  'world-class': 2,
#  'games,': 2,
#  'offer': 2,
#  'competitive': 1,
#  'compensation': 1,
#  'packages': 2,
#  'culture': 1,
#  'thrives': 1,
#  'off': 6,
#  'creativity': 2,
#  'individuality.': 1,
#  'At': 2,
#  'EA,': 1,
#  'live': 4,
#  '“work': 1,
#  'hard/play': 1,
#  'hard”': 1,
#  'credo': 1,
#  'every': 1,
#  'day.': 1,
#  'More': 1,
#  'location:https://www.ea.com/careers/careers-overview/austinElectronic': 1,
#  'Arts': 1,
#  'Inc.': 1,
#  'leading': 1,
#  'global': 1,
#  'interactive': 1,
#  'entertainment': 1,
#  'software': 1,
#  'company.': 1,
#  'delivers': 1,
#  'content': 1,
#  'online': 1,
#  'Internet-connected': 1,
#  'consoles,': 1,
#  'personal': 1,
#  'computers,': 1,
#  'mobile': 1,
#  'phones': 2,
#  'tablets.': 1}

# %% [markdown]
# ### In this approach, the Count Vectorizer(a Natural Language Processing technique) function is used to compute the word count of each word in main body of job description.

# %%
cv = CountVectorizer(stop_words=['and', 'And', 'to', 'or', 'a'] ) #initializes CountVectorizer function with specific stop words

# %%
cv.fit(mega_text.split()) #fits all of the words inside mega_text with CountVectorizer function
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None,
#         stop_words=['and', 'And', 'to', 'or', 'a'], strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None)

# %%
cv_all = cv.transform(mega_text.split()) #transforms words with CountVectorizer function

# %%
cv_all #displays contents of cv_all, which is currently a sparse matrix
# Out:
# <1171x533 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1069 stored elements in Compressed Sparse Row format>

# %%
type(cv_all) #shows the data type of cv_all
# Out:
# scipy.sparse.csr.csr_matrix

# %%
cv_df = pd.DataFrame(cv_all.todense(), columns=cv.get_feature_names()) #converts the sparse matrix cv_all into Data Frame cv_df

# %%
cv_df.shape #shows the number of rows and columns in new dataframe
# Out:
# (1171, 533)

# %%
j = 0 #initializes j to 0
for i in mega_text.split(): #loops through words in mega_text
    j+=1 #increments j

print(j) #prints j, or the number of words that are in mega_text
# Out:
# 1171

# %%
cv_df.columns #shows the columns in cv_df dataframe
# Out:
# Index(['24hrs', '401k', 'about', 'acting', 'active', 'add', 'advanced',
#        'advisor', 'advisors', 'advocate',
#        ...
#        'write', 'writing', 'wrote', 'www', 'yeah', 'years', 'you', 'your',
#        'yourself', 'zepplin'],
#       dtype='object', length=533)

# %%
w_dict = {} #initializes empty dictionary 
for i in cv_df.columns: #loops through columns in cv_df dataframe
    w_dict[i] = cv_df[i].sum() #stores the word as key and its word count as a value in w_dict dictionary 
    
print(w_dict) #prints the contents of dictionary
# Out:
# {'24hrs': 1, '401k': 1, 'about': 9, 'acting': 1, 'active': 1, 'add': 1, 'advanced': 1, 'advisor': 1, 'advisors': 1, 'advocate': 1, 'after': 1, 'algorithm': 1, 'all': 6, 'allows': 1, 'also': 1, 'always': 1, 'an': 6, 'analyses': 1, 'analysis': 1, 'analyst': 1, 'analysts': 1, 'analytics': 1, 'answersnlp': 1, 'any': 7, 'anything': 1, 'apart': 1, 'application': 1, 'approachable': 1, 'are': 6, 'around': 1, 'arts': 1, 'as': 4, 'asked': 1, 'at': 6, 'audience': 2, 'austinelectronic': 1, 'available': 1, 'avoid': 1, 'awesome': 1, 'aws': 1, 'bachelor': 1, 'back': 1, 'based': 1, 'basic': 2, 'be': 6, 'because': 1, 'benefit': 1, 'best': 5, 'better': 1, 'bi': 1, 'big': 2, 'blogs': 1, 'both': 2, 'brag': 1, 'break': 1, 'brings': 1, 'business': 1, 'but': 1, 'by': 2, 'call': 3, 'can': 6, 'candisplay': 1, 'care': 3, 'careers': 2, 'catch': 1, 'celebrate': 1, 'center': 3, 'change': 2, 'changes': 1, 'changetailor': 1, 'chat': 2, 'chats': 1, 'check': 1, 'class': 2, 'code': 5, 'coding': 1, 'coffee': 1, 'collaborate': 1, 'collaborating': 1, 'collaborative': 1, 'com': 1, 'come': 2, 'comegrab': 1, 'committing': 1, 'communicating': 1, 'communications': 1, 'company': 2, 'compensation': 1, 'competitive': 1, 'complete': 1, 'comprehensive': 1, 'computer': 1, 'computers': 1, 'confidence': 1, 'confluence': 1, 'connected': 1, 'consider': 1, 'consoles': 1, 'content': 1, 'contributes': 1, 'could': 1, 'couple': 1, 'course': 1, 'coworkers': 1, 'create': 2, 'creating': 1, 'creativity': 2, 'credo': 1, 'culture': 1, 'curiosity': 1, 'customer': 7, 'cutting': 1, 'data': 9, 'databasesexperience': 1, 'day': 3, 'decisions': 1, 'degree': 1, 'delivers': 1, 'depending': 1, 'deployed': 1, 'depth': 1, 'designer': 1, 'desk': 1, 'determination': 1, 'development': 1, 'did': 1, 'distributed': 1, 'diversity': 1, 'do': 1, 'dockergaming': 1, 'document': 1, 'documentation': 2, 'don': 2, 'down': 1, 'downlearner': 1, 'duplication': 1, 'ea': 8, 'each': 3, 'edge': 1, 'effect': 1, 'efforts': 1, 'either': 1, 'else': 2, 'email': 1, 'energy': 1, 'enjoy': 1, 'ensure': 1, 'entertainment': 1, 'every': 1, 'exchange': 1, 'exist': 1, 'experience': 9, 'experiences': 5, 'expert': 4, 'expertise': 1, 'facebook': 1, 'facilitate': 1, 'fair': 1, 'fanatic': 2, 'few': 1, 'field': 2, 'find': 1, 'finding': 1, 'findingsif': 1, 'finish': 1, 'flight': 1, 'focus': 1, 'following': 1, 'for': 12, 'from': 5, 'functions': 1, 'fyiwe': 1, 'game': 1, 'games': 7, 'gaming': 1, 'genuinely': 1, 'getting': 1, 'give': 1, 'giving': 1, 'glad': 1, 'global': 1, 'goal': 1, 'goals': 1, 'going': 2, 'good': 1, 'great': 4, 'hard': 2, 'has': 1, 'hats': 1, 'have': 3, 'having': 1, 'headphones': 1, 'heads': 1, 'health': 1, 'heard': 1, 'help': 5, 'high': 1, 'hottest': 1, 'hours': 1, 'how': 6, 'however': 1, 'hq': 1, 'https': 1, 'ideal': 1, 'ideas': 1, 'identifying': 1, 'if': 1, 'impact': 1, 'important': 1, 'improving': 2, 'in': 14, 'inc': 1, 'inclusion': 1, 'individuality': 1, 'industry': 1, 'influencers': 1, 'inside': 1, 'insights': 3, 'inspire': 1, 'inspires': 1, 'interactive': 1, 'interested': 1, 'internet': 1, 'interpret': 1, 'into': 3, 'is': 8, 'it': 5, 'itprogrammer': 1, 'its': 1, 'jenkins': 1, 'jira': 2, 'job': 1, 'jobsyou': 1, 'just': 2, 'keeping': 1, 'key': 1, 'kind': 1, 'kinds': 1, 'knit': 1, 'know': 3, 'knowledge': 1, 'known': 1, 'language': 4, 'larger': 1, 'last': 5, 'latest': 1, 'lead': 1, 'leading': 1, 'learning': 1, 'least': 1, 'less': 1, 'let': 1, 'level': 2, 'levels': 1, 'life': 1, 'like': 3, 'likes': 1, 'listen': 1, 'live': 1, 'lives': 2, 'll': 2, 'location': 1, 'looking': 3, 'lot': 1, 'lottery': 1, 'love': 2, 'machine': 1, 'machines': 1, 'make': 7, 'management': 1, 'many': 1, 'markdowns': 1, 'market': 1, 'match': 2, 'mates': 2, 'math': 1, 'mean': 1, 'meeting': 1, 'mindhave': 1, 'mllib': 1, 'mobile': 1, 'model': 2, 'modeling': 1, 'models': 2, 'month': 1, 'monthdocumentation': 1, 'more': 1, 'need': 3, 'new': 2, 'news': 1, 'next': 3, 'nextspend': 1, 'nice': 1, 'night': 2, 'nlp': 2, 'nlpmaster': 1, 'no': 1, 'not': 1, 'notebooks': ...

# %%
sorted(w_dict.items(), key=lambda x:x[1], reverse=True) #takes the word count of every word in mega_text and sorts it from highest 
#word count to lowest word count
# Out:
# [('the', 38),
#  ('you', 35),
#  ('we', 21),
#  ('of', 20),
#  ('re', 17),
#  ('with', 16),
#  ('on', 15),
#  ('that', 15),
#  ('in', 14),
#  ('for', 12),
#  ('our', 10),
#  ('about', 9),
#  ('data', 9),
#  ('experience', 9),
#  ('ea', 8),
#  ('is', 8),
#  ('work', 8),
#  ('your', 8),
#  ('any', 7),
#  ('customer', 7),
#  ('games', 7),
#  ('make', 7),
#  ('people', 7),
#  ('players', 7),
#  ('team', 7),
#  ('up', 7),
#  ('all', 6),
#  ('an', 6),
#  ('are', 6),
#  ('at', 6),
#  ('be', 6),
#  ('can', 6),
#  ('how', 6),
#  ('their', 6),
#  ('best', 5),
#  ('code', 5),
#  ('experiences', 5),
#  ('from', 5),
#  ('help', 5),
#  ('it', 5),
#  ('last', 5),
#  ('other', 5),
#  ('right', 5),
#  ('they', 5),
#  ('understand', 5),
#  ('what', 5),
#  ('world', 5),
#  ('as', 4),
#  ('expert', 4),
#  ('great', 4),
#  ('language', 4),
#  ('problems', 4),
#  ('science', 4),
#  ('time', 4),
#  ('who', 4),
#  ('call', 3),
#  ('care', 3),
#  ('center', 3),
#  ('day', 3),
#  ('each', 3),
#  ('have', 3),
#  ('insights', 3),
#  ('into', 3),
#  ('know', 3),
#  ('like', 3),
#  ('looking', 3),
#  ('need', 3),
#  ('next', 3),
#  ('one', 3),
#  ('person', 3),
#  ('plan', 3),
#  ('play', 3),
#  ('player', 3),
#  ('project', 3),
#  ('results', 3),
#  ('scientist', 3),
#  ('so', 3),
#  ('solve', 3),
#  ('some', 3),
#  ('take', 3),
#  ('them', 3),
#  ('things', 3),
#  ('this', 3),
#  ('use', 3),
#  ('want', 3),
#  ('when', 3),
#  ('audience', 2),
#  ('basic', 2),
#  ('big', 2),
#  ('both', 2),
#  ('by', 2),
#  ('careers', 2),
#  ('change', 2),
#  ('chat', 2),
#  ('class', 2),
#  ('come', 2),
#  ('company', 2),
#  ('create', 2),
#  ('creativity', 2),
#  ('documentation', 2),
#  ('don', 2),
#  ('else', 2),
#  ('fanatic', 2),
#  ('field', 2),
#  ('going', 2),
#  ('hard', 2),
#  ('improving', 2),
#  ('jira', 2),
#  ('just', 2),
#  ('level', 2),
#  ('lives', 2),
#  ('ll', 2),
#  ('love', 2),
#  ('match', 2),
#  ('mates', 2),
#  ('model', 2),
#  ('models', 2),
#  ('new', 2),
#  ('night', 2),
#  ('nlp', 2),
#  ('office', 2),
#  ('organization', 2),
#  ('packages', 2),
#  ('part', 2),
#  ('perks', 2),
#  ('production', 2),
#  ('programming', 2),
#  ('provide', 2),
#  ('providing', 2),
#  ('read', 2),
#  ('research', 2),
#  ('role', 2),
#  ('services', 2),
#  ('stash', 2),
#  ('statistics', 2),
#  ('taking', 2),
#  ('test', 2),
#  ('these', 2),
#  ('whenever', 2),
#  ('while', 2),
#  ('win', 2),
#  ('working', 2),
#  ('write', 2),
#  ('yourself', 2),
#  ('24hrs', 1),
#  ('401k', 1),
#  ('acting', 1),
#  ('active', 1),
#  ('add', 1),
#  ('advanced', 1),
#  ('advisor', 1),
#  ('advisors', 1),
#  ('advocate', 1),
#  ('after', 1),
#  ('algorithm', 1),
#  ('allows', 1),
#  ('also', 1),
#  ('always', 1),
#  ('analyses', 1),
#  ('analysis', 1),
#  ('analyst', 1),
#  ('analysts', 1),
#  ('analytics', 1),
#  ('answersnlp', 1),
#  ('anything', 1),
#  ('apart', 1),
#  ('application', 1),
#  ('approachable', 1),
#  ('around', 1),
#  ('arts', 1),
#  ('asked', 1),
#  ('austinelectronic', 1),
#  ('available', 1),
#  ('avoid', 1),
#  ('awesome', 1),
#  ('aws', 1),
#  ('bachelor', 1),
#  ('back', 1),
#  ('based', 1),
#  ('because', 1),
#  ('benefit', 1),
#  ('better', 1),
#  ('bi', 1),
#  ('blogs', 1),
#  ('brag', 1),
#  ('break', 1),
#  ('brings', 1),
#  ('business', 1),
#  ('but', 1),
#  ('candisplay', 1),
#  ('catch', 1),
#  ('celebrate', 1),
#  ('changes', 1),
#  ('changetailor', 1),
#  ('chats', 1),
#  ('check', 1),
#  ('coding', 1),
#  ('coffee', 1),
#  ('collaborate', 1),
#  ('collaborating', 1),
#  ('collaborative', 1),
#  ('com', 1),
#  ('comegrab', 1),
#  ('committing', 1),
#  ('communicating', 1),
#  ('communications', 1),
#  ('compensation', 1),
#  ('competitive', 1),
#  ('complete', 1),
#  ('comprehensive', 1),
#  ('computer', 1),
#  ('computers', 1),
#  ('confidence', 1),
#  ('confluence', 1),
#  ('connected', 1),
#  ('consider', 1),
#  ('consoles', 1),
#  ('content', 1),
#  ('contributes', 1),
#  ('could', 1),
#  ('couple', 1),
#  ('course', 1),
#  ('coworkers', 1),
#  ('creating', 1),
#  ('credo', 1),
#  ('culture', 1),
#  ('curiosity', 1),
#  ('cutting', 1),
#  ('databasesexperience', 1),
#  ('decisions', 1),
#  ('degree', 1),
#  ('delivers', 1),
#  ('depending', 1),
#  ('deployed', 1),
#  ('depth', 1),
#  ('designer', 1),
#  ('desk', 1),
#  ('determination', 1),
#  ('development', 1),
#  ('did', 1),
#  ('distributed', 1),
#  ('diversity', 1),
#  ('do', 1),
#  ('dockergaming', 1),
#  ('document', 1),
#  ('down', 1),
#  ('downlearner', 1),
#  ('duplication', 1),
#  ('edge', 1),
#  ('effect', 1),
#  ('efforts', 1),
#  ('either', 1),
#  ('email', 1),
#  ('energy', 1),
#  ('enjoy', 1),
#  ('ensure', 1),
#  ('entertainment', 1),
#  ('every', 1),
#  ('exchange', 1),
#  ('exist', 1),
#  ('expertise', 1),
#  ('facebook', 1),
#  ('facilitate', 1),
#  ('fair', 1),
#  ('few', 1),
#  ('find', 1),
#  ('finding', 1),
#  ('findingsif', 1),
#  ('finish', 1),
#  ('flight', 1),
#  ('focus', 1),
#  ('following', 1),
#  ('functions', 1),
#  ('fyiwe', 1),
#  ('game', 1),
#  ('gaming', 1),
#  ('genuinely', 1),
#  ('getting', 1),
#  ('give', 1),
#  ('giving', 1),
#  ('glad', 1),
#  ('global', 1),
#  ('goal', 1),
#  ('goals', 1),
#  ('good', 1),
#  ('has', 1),
#  ('hats', 1),
#  ('having', 1),
#  ('headphones', 1),
#  ('heads', 1),
#  ('health', 1),
#  ('heard', 1),
#  ('high', 1),
#  ('hottest', 1),
#  ('hours', 1),
#  ('however', 1),
#  ('hq', 1),
#  ('https', 1),
#  ('ideal', 1),
#  ('ideas', 1),
#  ('identifying', 1),
#  ('if', 1),
#  ('impact', 1),
#  ('important', 1),
#  ('inc', 1),
#  ('inclusion', 1),
#  ('individuality', 1),
#  ('industry', 1),
#  ('influencers', 1),
#  ('inside', 1),
#  ('inspire', 1),
#  ('inspires', 1),
#  ('interactive', 1),
#  ('interested', 1),
#  ('internet', 1),
#  ('interpret', 1),
#  ('itprogrammer', 1),
#  ('its', 1),
#  ('jenkins', 1),
#  ('job', 1),
#  ('jobsyou', 1),
#  ('keeping', 1),
#  ('key', 1),
#  ('kind', 1),
#  ('kinds', 1),
#  ('knit', 1),
#  ('knowledge', 1),
#  ('known', 1),
#  ('larger', 1),
#  ('latest', 1),
#  ('lead', 1),
#  ('leading', 1),
#  ('learning', 1),
#  ('least', 1),
#  ('less', 1),
#  ('let', 1),
#  ('levels', 1),
#  ('life', 1),
#  ('likes', 1),
#  ('listen', 1),
#  ('live', 1),
#  ('location', 1),
#  ('lot', 1),
#  ('lottery', 1),
#  ('machine', 1),
#  ('machines', 1),
#  ('management', 1),
#  ('many', 1),
#  ('markdowns', 1),
#  ('market', 1),
#  ('math', 1),
#  ('mean', 1),
#  ('meeting', 1),
#  ('mindhave', 1),
#  ('mllib', 1),
#  ('mobile', 1),
#  ('modeling', 1),
#  ('month', 1),
#  ('monthdocumentation', 1),
#  ('more', 1),
#  ('news', 1),
#  ('nextspend', 1),
#  ('nice', 1),
#  ('nlpmaster', 1),
#  ('no', 1),
#  ('not', 1),
#  ('notebooks', 1),
#  ('notes', 1),
#  ('off', 1),
#  ('offer', 1),
#  ('offerings', 1),
#  ('online', 1),
#  ('ontalk', 1),
#  ('operations', 1),
#  ('optimize', 1),
#  ('organizational', 1),
#  ('original', 1),
#  ('out', 1),
#  ('outside', 1),
#  ('over', 1),
#  ('overall', 1),
#  ('overflow', 1),
#  ('overview', 1),
#  ('overwe', 1),
#  ('parameters', 1),
#  ('participant', 1),
#  ('passed', 1),
#  ('passion', 1),
#  ('patient', 1),
#  ('peer', 1),
#  ('performance', 1),
#  ('personal', 1),
#  ('phones', 1),
#  ('pioneering', 1),
#  ('place', 1),
#  ('plans', 1),
#  ('plus', 1),
#  ('pluswhat', 1),
#  ('positive', 1),
#  ('posts', 1),
#  ('practices', 1),
#  ('practicesexperiment', 1),
#  ('predict', 1),
#  ('prioritization', 1),
#  ('problem', 1),
#  ('programmer', 1),
#  ('projecttake', 1),
#  ('proposalattend', 1),
#  ('pull', 1),
#  ('pursue', 1),
#  ('put', 1),
#  ('pyspark', 1),
#  ('pythonexperience', 1),
#  ('questions', 1),
#  ('realize', 1),
#  ('regular', 1),
#  ('reimbursement', 1),
#  ('related', 1),
#  ('relational', 1),
#  ('relevant', 1),
#  ('repowe', 1),
#  ('resources', 1),
#  ('rest', 1),
#  ('room', 1),
#  ('say', 1),
#  ('scala', 1),
#  ('scientists', 1),
#  ('script', 1),
#  ('see', 1),
#  ('senior', 1),
#  ('seo', 1),
#  ('series', 1),
#  ('service', 1),
#  ('session', 1),
#  ('set', 1),
#  ('share', 1),
#  ('show', 1),
#  ('side', 1),
#  ('significant', 1),
#  ('since', 1),
#  ('sitting', 1),
#  ('situationpeople', 1),
#  ('situationuse', 1),
#  ('skills', 1),
#  ('slackwe', 1),
#  ('sleep', 1),
#  ('snuff', 1),
#  ('software', 1),
#  ('somebody', 1),
#  ('someone', 1),
#  ('sophisticationyou', 1),
#  ('source', 1),
#  ('spark', 1),
#  ('speaking', 1),
#  ('spoilers', 1),
#  ('stack', 1),
#  ('stakeholders', 1),
#  ('stakeholdersprioritize', 1),
#  ('statistical', 1),
#  ('statistician', 1),
#  ('stats', 1),
#  ('stop', 1),
#  ('store', 1),
#  ('stories', 1),
#  ('strives', 1),
#  ('studios', 1),
#  ('stuff', 1),
#  ('subscribed', 1),
#  ('such', 1),
#  ('summary', 1),
#  ('super', 1),
#  ('support', 1),
#  ('sure', 1),
#  ('surface', 1),
#  ('surrounded', 1),
#  ('survey', 1),
#  ('tablets', 1),
#  ('takes', 1),
#  ('talk', 1),
#  ('talking', 1),
#  ('teams', 1),
#  ('teamswe', 1),
#  ('teamwork', 1),
#  ('tech', 1),
#  ('technique', 1),
#  ('techniques', 1),
#  ('tell', 1),
#  ('text', 1),
#  ('than', 1),
#  ('then', 1),
#  ('thrives', 1),
#  ('through', 1),
#  ('tinker', 1),
#  ('tocheck', 1),
#  ('today', 1),
#  ('tomorrow', 1),
#  ('track', 1),
#  ('trainpull', 1),
#  ('trusted', 1),
#  ('tuition', 1),
#  ('turn', 1),
#  ('tv', 1),
#  ('tweaks', 1),
#  ('types', 1),
#  ('typical', 1),
#  ('ultimate', 1),
#  ('understandability', 1),
#  ('understanding', 1),
#  ('understoodidentify', 1),
#  ('until', 1),
#  ('update', 1),
#  ('us', 1),
#  ('using', 1),
#  ('values', 1),
#  ('video', 1),
#  ('view', 1),
#  ('vignette', 1),
#  ('virtual', 1),
#  ('vs', 1),
#  ('wait', 1),
#  ('weareea', 1),
#  ('wearing', 1),
#  ('well', 1),
#  ('where', 1),
#  ('wherever', 1),
#  ('whyteacher', 1),
#  ('will', 1),
#  ('writing', 1),
#  ('wrote', 1),
#  ('www', 1),
#  ('yeah', 1),
#  ('years', 1),
#  ('zepplin', 1)]

# %%
#Uses OrderedDict function in order to sort the word count of each word from highest to lowest 
d = collections.OrderedDict(sorted(w_dict.items(), key=itemgetter(1), reverse=True))

# %%
d #generates content of d
# Out:
# OrderedDict([('the', 38),
#              ('you', 35),
#              ('we', 21),
#              ('of', 20),
#              ('re', 17),
#              ('with', 16),
#              ('on', 15),
#              ('that', 15),
#              ('in', 14),
#              ('for', 12),
#              ('our', 10),
#              ('about', 9),
#              ('data', 9),
#              ('experience', 9),
#              ('ea', 8),
#              ('is', 8),
#              ('work', 8),
#              ('your', 8),
#              ('any', 7),
#              ('customer', 7),
#              ('games', 7),
#              ('make', 7),
#              ('people', 7),
#              ('players', 7),
#              ('team', 7),
#              ('up', 7),
#              ('all', 6),
#              ('an', 6),
#              ('are', 6),
#              ('at', 6),
#              ('be', 6),
#              ('can', 6),
#              ('how', 6),
#              ('their', 6),
#              ('best', 5),
#              ('code', 5),
#              ('experiences', 5),
#              ('from', 5),
#              ('help', 5),
#              ('it', 5),
#              ('last', 5),
#              ('other', 5),
#              ('right', 5),
#              ('they', 5),
#              ('understand', 5),
#              ('what', 5),
#              ('world', 5),
#              ('as', 4),
#              ('expert', 4),
#              ('great', 4),
#              ('language', 4),
#              ('problems', 4),
#              ('science', 4),
#              ('time', 4),
#              ('who', 4),
#              ('call', 3),
#              ('care', 3),
#              ('center', 3),
#              ('day', 3),
#              ('each', 3),
#              ('have', 3),
#              ('insights', 3),
#              ('into', 3),
#              ('know', 3),
#              ('like', 3),
#              ('looking', 3),
#              ('need', 3),
#              ('next', 3),
#              ('one', 3),
#              ('person', 3),
#              ('plan', 3),
#              ('play', 3),
#              ('player', 3),
#              ('project', 3),
#              ('results', 3),
#              ('scientist', 3),
#              ('so', 3),
#              ('solve', 3),
#              ('some', 3),
#              ('take', 3),
#              ('them', 3),
#              ('things', 3),
#              ('this', 3),
#              ('use', 3),
#              ('want', 3),
#              ('when', 3),
#              ('audience', 2),
#              ('basic', 2),
#              ('big', 2),
#              ('both', 2),
#              ('by', 2),
#              ('careers', 2),
#              ('change', 2),
#              ('chat', 2),
#              ('class', 2),
#              ('come', 2),
#              ('company', 2),
#              ('create', 2),
#              ('creativity', 2),
#              ('documentation', 2),
#              ('don', 2),
#              ('else', 2),
#              ('fanatic', 2),
#              ('field', 2),
#              ('going', 2),
#              ('hard', 2),
#              ('improving', 2),
#              ('jira', 2),
#              ('just', 2),
#              ('level', 2),
#              ('lives', 2),
#              ('ll', 2),
#              ('love', 2),
#              ('match', 2),
#              ('mates', 2),
#              ('model', 2),
#              ('models', 2),
#              ('new', 2),
#              ('night', 2),
#              ('nlp', 2),
#              ('office', 2),
#              ('organization', 2),
#              ('packages', 2),
#              ('part', 2),
#              ('perks', 2),
#              ('production', 2),
#              ('programming', 2),
#              ('provide', 2),
#              ('providing', 2),
#              ('read', 2),
#              ('research', 2),
#              ('role', 2),
#              ('services', 2),
#              ('stash', 2),
#              ('statistics', 2),
#              ('taking', 2),
#              ('test', 2),
#              ('these', 2),
#              ('whenever', 2),
#              ('while', 2),
#              ('win', 2),
#              ('working', 2),
#              ('write', 2),
#              ('yourself', 2),
#              ('24hrs', 1),
#              ('401k', 1),
#              ('acting', 1),
#              ('active', 1),
#              ('add', 1),
#              ('advanced', 1),
#              ('advisor', 1),
#              ('advisors', 1),
#              ('advocate', 1),
#              ('after', 1),
#              ('algorithm', 1),
#              ('allows', 1),
#              ('also', 1),
#              ('always', 1),
#              ('analyses', 1),
#              ('analysis', 1),
#              ('analyst', 1),
#              ('analysts', 1),
#              ('analytics', 1),
#              ('answersnlp', 1),
#              ('anything', 1),
#              ('apart', 1),
#              ('application', 1),
#              ('approachable', 1),
#              ('around', 1),
#              ('arts', 1),
#              ('asked', 1),
#              ('austinelectronic', 1),
#              ('available', 1),
#              ('avoid', 1),
#              ('awesome', 1),
#              ('aws', 1),
#              ('bachelor', 1),
#              ('back', 1),
#              ('based', 1),
#              ('because', 1),
#              ('benefit', 1),
#              ('better', 1),
#              ('bi', 1),
#              ('blogs', 1),
#              ('brag', 1),
#              ('break', 1),
#              ('brings', 1),
#              ('business', 1),
#              ('but', 1),
#              ('candisplay', 1),
#              ('catch', 1),
#              ('celebrate', 1),
#              ('changes', 1),
#              ('changetailor', 1),
#              ('chats', 1),
#              ('check', 1),
#              ('coding', 1),
#              ('coffee', 1),
#              ('collaborate', 1),
#              ('collaborating', 1),
#              ('collaborative', 1),
#              ('com', 1),
#              ('comegrab', 1),
#              ('committing', 1),
#              ('communicating', 1),
#              ('communications', 1),
#              ('compensation', 1),
#              ('competitive', 1),
#              ('complete', 1),
#              ('comprehensive', 1),
#              ('computer', 1),
#              ('computers', 1),
#              ('confidence', 1),
#              ('confluence', 1),
#              ('connected', 1),
#              ('consider', 1),
#              ('consoles', 1),
#              ('content', 1),
#              ('contributes', 1),
#              ('could', 1),
#              ('couple', 1),
#              ('course', 1),
#              ('coworkers', 1),
#              ('creating', 1),
#              ('credo', 1),
#              ('culture', 1),
#              ('curiosity', 1),
#              ('cutting', 1),
#              ('databasesexperience', 1),
#              ('decisions', 1),
#              ('degree', 1),
#              ('delivers', 1),
#              ('depending', 1),
#              ('deployed', 1),
#              ('depth', 1),
#              ('designer', 1),
#              ('desk', 1),
#              ('determination', 1),
#              ('development', 1),
#              ('did', 1),
#              ('distributed', 1),
#              ('diversity', 1),
#              ('do', 1),
#              ('dockergaming', 1),
#              ('document', 1),
#              ('down', 1),
#              ('downlearner', 1),
#              ('duplication', 1),
#              ('edge', 1),
#              ('effect', 1),
#              ('efforts', 1),
#              ('either', 1),
#              ('email', 1),
#              ('energy', 1),
#              ('enjoy', 1),
#              ('ensure', 1),
#              ('entertainment', 1),
#              ('every', 1),
#              ('exchange', 1),
#              ('exist', 1),
#              ('expertise', 1),
#              ('facebook', 1),
#              ('facilitate', 1),
#              ('fair', 1),
#              ('few', 1),
#              ('find', 1),
#              ('finding', 1),
#              ('findingsif', 1),
#              ('finish', 1),
#              ('flight', 1),
#              ('focus', 1),
#              ('following', 1),
#              ('functions', 1),
#              ('fyiwe', 1),
#              ('game', 1),
#              ('gaming', 1),
#              ('genuinely', 1),
#              ('getting', 1),
#              ('give', 1),
#              ('giving', 1),
#              ('glad', 1),
#              ('global', 1),
#              ('goal', 1),
#              ('goals', 1),
#              ('good', 1),
#              ('has', 1),
#              ('hats', 1),
#              ('having', 1),
#              ('headphones', 1),
#              ('heads', 1),
#              ('health', 1),
#              ('heard', 1),
#              ('high', 1),
#              ('hottest', 1),
#              ('hours', 1),
#              ('however', 1),
#              ('hq', 1),
#              ('https', 1),
#              ('ideal', 1),
#              ('ideas', 1),
#              ('identifying', 1),
#              ('if', 1),
#              ('impact', 1),
#              ('important', 1),
#              ('inc', 1),
#              ('inclusion', 1),
#              ('individuality', 1),
#              ('industry', 1),
#              ('influencers', 1),
#              ('inside', 1),
#              ('inspire', 1),
#              ('inspires', 1),
#              ('interactive', 1),
#              ('interested', 1),
#              ('internet', 1),
#              ('interpret', 1),
#              ('itprogrammer', 1),
#              ('its', 1),
#              ('jenkins', 1),
#              ('job', 1),
#              ('jobsyou', 1),
#              ('keeping', 1),
#              ('key', 1),
#              ('kind', 1),
#              ('kinds', 1),
#              ('knit', 1),
#              ('knowledge', 1),
#              ('known', 1),
#              ('larger', 1),
#              ('latest', 1),
#              ('lead', 1),
#              ('leading', 1),
#              ('learning', 1),
#              ('least', 1),
#              ('less', 1),
#              ('let', 1),
#              ('levels', 1),
#              ('life', 1),
#              ('likes', 1),
#              ('listen', 1),
#              ('live', 1),
#              ('location', 1),
#              ('lot', 1),
#              ('lottery', 1),
#              ('machine', 1),
#              ('machines', 1),
#              ('management', 1),
#              ('many', 1),
#              ('markdowns', 1),
#              ('market', 1),
#              ('math', 1),
#              ('mean', 1),
#              ('meeting', 1),
#              ('mindhave', 1),
#              ('mllib', 1),
#              ('mobile', 1),
#              ('modeling', 1),
#              ('month', 1),
#              ('monthdocumentation', 1),
#              ('more', 1),
#              ('news', 1),
#              ('nextspend', 1),
#              ('nice', 1),
#              ('nlpmaster', 1),
#              ('no', 1),
#              ('not', 1),
#              ('notebooks', 1),
#              ('notes', 1),
#              ('off', 1),
#              ('offer', 1),
#              ('offerings', 1),
#              ('online', 1),
#              ('ontalk', 1),
#              ('operations', 1),
#              ('optimize', 1),
#              ('organizational', 1),
#              ('original', 1),
#              ('out', 1),
#              ('outside', 1),
#              ('over', 1),
#              ('overall', 1),
#              ('overflow', 1),
#              ('overview', 1),
#              ('overwe', 1),
#              ('parameters', 1),
#              ('participant', 1),
#              ('passed', 1),
#              ('passion', 1),
#              ('patient', 1),
#              ('peer', 1),
#              ('performance', 1),
#              ('personal', 1),
#              ('phones', 1),
#              ('pioneering', 1),
#              ('place', 1),
#              ('plans', 1),
#              ('plus', 1),
#              ('pluswhat', 1),
#              ('positive', 1),
#              ('posts', 1),
#              ('practices', 1),
#              ('practicesexperiment', 1),
#              ('predict', 1),
#              ('prioritization', 1),
#              ('problem', 1),
#              ('programmer', 1),
#              ('projecttake', 1),
#              ('proposalattend', 1),
#              ('pull', 1),
#              ('pursue', 1),
#              ('put', 1),
#              ('pyspark', 1),
#              ('pythonexperience', 1),
#              ('questions', 1),
#              ('realize', 1),
#              ('regular', 1),
#              ('reimbursement', 1),
#              ('related', 1),
#              ('relational', 1),
#              ('relevant', 1),
#              ('repowe', 1),
#              ('resources', 1),
#              ('rest', 1),
#              ('room', 1),
#              ('say', 1),
#              ('scala', 1),
#              ('scientists', 1),
#              ('script', 1),
#              ('see', 1),
#              ('senior', 1),
#              ('seo', 1),
#              ('series', 1),
#              ('service', 1),
#              ('session', 1),
#              ('set', 1),
#              ('share', 1),
#              ('show', 1),
#              ('side', 1),
#              ('significant', 1),
#              ('since', 1),
#              ('sitting', 1),
#              ('situationpeople', 1),
#              ('situationuse', 1),
#              ('skills', 1),
#              ('slackwe', 1),
#              ('sleep', 1),
#              ('snuff', 1),
#              ('software', 1),
#              ('somebody', 1),
#              ('someone', 1),
#              ('sophisticationyou', 1),
#              ('source', 1),
#              ('spark', 1),
#              ('speaking', 1),
#              ('spoilers', 1),
#              ('stack', 1),
#              ('stakeholders', 1),
#              ('stakeholdersprioritize', 1),
#              ('statistical', 1),
#              ('statistician', 1),
#              ('stats', 1),
#              ('stop', 1),
#              ('store', 1),
#              ('stories', 1),
#              ('strives', 1),
#              ('studios', 1),
#              ('stuff', 1),
#              ('subscribed', 1),
#              ('such', 1),
#              ('summary', 1),
#              ('super', 1),
#              ('support', 1),
#              ('sure', 1),
#              ('surface', 1),
#              ('surrounded', 1),
#              ('survey', 1),
#              ('tablets', 1),
#              ('takes', 1),
#              ('talk', 1),
#              ('talking', 1),
#              ('teams', 1),
#              ('teamswe', 1),
#              ('teamwork', 1),
#              ('tech', 1),
#              ('technique', 1),
#              ('techniques', 1),
#              ('tell', 1),
#              ('text', 1),
#              ('than', 1),
#              ('then', 1),
#              ('thrives', 1),
#              ('through', 1),
#              ('tinker', 1),
#              ('tocheck', 1),
#              ('today', 1),
#              ('tomorrow', 1),
#              ('track', 1),
#              ('trainpull', 1),
#              ('trusted', 1),
#              ('tuition', 1),
#              ('turn', 1),
#              ('tv', 1),
#              ('tweaks', 1),
#              ('types', 1),
#              ('typical', 1),
#              ('ultimate', 1),
#              ('understandability', 1),
#              ('understanding', 1),
#              ('understoodidentify', 1),
#              ('until', 1),
#              ('update', 1),
#              ('us', 1),
#              ('using', 1),
#              ('values', 1),
#              ('video', 1),
#              ('view', 1),
#              ('vignette', 1),
#              ('virtual', 1),
#              ('vs', 1),
#              ('wait', 1),
#              ('weareea', 1),
#              ('wearing', 1),
#              ('well', 1),
#              ('where', 1),
#              ('wherever', 1),
#              ('whyteacher', 1),
#              ('will', 1),
#              ('writing', 1),
#              ('wrote', 1),
#              ('www', 1),
#              ('yeah', 1),
#              ('years', 1),
#              ('zepplin', 1)])

# %% [markdown]
# ### Using Natural Language Toolkit(NLTK) to determine word count so that all of the stop words can be filtered with just a couple of lines of code. Provides a faster and more efficient way of determining the word count of only words that matter in a job description

# %%
nltk.__version__ #gets current version of nltk
# Out:
# '3.3'

# %%
stop_words =set(stopwords.words('English')) #finds all of the stop words in the English language

# %%
real_words = [i for i in mega_text.split() if i not in stop_words] #gathers a list of non-stopwords from the meta tag job description

# %%
real_words #shows all of the real words(non-stopwords )
# Out:
# ['Data',
#  'Scientist,',
#  'EA',
#  'Customer',
#  'Experience#WeAreEA',
#  'exist',
#  'inspire',
#  'world',
#  'play.',
#  'EA',
#  'values',
#  'creativity,',
#  'pioneering,',
#  'passion,',
#  'determination,',
#  'learning,',
#  'teamwork.',
#  'We',
#  'mean',
#  'things',
#  'like',
#  'acting',
#  'curiosity,',
#  'speaking',
#  'original',
#  'ideas,',
#  'committing',
#  'one',
#  'team.We’re',
#  'looking',
#  'best',
#  'kinds',
#  'people',
#  'make',
#  'great',
#  'experiences',
#  'players.',
#  'The',
#  'best',
#  'people',
#  'want',
#  'job',
#  'inspires',
#  'them,',
#  'giving',
#  'room',
#  'enjoy',
#  'lives.',
#  'And',
#  'want',
#  'give',
#  'that.',
#  'We',
#  'celebrate',
#  'diversity',
#  'inclusion',
#  'creating',
#  'place',
#  'come',
#  'work',
#  'yourself.You’re',
#  'Data',
#  'Scientist.You',
#  'Understand',
#  'That',
#  'You',
#  'Have',
#  '2',
#  'Basic',
#  'JobsYou',
#  'know',
#  'pull',
#  'types',
#  'data',
#  'source,',
#  'Facebook',
#  'posts,',
#  'call',
#  'center',
#  'chats,',
#  'video',
#  'likes',
#  'survey',
#  'results.Help',
#  'studios',
#  'understand',
#  'problems',
#  'players',
#  'games',
#  'provide',
#  'insights',
#  'help',
#  'optimize',
#  'call',
#  'center.',
#  'Both',
#  'pursue',
#  'ultimate',
#  'goal',
#  'providing',
#  'World’s',
#  'Best',
#  'Service',
#  'World’s',
#  'Best',
#  'Games.You',
#  'use',
#  'resources',
#  'available',
#  'help',
#  'solve',
#  'problem,',
#  'new',
#  'algorithm,',
#  'programming',
#  'language',
#  'person',
#  'sitting',
#  'next',
#  'you.You’re',
#  'programmer/statistician/NLP',
#  'expert',
#  'fanatic',
#  'games',
#  'Customer',
#  'Experiences.You’re',
#  'also',
#  'genuinely',
#  'nice',
#  'person',
#  'brings',
#  'positive',
#  'energy',
#  'office.',
#  'You’re',
#  'approachable',
#  'take',
#  'time',
#  'listen',
#  'understand',
#  'someone',
#  'else’s',
#  'view.This',
#  'role',
#  'part',
#  'EA’s',
#  'Customer',
#  'Experience',
#  'organization.',
#  'The',
#  'Customer',
#  'Experience',
#  'organization',
#  'strives',
#  'make',
#  'EA',
#  'known',
#  'taking',
#  'care',
#  'players.',
#  'We’re',
#  'players',
#  'taking',
#  'care',
#  'players',
#  'people',
#  'talking',
#  'people',
#  '–',
#  'whenever,',
#  'wherever,',
#  'however',
#  'need',
#  'us.We’re',
#  'Data',
#  'Science',
#  'team,',
#  'part',
#  'larger',
#  'Customer',
#  'Experience',
#  'Insights',
#  'team.We',
#  'surrounded',
#  'Production,',
#  'BI,',
#  'SEO',
#  'Market',
#  'Research',
#  'analysts.',
#  'We’re',
#  'people',
#  'use',
#  'advanced',
#  'statistics',
#  'modeling',
#  'help',
#  'solve',
#  'business',
#  'problems.',
#  'We',
#  'surface',
#  'player',
#  'problems',
#  'text',
#  'analytics',
#  'offerings.',
#  'We',
#  'write',
#  'lot',
#  'code',
#  'talk',
#  'stakeholders',
#  'teams',
#  'levels.',
#  'We',
#  'great',
#  'team',
#  'mates',
#  'trusted',
#  'advisors,',
#  'provide',
#  'insights',
#  'facilitate',
#  'decisions',
#  'create',
#  'models',
#  'change',
#  'experiences.A',
#  'typical',
#  'day',
#  'life',
#  'Data',
#  'Scientist:Come',
#  'office',
#  'catch',
#  'team',
#  'mates',
#  'last',
#  'night’s',
#  'gaming',
#  'session',
#  'hottest',
#  'show',
#  'TV',
#  '(no',
#  'spoilers',
#  '24hrs',
#  'passed',
#  '–',
#  'that:',
#  'anything',
#  'fair',
#  'game!)Check',
#  'last',
#  'night’s',
#  'Jenkins',
#  'script',
#  'add',
#  'code',
#  'project',
#  'you’re',
#  'working',
#  'onTalk',
#  'one',
#  'coworkers',
#  'Call',
#  'Center',
#  'side',
#  'match',
#  'right',
#  'advisor',
#  'right',
#  'player',
#  '–',
#  'could',
#  'next',
#  'big',
#  'projectTake',
#  'time',
#  'back',
#  'desk',
#  'write',
#  'notes',
#  'make',
#  'project',
#  'plan',
#  'proposalAttend',
#  'JIRA',
#  'prioritization',
#  'meeting',
#  'update',
#  'work',
#  'that’s',
#  'flight',
#  'plan',
#  'work',
#  'comeGrab',
#  'coffee',
#  'read',
#  'stats',
#  'blogs',
#  'tech',
#  'news',
#  'you’re',
#  'subscribed',
#  'toCheck',
#  'model',
#  'deployed',
#  'production',
#  'last',
#  'month',
#  'see',
#  'it’s',
#  'time',
#  're-trainPull',
#  'latest',
#  'changes',
#  'NLP',
#  'model',
#  'you’re',
#  'collaborating',
#  'Stash',
#  'tinker',
#  'parameters,',
#  'chat',
#  'peer',
#  'results',
#  'tweaks',
#  'make',
#  'plans',
#  'change',
#  'nextSpend',
#  'couple',
#  'hours',
#  'heads',
#  'down/headphones',
#  'getting',
#  'series',
#  'analysis.Finish',
#  'day',
#  'looking',
#  'code',
#  'wrote',
#  'today,',
#  'knit',
#  'Markdowns',
#  'make',
#  'sure',
#  'documentation',
#  'snuff.So',
#  'Data',
#  'Scientists',
#  'make',
#  'great',
#  'experiences',
#  'players?',
#  'They:Tell',
#  'stories',
#  'data',
#  'interpret',
#  'results',
#  'stakeholdersPrioritize',
#  'problems',
#  'solve',
#  'based',
#  'impact',
#  'player',
#  'experience',
#  'keeping',
#  'overall',
#  'organizational',
#  'goals',
#  'mindHave',
#  'basic',
#  'understanding',
#  'EA’s',
#  'games',
#  'find',
#  'time',
#  'play',
#  'whenever',
#  'canDisplay',
#  'confidence',
#  'communicating',
#  'senior',
#  'management,',
#  'audience,',
#  'ensure',
#  'say',
#  'heard',
#  'understoodIdentify',
#  'lead',
#  'collaborative',
#  'efforts',
#  'inside',
#  'outside',
#  'team;',
#  'working',
#  'key',
#  'influencers',
#  'effect',
#  'changeTailor',
#  'communications',
#  'audience,',
#  'providing',
#  'either',
#  'in-depth',
#  'expertise',
#  'high-level',
#  'summary',
#  'depending',
#  'situationUse',
#  'models',
#  'techniques',
#  'win',
#  'performance',
#  'understandability',
#  'vs.',
#  'sophisticationYou’ll',
#  'need',
#  'awesome',
#  'wearing',
#  'hats:Customer',
#  'Advocate',
#  '–',
#  'You',
#  'care',
#  'kind',
#  'experience',
#  'players',
#  'games',
#  'services',
#  'don’t',
#  'work',
#  'want',
#  'active',
#  'participant',
#  'improving',
#  'itProgrammer',
#  '–',
#  'You’re',
#  'expert',
#  'writing',
#  'functions',
#  'identifying',
#  'right',
#  'language',
#  'right',
#  'situationPeople',
#  'Analyst',
#  '–',
#  'You',
#  'understand',
#  'work',
#  'contributes',
#  'improving',
#  'people’s',
#  'lives',
#  'predict',
#  'machine',
#  'going',
#  'break',
#  'downLearner',
#  '–',
#  'You',
#  'regular',
#  'Stack',
#  'Overflow,',
#  'know',
#  'take',
#  'apart',
#  'Vignette',
#  'always',
#  'looking',
#  'new',
#  'project',
#  'allows',
#  'put',
#  'cutting',
#  'edge',
#  'technique',
#  'good',
#  'use',
#  'read',
#  'last',
#  'monthDocumentation',
#  'Expert',
#  '–',
#  'know',
#  'right',
#  'level',
#  'documentation',
#  'help',
#  'next',
#  'person',
#  'understand',
#  'did,',
#  'whyTeacher',
#  '–',
#  'you’re',
#  'patient',
#  'field',
#  'questions',
#  'rest',
#  'team',
#  'around',
#  'better',
#  'coding',
#  'practicesExperiment',
#  'Designer',
#  '–',
#  'You',
#  'create',
#  'A/B',
#  'test',
#  'sleep,',
#  'don’t',
#  'let',
#  'less',
#  'ideal',
#  'A/B',
#  'test',
#  'set',
#  'stop',
#  'finding',
#  'answersNLP',
#  'fanatic',
#  '–',
#  'turn',
#  'language',
#  'math???',
#  'Yeah',
#  '–',
#  'that’s',
#  'stuff',
#  'love!A',
#  'last',
#  'things',
#  'work,',
#  'they’re',
#  'super',
#  'important:We',
#  'chat',
#  'SlackWe',
#  'email',
#  'things',
#  'wait',
#  'FYIWe',
#  'store',
#  'code',
#  'Stash,',
#  'how-to’s',
#  'Confluence',
#  'complete',
#  'analyses',
#  'Knowledge',
#  'RepoWe',
#  'document',
#  'code',
#  'like',
#  'we’re',
#  'going',
#  'win',
#  'lottery',
#  'tomorrow',
#  'somebody',
#  'else',
#  'take',
#  'overWe',
#  'plan',
#  'track',
#  'work',
#  'JIRA',
#  'avoid',
#  'duplication',
#  'teamsWe',
#  'collaborate',
#  'Data',
#  'Science',
#  'HQ',
#  'share',
#  'best',
#  'practices',
#  'exchange',
#  'findingsIf',
#  'you’re',
#  'interested',
#  'role,',
#  'you’ll',
#  'need',
#  'skills',
#  'experiences:3',
#  '5',
#  'years’',
#  'experience',
#  'Data',
#  'Science',
#  'focus',
#  'NLPMaster’s',
#  'Computer',
#  'Science,',
#  'Statistics,',
#  'Operations',
#  'Research',
#  'related',
#  'field',
#  '(we',
#  'consider',
#  'Bachelor’s',
#  'degree',
#  'significant',
#  'relevant',
#  'experience)Expert',
#  'least',
#  'one',
#  'Statistical',
#  'Programming',
#  'Language',
#  'R',
#  'PythonExperience',
#  'relational',
#  'distributed',
#  'databasesExperience',
#  'following',
#  'big',
#  'plus:',
#  'PySpark,',
#  'Scala,',
#  'Zepplin',
#  'Notebooks,',
#  'Spark',
#  'MLlib',
#  'well',
#  'application',
#  'development',
#  'using',
#  'AWS,',
#  'Virtual',
#  'Machines,',
#  'DockerGaming',
#  'industry',
#  'customer',
#  'support',
#  'experience',
#  'plusWhat’s',
#  'you?',
#  'Glad',
#  'asked!We',
#  'love',
#  'brag',
#  'great',
#  'perks',
#  'like',
#  'comprehensive',
#  'health',
#  'benefit',
#  'packages,',
#  'tuition',
#  'reimbursement,',
#  '401k',
#  'company',
#  'match',
#  'and,',
#  'course,',
#  'many',
#  'perks!',
#  'And',
#  'since',
#  'realize',
#  'takes',
#  'world-class',
#  'people',
#  'make',
#  'world-class',
#  'games,',
#  'offer',
#  'competitive',
#  'compensation',
#  'packages',
#  'culture',
#  'thrives',
#  'creativity',
#  'individuality.',
#  'At',
#  'EA,',
#  'live',
#  '“work',
#  'hard/play',
#  'hard”',
#  'credo',
#  'every',
#  'day.',
#  'More',
#  'location:https://www.ea.com/careers/careers-overview/austinElectronic',
#  'Arts',
#  'Inc.',
#  'leading',
#  'global',
#  'interactive',
#  'entertainment',
#  'software',
#  'company.',
#  'EA',
#  'delivers',
#  'games,',
#  'content',
#  'online',
#  'services',
#  'Internet-connected',
#  'consoles,',
#  'personal',
#  'computers,',
#  'mobile',
#  'phones',
#  'tablets.']

# %%
word_dict1 = {} #creates empty dictionary 
for i in real_words: #loops through all of the non-stopwords in job description 
    print(i, real_words.count(i)) #prints the non-stopwords along with its word count 
    word_dict1[i] = mega_text.count(i) #stores non-stopword as a key and its word count as a value in dictionary
# Out:
# Data 7
# Scientist, 1
# EA 4
# Customer 5
# Experience#WeAreEA 1
# exist 1
# inspire 1
# world 1
# play. 1
# EA 4
# values 1
# creativity, 1
# pioneering, 1
# passion, 1
# determination, 1
# learning, 1
# teamwork. 1
# We 5
# mean 1
# things 3
# like 3
# acting 1
# curiosity, 1
# speaking 1
# original 1
# ideas, 1
# committing 1
# one 3
# team.We’re 1
# looking 3
# best 3
# kinds 1
# people 6
# make 7
# great 4
# experiences 2
# players. 2
# The 2
# best 3
# people 6
# want 3
# job 1
# inspires 1
# them, 1
# giving 1
# room 1
# enjoy 1
# lives. 1
# And 2
# want 3
# give 1
# that. 1
# We 5
# celebrate 1
# diversity 1
# inclusion 1
# creating 1
# place 1
# come 1
# work 6
# yourself.You’re 1
# Data 7
# Scientist.You 1
# Understand 1
# That 1
# You 5
# Have 1
# 2 1
# Basic 1
# JobsYou 1
# know 3
# pull 1
# types 1
# data 2
# source, 1
# Facebook 1
# posts, 1
# call 2
# center 1
# chats, 1
# video 1
# likes 1
# survey 1
# results.Help 1
# studios 1
# understand 4
# problems 3
# players 4
# games 4
# provide 2
# insights 2
# help 4
# optimize 1
# call 2
# center. 1
# Both 1
# pursue 1
# ultimate 1
# goal 1
# providing 2
# World’s 2
# Best 2
# Service 1
# World’s 2
# Best 2
# Games.You 1
# use 3
# resources 1
# available 1
# help 4
# solve 3
# problem, 1
# new 2
# algorithm, 1
# programming 1
# language 3
# person 3
# sitting 1
# next 3
# you.You’re 1
# programmer/statistician/NLP 1
# expert 2
# fanatic 2
# games 4
# Customer 5
# Experiences.You’re 1
# also 1
# genuinely 1
# nice 1
# person 3
# brings 1
# positive 1
# energy 1
# office. 1
# You’re 2
# approachable 1
# take 3
# time 4
# listen 1
# understand 4
# someone 1
# else’s 1
# view.This 1
# role 1
# part 2
# EA’s 2
# Customer 5
# Experience 3
# organization. 1
# The 2
# Customer 5
# Experience 3
# organization 1
# strives 1
# make 7
# EA 4
# known 1
# taking 2
# care 3
# players. 2
# We’re 2
# players 4
# taking 2
# care 3
# players 4
# people 6
# talking 1
# people 6
# – 12
# whenever, 1
# wherever, 1
# however 1
# need 3
# us.We’re 1
# Data 7
# Science 3
# team, 1
# part 2
# larger 1
# Customer 5
# Experience 3
# Insights 1
# team.We 1
# surrounded 1
# Production, 1
# BI, 1
# SEO 1
# Market 1
# Research 2
# analysts. 1
# We’re 2
# people 6
# use 3
# advanced 1
# statistics 1
# modeling 1
# help 4
# solve 3
# business 1
# problems. 1
# We 5
# surface 1
# player 3
# problems 3
# text 1
# analytics 1
# offerings. 1
# We 5
# write 2
# lot 1
# code 5
# talk 1
# stakeholders 1
# teams 1
# levels. 1
# We 5
# great 4
# team 3
# mates 2
# trusted 1
# advisors, 1
# provide 2
# insights 2
# facilitate 1
# decisions 1
# create 2
# models 2
# change 2
# experiences.A 1
# typical 1
# day 2
# life 1
# Data 7
# Scientist:Come 1
# office 1
# catch 1
# team 3
# mates 2
# last 5
# night’s 2
# gaming 1
# session 1
# hottest 1
# show 1
# TV 1
# (no 1
# spoilers 1
# 24hrs 1
# passed 1
# – 12
# that: 1
# anything 1
# fair 1
# game!)Check 1
# last 5
# night’s 2
# Jenkins 1
# script 1
# add 1
# code 5
# project 3
# you’re 5
# working 2
# onTalk 1
# one 3
# coworkers 1
# Call 1
# Center 1
# side 1
# match 2
# right 5
# advisor 1
# right 5
# player 3
# – 12
# could 1
# next 3
# big 2
# projectTake 1
# time 4
# back 1
# desk 1
# write 2
# notes 1
# make 7
# project 3
# plan 3
# proposalAttend 1
# JIRA 2
# prioritization 1
# meeting 1
# update 1
# work 6
# that’s 2
# flight 1
# plan 3
# work 6
# comeGrab 1
# coffee 1
# read 2
# stats 1
# blogs 1
# tech 1
# news 1
# you’re 5
# subscribed 1
# toCheck 1
# model 2
# deployed 1
# production 1
# last 5
# month 1
# see 1
# it’s 1
# time 4
# re-trainPull 1
# latest 1
# changes 1
# NLP 1
# model 2
# you’re 5
# collaborating 1
# Stash 1
# tinker 1
# parameters, 1
# chat 2
# peer 1
# results 2
# tweaks 1
# make 7
# plans 1
# change 2
# nextSpend 1
# couple 1
# hours 1
# heads 1
# down/headphones 1
# getting 1
# series 1
# analysis.Finish 1
# day 2
# looking 3
# code 5
# wrote 1
# today, 1
# knit 1
# Markdowns 1
# make 7
# sure 1
# documentation 2
# snuff.So 1
# Data 7
# Scientists 1
# make 7
# great 4
# experiences 2
# players? 1
# They:Tell 1
# stories 1
# data 2
# interpret 1
# results 2
# stakeholdersPrioritize 1
# problems 3
# solve 3
# based 1
# impact 1
# player 3
# experience 4
# keeping 1
# overall 1
# organizational 1
# goals 1
# mindHave 1
# basic 1
# understanding 1
# EA’s 2
# games 4
# find 1
# time 4
# play 1
# whenever 1
# canDisplay 1
# confidence 1
# communicating 1
# senior 1
# management, 1
# audience, 2
# ensure 1
# say 1
# heard 1
# understoodIdentify 1
# lead 1
# collaborative 1
# efforts 1
# inside 1
# outside 1
# team; 1
# working 2
# key 1
# influencers 1
# effect 1
# changeTailor 1
# communications 1
# audience, 2
# providing 2
# either 1
# in-depth 1
# expertise 1
# high-level 1
# summary 1
# depending 1
# situationUse 1
# models 2
# techniques 1
# win 2
# performance 1
# understandability 1
# vs. 1
# sophisticationYou’ll 1
# need 3
# awesome 1
# wearing 1
# hats:Customer 1
# Advocate 1
# – 12
# You 5
# care 3
# kind 1
# experience 4
# players 4
# games 4
# services 2
# don’t 2
# work 6
# want 3
# active 1
# participant 1
# improving 2
# itProgrammer 1
# – 12
# You’re 2
# expert 2
# writing 1
# functions 1
# identifying 1
# right 5
# language 3
# right 5
# situationPeople 1
# Analyst 1
# – 12
# You 5
# understand 4
# work 6
# contributes 1
# improving 2
# people’s 1
# lives 1
# predict 1
# machine 1
# going 2
# break 1
# downLearner 1
# – 12
# You 5
# regular 1
# Stack 1
# Overflow, 1
# know 3
# take 3
# apart 1
# Vignette 1
# always 1
# looking 3
# new 2
# project 3
# allows 1
# put 1
# cutting 1
# edge 1
# technique 1
# good 1
# use 3
# read 2
# last 5
# monthDocumentation 1
# Expert 1
# – 12
# know 3
# right 5
# level 1
# documentation 2
# help 4
# next 3
# person 3
# understand 4
# did, 1
# whyTeacher 1
# – 12
# you’re 5
# patient 1
# field 2
# questions 1
# rest 1
# team 3
# around 1
# better 1
# coding 1
# practicesExperiment 1
# Designer 1
# – 12
# You 5
# create 2
# A/B 2
# test 2
# sleep, 1
# don’t 2
# let 1
# less 1
# ideal 1
# A/B 2
# test 2
# set 1
# stop 1
# finding 1
# answersNLP 1
# fanatic 2
# – 12
# turn 1
# language 3
# math??? 1
# Yeah 1
# – 12
# that’s 2
# stuff 1
# love!A 1
# last 5
# things 3
# work, 1
# they’re 1
# super 1
# important:We 1
# chat 2
# SlackWe 1
# email 1
# things 3
# wait 1
# FYIWe 1
# store 1
# code 5
# Stash, 1
# how-to’s 1
# Confluence 1
# complete 1
# analyses 1
# Knowledge 1
# RepoWe 1
# document 1
# code 5
# like 3
# we’re 1
# going 2
# win 2
# lottery 1
# tomorrow 1
# somebody 1
# else 1
# take 3
# overWe 1
# plan 3
# track 1
# work 6
# JIRA 2
# avoid 1
# duplication 1
# teamsWe 1
# collaborate 1
# Data 7
# Science 3
# HQ 1
# share 1
# best 3
# practices 1
# exchange 1
# findingsIf 1
# you’re 5
# interested 1
# role, 1
# you’ll 1
# need 3
# skills 1
# experiences:3 1
# 5 1
# years’ 1
# experience 4
# Data 7
# Science 3
# focus 1
# NLPMaster’s 1
# Computer 1
# Science, 1
# Statistics, 1
# Operations 1
# Research 2
# related 1
# field 2
# (we 1
# consider 1
# Bachelor’s 1
# degree 1
# significant 1
# relevant 1
# experience)Expert 1
# least 1
# one 3
# Statistical 1
# Programming 1
# Language 1
# R 1
# PythonExperience 1
# relational 1
# distributed 1
# databasesExperience 1
# following 1
# big 2
# plus: 1
# PySpark, 1
# Scala, 1
# Zepplin 1
# Notebooks, 1
# Spark 1
# MLlib 1
# well 1
# application 1
# development 1
# using 1
# AWS, 1
# Virtual 1
# Machines, 1
# DockerGaming 1
# industry 1
# customer 1
# support 1
# experience 4
# plusWhat’s 1
# you? 1
# Glad 1
# asked!We 1
# love 1
# brag 1
# great 4
# perks 1
# like 3
# comprehensive 1
# health 1
# benefit 1
# packages, 1
# tuition 1
# reimbursement, 1
# 401k 1
# company 1
# match 2
# and, 1
# course, 1
# many 1
# perks! 1
# And 2
# since 1
# realize 1
# takes 1
# world-class 2
# people 6
# make 7
# world-class 2
# games, 2
# offer 1
# competitive 1
# compensation 1
# packages 1
# culture 1
# thrives 1
# creativity 1
# individuality. 1
# At 1
# EA, 1
# live 1
# “work 1
# hard/play 1
# hard” 1
# credo 1
# every 1
# day. 1
# More 1
# location:https://www.ea.com/careers/careers-overview/austinElectronic 1
# Arts 1
# Inc. 1
# leading 1
# global 1
# interactive 1
# entertainment 1
# software 1
# company. 1
# EA 4
# delivers 1
# games, 2
# content 1
# online 1
# services 2
# Internet-connected 1
# consoles, 1
# personal 1
# computers, 1
# mobile 1
# phones 1
# tablets. 1

# %%
word_dict1 #generates contents of dictionary
# Out:
# {'Data': 7,
#  'Scientist,': 1,
#  'EA': 8,
#  'Customer': 6,
#  'Experience#WeAreEA': 1,
#  'exist': 1,
#  'inspire': 2,
#  'world': 3,
#  'play.': 1,
#  'values': 1,
#  'creativity,': 1,
#  'pioneering,': 1,
#  'passion,': 1,
#  'determination,': 1,
#  'learning,': 1,
#  'teamwork.': 1,
#  'We': 18,
#  'mean': 1,
#  'things': 3,
#  'like': 4,
#  'acting': 1,
#  'curiosity,': 1,
#  'speaking': 1,
#  'original': 1,
#  'ideas,': 1,
#  'committing': 1,
#  'one': 7,
#  'team.We’re': 1,
#  'looking': 3,
#  'best': 3,
#  'kinds': 1,
#  'people': 7,
#  'make': 7,
#  'great': 4,
#  'experiences': 4,
#  'players.': 2,
#  'The': 3,
#  'want': 3,
#  'job': 1,
#  'inspires': 1,
#  'them,': 1,
#  'giving': 1,
#  'room': 1,
#  'enjoy': 1,
#  'lives.': 1,
#  'And': 2,
#  'give': 1,
#  'that.': 1,
#  'celebrate': 1,
#  'diversity': 1,
#  'inclusion': 1,
#  'creating': 1,
#  'place': 1,
#  'come': 2,
#  'work': 12,
#  'yourself.You’re': 1,
#  'Scientist.You': 1,
#  'Understand': 1,
#  'That': 1,
#  'You': 14,
#  'Have': 2,
#  '2': 2,
#  'Basic': 1,
#  'JobsYou': 1,
#  'know': 4,
#  'pull': 1,
#  'types': 1,
#  'data': 3,
#  'source,': 1,
#  'Facebook': 1,
#  'posts,': 1,
#  'call': 2,
#  'center': 2,
#  'chats,': 1,
#  'video': 1,
#  'likes': 1,
#  'survey': 1,
#  'results.Help': 1,
#  'studios': 1,
#  'understand': 6,
#  'problems': 4,
#  'players': 7,
#  'games': 6,
#  'provide': 2,
#  'insights': 2,
#  'help': 4,
#  'optimize': 1,
#  'center.': 1,
#  'Both': 1,
#  'pursue': 1,
#  'ultimate': 1,
#  'goal': 2,
#  'providing': 2,
#  'World’s': 2,
#  'Best': 2,
#  'Service': 1,
#  'Games.You': 1,
#  'use': 4,
#  'resources': 1,
#  'available': 1,
#  'solve': 3,
#  'problem,': 1,
#  'new': 3,
#  'algorithm,': 1,
#  'programming': 1,
#  'language': 3,
#  'person': 4,
#  'sitting': 1,
#  'next': 4,
#  'you.You’re': 1,
#  'programmer/statistician/NLP': 1,
#  'expert': 3,
#  'fanatic': 2,
#  'Experiences.You’re': 1,
#  'also': 1,
#  'genuinely': 1,
#  'nice': 1,
#  'brings': 1,
#  'positive': 1,
#  'energy': 1,
#  'office.': 1,
#  'You’re': 5,
#  'approachable': 1,
#  'take': 6,
#  'time': 4,
#  'listen': 1,
#  'someone': 1,
#  'else’s': 1,
#  'view.This': 1,
#  'role': 2,
#  'part': 4,
#  'EA’s': 2,
#  'Experience': 7,
#  'organization.': 1,
#  'organization': 3,
#  'strives': 1,
#  'known': 1,
#  'taking': 2,
#  'care': 5,
#  'We’re': 4,
#  'talking': 1,
#  '–': 12,
#  'whenever,': 1,
#  'wherever,': 1,
#  'however': 1,
#  'need': 3,
#  'us.We’re': 1,
#  'Science': 4,
#  'team,': 1,
#  'larger': 1,
#  'Insights': 1,
#  'team.We': 2,
#  'surrounded': 1,
#  'Production,': 1,
#  'BI,': 1,
#  'SEO': 1,
#  'Market': 1,
#  'Research': 2,
#  'analysts.': 1,
#  'advanced': 1,
#  'statistics': 1,
#  'modeling': 1,
#  'business': 1,
#  'problems.': 1,
#  'surface': 1,
#  'player': 10,
#  'text': 1,
#  'analytics': 1,
#  'offerings.': 1,
#  'write': 2,
#  'lot': 2,
#  'code': 5,
#  'talk': 2,
#  'stakeholders': 2,
#  'teams': 2,
#  'levels.': 1,
#  'team': 10,
#  'mates': 2,
#  'trusted': 1,
#  'advisors,': 1,
#  'facilitate': 1,
#  'decisions': 1,
#  'create': 2,
#  'models': 2,
#  'change': 5,
#  'experiences.A': 1,
#  'typical': 1,
#  'day': 4,
#  'life': 1,
#  'Scientist:Come': 1,
#  'office': 2,
#  'catch': 1,
#  'last': 5,
#  'night’s': 2,
#  'gaming': 1,
#  'session': 1,
#  'hottest': 1,
#  'show': 1,
#  'TV': 1,
#  '(no': 1,
#  'spoilers': 1,
#  '24hrs': 1,
#  'passed': 1,
#  'that:': 1,
#  'anything': 1,
#  'fair': 1,
#  'game!)Check': 1,
#  'Jenkins': 1,
#  'script': 1,
#  'add': 1,
#  'project': 4,
#  'you’re': 5,
#  'working': 2,
#  'onTalk': 1,
#  'coworkers': 1,
#  'Call': 1,
#  'Center': 1,
#  'side': 4,
#  'match': 2,
#  'right': 5,
#  'advisor': 2,
#  'could': 1,
#  'big': 2,
#  'projectTake': 1,
#  'back': 1,
#  'desk': 1,
#  'notes': 1,
#  'plan': 4,
#  'proposalAttend': 1,
#  'JIRA': 2,
#  'prioritization': 1,
#  'meeting': 1,
#  'update': 1,
#  'that’s': 2,
#  'flight': 1,
#  'comeGrab': 1,
#  'coffee': 1,
#  'read': 2,
#  'stats': 1,
#  'blogs': 1,
#  'tech': 3,
#  'news': 1,
#  'subscribed': 1,
#  'toCheck': 1,
#  'model': 5,
#  'deployed': 1,
#  'production': 1,
#  'month': 2,
#  'see': 1,
#  'it’s': 1,
#  're-trainPull': 1,
#  'latest': 1,
#  'changes': 1,
#  'NLP': 4,
#  'collaborating': 1,
#  'Stash': 2,
#  'tinker': 1,
#  'parameters,': 1,
#  'chat': 3,
#  'peer': 1,
#  'results': 3,
#  'tweaks': 1,
#  'plans': 1,
#  'nextSpend': 1,
#  'couple': 1,
#  'hours': 1,
#  'heads': 1,
#  'down/headphones': 1,
#  'getting': 1,
#  'series': 1,
#  'analysis.Finish': 1,
#  'wrote': 1,
#  'today,': 1,
#  'knit': 1,
#  'Markdowns': 1,
#  'sure': 2,
#  'documentation': 2,
#  'snuff.So': 1,
#  'Scientists': 1,
#  'players?': 1,
#  'They:Tell': 1,
#  'stories': 1,
#  'interpret': 1,
#  'stakeholdersPrioritize': 1,
#  'based': 1,
#  'impact': 1,
#  'experience': 9,
#  'keeping': 1,
#  'overall': 1,
#  'organizational': 1,
#  'goals': 1,
#  'mindHave': 1,
#  'basic': 1,
#  'understanding': 1,
#  'find': 3,
#  'play': 14,
#  'whenever': 2,
#  'canDisplay': 1,
#  'confidence': 1,
#  'communicating': 1,
#  'senior': 1,
#  'management,': 1,
#  'audience,': 2,
#  'ensure': 1,
#  'say': 1,
#  'heard': 1,
#  'understoodIdentify': 1,
#  'lead': 2,
#  'collaborative': 1,
#  'efforts': 1,
#  'inside': 1,
#  'outside': 1,
#  'team;': 1,
#  'key': 1,
#  'influencers': 1,
#  'effect': 1,
#  'changeTailor': 1,
#  'communications': 1,
#  'either': 1,
#  'in-depth': 1,
#  'expertise': 1,
#  'high-level': 1,
#  'summary': 1,
#  'depending': 1,
#  'situationUse': 1,
#  'techniques': 1,
#  'win': 3,
#  'performance': 1,
#  'understandability': 1,
#  'vs.': 1,
#  'sophisticationYou’ll': 1,
#  'awesome': 1,
#  'wearing': 1,
#  'hats:Customer': 1,
#  'Advocate': 1,
#  'kind': 2,
#  'services': 2,
#  'don’t': 2,
#  'active': 2,
#  'participant': 1,
#  'improving': 2,
#  'itProgrammer': 1,
#  'writing': 1,
#  'functions': 1,
#  'identifying': 1,
#  'situationPeople': 1,
#  'Analyst': 1,
#  'contributes': 1,
#  'people’s': 1,
#  'lives': 2,
#  'predict': 1,
#  'machine': 1,
#  'going': 2,
#  'break': 1,
#  'downLearner': 1,
#  'regular': 1,
#  'Stack': 1,
#  'Overflow,': 1,
#  'apart': 1,
#  'Vignette': 1,
#  'always': 1,
#  'allows': 1,
#  'put': 3,
#  'cutting': 1,
#  'edge': 2,
#  'technique': 2,
#  'good': 1,
#  'monthDocumentation': 1,
#  'Expert': 2,
#  'level': 3,
#  'did,': 1,
#  'whyTeacher': 1,
#  'patient': 1,
#  'field': 2,
#  'questions': 1,
#  'rest': 2,
#  'around': 1,
#  'better': 1,
#  'coding': 1,
#  'practicesExperiment': 1,
#  'Designer': 1,
#  'A/B': 2,
#  'test': 4,
#  'sleep,': 1,
#  'let': 3,
#  'less': 1,
#  'ideal': 1,
#  'set': 1,
#  'stop': 1,
#  'finding': 2,
#  'answersNLP': 1,
#  'turn': 1,
#  'math???': 1,
#  'Yeah': 1,
#  'stuff': 1,
#  'love!A': 1,
#  'work,': 1,
#  'they’re': 1,
#  'super': 1,
#  'important:We': 1,
#  'SlackWe': 1,
#  'email': 1,
#  'wait': 1,
#  'FYIWe': 1,
#  'store': 1,
#  'Stash,': 1,
#  'how-to’s': 1,
#  'Confluence': 1,
#  'complete': 1,
#  'analyses': 1,
#  'Knowledge': 1,
#  'RepoWe': 1,
#  'document': 3,
#  'we’re': 1,
#  'lottery': 1,
#  'tomorrow': 1,
#  'somebody': 1,
#  'else': 2,
#  'overWe': 1,
#  'track': 1,
#  'avoid': 1,
#  'duplication': 1,
#  'teamsWe': 1,
#  'collaborate': 1,
#  'HQ': 1,
#  'share': 1,
#  'practices': 2,
#  'exchange': 1,
#  'findingsIf': 1,
#  'interested': 1,
#  'role,': 1,
#  'you’ll': 1,
#  'skills': 1,
#  'experiences:3': 1,
#  '5': 1,
#  'years’': 1,
#  'focus': 1,
#  'NLPMaster’s': 1,
#  'Computer': 1,
#  'Science,': 1,
#  'Statistics,': 1,
#  'Operations': 1,
#  'related': 1,
#  '(we': 1,
#  'consider': 1,
#  'Bachelor’s': 1,
#  'degree': 1,
#  'significant': 1,
#  'relevant': 1,
#  'experience)Expert': 1,
#  'least': 1,
#  'Statistical': 1,
#  'Programming': 1,
#  'Language': 1,
#  'R': 6,
#  'PythonExperience': 1,
#  'relational': 1,
#  'distributed': 1,
#  'databasesExperience': 1,
#  'following': 1,
#  'plus:': 1,
#  'PySpark,': 1,
#  'Scala,': 1,
#  'Zepplin': 1,
#  'Notebooks,': 1,
#  'Spark': 2,
#  'MLlib': 1,
#  'well': 1,
#  'application': 1,
#  'development': 1,
#  'using': 1,
#  'AWS,': 1,
#  'Virtual': 1,
#  'Machines,': 1,
#  'DockerGaming': 1,
#  'industry': 1,
#  'customer': 1,
#  'support': 1,
#  'plusWhat’s': 1,
#  'you?': 1,
#  'Glad': 1,
#  'asked!We': 1,
#  'love': 2,
#  'brag': 1,
#  'perks': 2,
#  'comprehensive': 1,
#  'health': 1,
#  'benefit': 1,
#  'packages,': 1,
#  'tuition': 1,
#  'reimbursement,': 1,
#  '401k': 1,
#  'company': 2,
#  'and,': 1,
#  'course,': 1,
#  'many': 1,
#  'perks!': 1,
#  'since': 1,
#  'realize': 1,
#  'takes': 1,
#  'world-class': 2,
#  'games,': 2,
#  'offer': 2,
#  'competitive': 1,
#  'compensation': 1,
#  'packages': 2,
#  'culture': 1,
#  'thrives': 1,
#  'creativity': 2,
#  'individuality.': 1,
#  'At': 2,
#  'EA,': 1,
#  'live': 4,
#  '“work': 1,
#  'hard/play': 1,
#  'hard”': 1,
#  'credo': 1,
#  'every': 1,
#  'day.': 1,
#  'More': 1,
#  'location:https://www.ea.com/careers/careers-overview/austinElectronic': 1,
#  'Arts': 1,
#  'Inc.': 1,
#  'leading': 1,
#  'global': 1,
#  'interactive': 1,
#  'entertainment': 1,
#  'software': 1,
#  'company.': 1,
#  'delivers': 1,
#  'content': 1,
#  'online': 1,
#  'Internet-connected': 1,
#  'consoles,': 1,
#  'personal': 1,
#  'computers,': 1,
#  'mobile': 1,
#  'phones': 2,
#  'tablets.': 1}

# %%
sorted(word_dict1.items(), key=itemgetter(1), reverse=True) #takes the word count of each non-stopword and stores it in a list
# Out:
# [('We', 18),
#  ('You', 14),
#  ('play', 14),
#  ('work', 12),
#  ('–', 12),
#  ('player', 10),
#  ('team', 10),
#  ('experience', 9),
#  ('EA', 8),
#  ('Data', 7),
#  ('one', 7),
#  ('people', 7),
#  ('make', 7),
#  ('players', 7),
#  ('Experience', 7),
#  ('Customer', 6),
#  ('understand', 6),
#  ('games', 6),
#  ('take', 6),
#  ('R', 6),
#  ('You’re', 5),
#  ('care', 5),
#  ('code', 5),
#  ('change', 5),
#  ('last', 5),
#  ('you’re', 5),
#  ('right', 5),
#  ('model', 5),
#  ('like', 4),
#  ('great', 4),
#  ('experiences', 4),
#  ('know', 4),
#  ('problems', 4),
#  ('help', 4),
#  ('use', 4),
#  ('person', 4),
#  ('next', 4),
#  ('time', 4),
#  ('part', 4),
#  ('We’re', 4),
#  ('Science', 4),
#  ('day', 4),
#  ('project', 4),
#  ('side', 4),
#  ('plan', 4),
#  ('NLP', 4),
#  ('test', 4),
#  ('live', 4),
#  ('world', 3),
#  ('things', 3),
#  ('looking', 3),
#  ('best', 3),
#  ('The', 3),
#  ('want', 3),
#  ('data', 3),
#  ('solve', 3),
#  ('new', 3),
#  ('language', 3),
#  ('expert', 3),
#  ('organization', 3),
#  ('need', 3),
#  ('tech', 3),
#  ('chat', 3),
#  ('results', 3),
#  ('find', 3),
#  ('win', 3),
#  ('put', 3),
#  ('level', 3),
#  ('let', 3),
#  ('document', 3),
#  ('inspire', 2),
#  ('players.', 2),
#  ('And', 2),
#  ('come', 2),
#  ('Have', 2),
#  ('2', 2),
#  ('call', 2),
#  ('center', 2),
#  ('provide', 2),
#  ('insights', 2),
#  ('goal', 2),
#  ('providing', 2),
#  ('World’s', 2),
#  ('Best', 2),
#  ('fanatic', 2),
#  ('role', 2),
#  ('EA’s', 2),
#  ('taking', 2),
#  ('team.We', 2),
#  ('Research', 2),
#  ('write', 2),
#  ('lot', 2),
#  ('talk', 2),
#  ('stakeholders', 2),
#  ('teams', 2),
#  ('mates', 2),
#  ('create', 2),
#  ('models', 2),
#  ('office', 2),
#  ('night’s', 2),
#  ('working', 2),
#  ('match', 2),
#  ('advisor', 2),
#  ('big', 2),
#  ('JIRA', 2),
#  ('that’s', 2),
#  ('read', 2),
#  ('month', 2),
#  ('Stash', 2),
#  ('sure', 2),
#  ('documentation', 2),
#  ('whenever', 2),
#  ('audience,', 2),
#  ('lead', 2),
#  ('kind', 2),
#  ('services', 2),
#  ('don’t', 2),
#  ('active', 2),
#  ('improving', 2),
#  ('lives', 2),
#  ('going', 2),
#  ('edge', 2),
#  ('technique', 2),
#  ('Expert', 2),
#  ('field', 2),
#  ('rest', 2),
#  ('A/B', 2),
#  ('finding', 2),
#  ('else', 2),
#  ('practices', 2),
#  ('Spark', 2),
#  ('love', 2),
#  ('perks', 2),
#  ('company', 2),
#  ('world-class', 2),
#  ('games,', 2),
#  ('offer', 2),
#  ('packages', 2),
#  ('creativity', 2),
#  ('At', 2),
#  ('phones', 2),
#  ('Scientist,', 1),
#  ('Experience#WeAreEA', 1),
#  ('exist', 1),
#  ('play.', 1),
#  ('values', 1),
#  ('creativity,', 1),
#  ('pioneering,', 1),
#  ('passion,', 1),
#  ('determination,', 1),
#  ('learning,', 1),
#  ('teamwork.', 1),
#  ('mean', 1),
#  ('acting', 1),
#  ('curiosity,', 1),
#  ('speaking', 1),
#  ('original', 1),
#  ('ideas,', 1),
#  ('committing', 1),
#  ('team.We’re', 1),
#  ('kinds', 1),
#  ('job', 1),
#  ('inspires', 1),
#  ('them,', 1),
#  ('giving', 1),
#  ('room', 1),
#  ('enjoy', 1),
#  ('lives.', 1),
#  ('give', 1),
#  ('that.', 1),
#  ('celebrate', 1),
#  ('diversity', 1),
#  ('inclusion', 1),
#  ('creating', 1),
#  ('place', 1),
#  ('yourself.You’re', 1),
#  ('Scientist.You', 1),
#  ('Understand', 1),
#  ('That', 1),
#  ('Basic', 1),
#  ('JobsYou', 1),
#  ('pull', 1),
#  ('types', 1),
#  ('source,', 1),
#  ('Facebook', 1),
#  ('posts,', 1),
#  ('chats,', 1),
#  ('video', 1),
#  ('likes', 1),
#  ('survey', 1),
#  ('results.Help', 1),
#  ('studios', 1),
#  ('optimize', 1),
#  ('center.', 1),
#  ('Both', 1),
#  ('pursue', 1),
#  ('ultimate', 1),
#  ('Service', 1),
#  ('Games.You', 1),
#  ('resources', 1),
#  ('available', 1),
#  ('problem,', 1),
#  ('algorithm,', 1),
#  ('programming', 1),
#  ('sitting', 1),
#  ('you.You’re', 1),
#  ('programmer/statistician/NLP', 1),
#  ('Experiences.You’re', 1),
#  ('also', 1),
#  ('genuinely', 1),
#  ('nice', 1),
#  ('brings', 1),
#  ('positive', 1),
#  ('energy', 1),
#  ('office.', 1),
#  ('approachable', 1),
#  ('listen', 1),
#  ('someone', 1),
#  ('else’s', 1),
#  ('view.This', 1),
#  ('organization.', 1),
#  ('strives', 1),
#  ('known', 1),
#  ('talking', 1),
#  ('whenever,', 1),
#  ('wherever,', 1),
#  ('however', 1),
#  ('us.We’re', 1),
#  ('team,', 1),
#  ('larger', 1),
#  ('Insights', 1),
#  ('surrounded', 1),
#  ('Production,', 1),
#  ('BI,', 1),
#  ('SEO', 1),
#  ('Market', 1),
#  ('analysts.', 1),
#  ('advanced', 1),
#  ('statistics', 1),
#  ('modeling', 1),
#  ('business', 1),
#  ('problems.', 1),
#  ('surface', 1),
#  ('text', 1),
#  ('analytics', 1),
#  ('offerings.', 1),
#  ('levels.', 1),
#  ('trusted', 1),
#  ('advisors,', 1),
#  ('facilitate', 1),
#  ('decisions', 1),
#  ('experiences.A', 1),
#  ('typical', 1),
#  ('life', 1),
#  ('Scientist:Come', 1),
#  ('catch', 1),
#  ('gaming', 1),
#  ('session', 1),
#  ('hottest', 1),
#  ('show', 1),
#  ('TV', 1),
#  ('(no', 1),
#  ('spoilers', 1),
#  ('24hrs', 1),
#  ('passed', 1),
#  ('that:', 1),
#  ('anything', 1),
#  ('fair', 1),
#  ('game!)Check', 1),
#  ('Jenkins', 1),
#  ('script', 1),
#  ('add', 1),
#  ('onTalk', 1),
#  ('coworkers', 1),
#  ('Call', 1),
#  ('Center', 1),
#  ('could', 1),
#  ('projectTake', 1),
#  ('back', 1),
#  ('desk', 1),
#  ('notes', 1),
#  ('proposalAttend', 1),
#  ('prioritization', 1),
#  ('meeting', 1),
#  ('update', 1),
#  ('flight', 1),
#  ('comeGrab', 1),
#  ('coffee', 1),
#  ('stats', 1),
#  ('blogs', 1),
#  ('news', 1),
#  ('subscribed', 1),
#  ('toCheck', 1),
#  ('deployed', 1),
#  ('production', 1),
#  ('see', 1),
#  ('it’s', 1),
#  ('re-trainPull', 1),
#  ('latest', 1),
#  ('changes', 1),
#  ('collaborating', 1),
#  ('tinker', 1),
#  ('parameters,', 1),
#  ('peer', 1),
#  ('tweaks', 1),
#  ('plans', 1),
#  ('nextSpend', 1),
#  ('couple', 1),
#  ('hours', 1),
#  ('heads', 1),
#  ('down/headphones', 1),
#  ('getting', 1),
#  ('series', 1),
#  ('analysis.Finish', 1),
#  ('wrote', 1),
#  ('today,', 1),
#  ('knit', 1),
#  ('Markdowns', 1),
#  ('snuff.So', 1),
#  ('Scientists', 1),
#  ('players?', 1),
#  ('They:Tell', 1),
#  ('stories', 1),
#  ('interpret', 1),
#  ('stakeholdersPrioritize', 1),
#  ('based', 1),
#  ('impact', 1),
#  ('keeping', 1),
#  ('overall', 1),
#  ('organizational', 1),
#  ('goals', 1),
#  ('mindHave', 1),
#  ('basic', 1),
#  ('understanding', 1),
#  ('canDisplay', 1),
#  ('confidence', 1),
#  ('communicating', 1),
#  ('senior', 1),
#  ('management,', 1),
#  ('ensure', 1),
#  ('say', 1),
#  ('heard', 1),
#  ('understoodIdentify', 1),
#  ('collaborative', 1),
#  ('efforts', 1),
#  ('inside', 1),
#  ('outside', 1),
#  ('team;', 1),
#  ('key', 1),
#  ('influencers', 1),
#  ('effect', 1),
#  ('changeTailor', 1),
#  ('communications', 1),
#  ('either', 1),
#  ('in-depth', 1),
#  ('expertise', 1),
#  ('high-level', 1),
#  ('summary', 1),
#  ('depending', 1),
#  ('situationUse', 1),
#  ('techniques', 1),
#  ('performance', 1),
#  ('understandability', 1),
#  ('vs.', 1),
#  ('sophisticationYou’ll', 1),
#  ('awesome', 1),
#  ('wearing', 1),
#  ('hats:Customer', 1),
#  ('Advocate', 1),
#  ('participant', 1),
#  ('itProgrammer', 1),
#  ('writing', 1),
#  ('functions', 1),
#  ('identifying', 1),
#  ('situationPeople', 1),
#  ('Analyst', 1),
#  ('contributes', 1),
#  ('people’s', 1),
#  ('predict', 1),
#  ('machine', 1),
#  ('break', 1),
#  ('downLearner', 1),
#  ('regular', 1),
#  ('Stack', 1),
#  ('Overflow,', 1),
#  ('apart', 1),
#  ('Vignette', 1),
#  ('always', 1),
#  ('allows', 1),
#  ('cutting', 1),
#  ('good', 1),
#  ('monthDocumentation', 1),
#  ('did,', 1),
#  ('whyTeacher', 1),
#  ('patient', 1),
#  ('questions', 1),
#  ('around', 1),
#  ('better', 1),
#  ('coding', 1),
#  ('practicesExperiment', 1),
#  ('Designer', 1),
#  ('sleep,', 1),
#  ('less', 1),
#  ('ideal', 1),
#  ('set', 1),
#  ('stop', 1),
#  ('answersNLP', 1),
#  ('turn', 1),
#  ('math???', 1),
#  ('Yeah', 1),
#  ('stuff', 1),
#  ('love!A', 1),
#  ('work,', 1),
#  ('they’re', 1),
#  ('super', 1),
#  ('important:We', 1),
#  ('SlackWe', 1),
#  ('email', 1),
#  ('wait', 1),
#  ('FYIWe', 1),
#  ('store', 1),
#  ('Stash,', 1),
#  ('how-to’s', 1),
#  ('Confluence', 1),
#  ('complete', 1),
#  ('analyses', 1),
#  ('Knowledge', 1),
#  ('RepoWe', 1),
#  ('we’re', 1),
#  ('lottery', 1),
#  ('tomorrow', 1),
#  ('somebody', 1),
#  ('overWe', 1),
#  ('track', 1),
#  ('avoid', 1),
#  ('duplication', 1),
#  ('teamsWe', 1),
#  ('collaborate', 1),
#  ('HQ', 1),
#  ('share', 1),
#  ('exchange', 1),
#  ('findingsIf', 1),
#  ('interested', 1),
#  ('role,', 1),
#  ('you’ll', 1),
#  ('skills', 1),
#  ('experiences:3', 1),
#  ('5', 1),
#  ('years’', 1),
#  ('focus', 1),
#  ('NLPMaster’s', 1),
#  ('Computer', 1),
#  ('Science,', 1),
#  ('Statistics,', 1),
#  ('Operations', 1),
#  ('related', 1),
#  ('(we', 1),
#  ('consider', 1),
#  ('Bachelor’s', 1),
#  ('degree', 1),
#  ('significant', 1),
#  ('relevant', 1),
#  ('experience)Expert', 1),
#  ('least', 1),
#  ('Statistical', 1),
#  ('Programming', 1),
#  ('Language', 1),
#  ('PythonExperience', 1),
#  ('relational', 1),
#  ('distributed', 1),
#  ('databasesExperience', 1),
#  ('following', 1),
#  ('plus:', 1),
#  ('PySpark,', 1),
#  ('Scala,', 1),
#  ('Zepplin', 1),
#  ('Notebooks,', 1),
#  ('MLlib', 1),
#  ('well', 1),
#  ('application', 1),
#  ('development', 1),
#  ('using', 1),
#  ('AWS,', 1),
#  ('Virtual', 1),
#  ('Machines,', 1),
#  ('DockerGaming', 1),
#  ('industry', 1),
#  ('customer', 1),
#  ('support', 1),
#  ('plusWhat’s', 1),
#  ('you?', 1),
#  ('Glad', 1),
#  ('asked!We', 1),
#  ('brag', 1),
#  ('comprehensive', 1),
#  ('health', 1),
#  ('benefit', 1),
#  ('packages,', 1),
#  ('tuition', 1),
#  ('reimbursement,', 1),
#  ('401k', 1),
#  ('and,', 1),
#  ('course,', 1),
#  ('many', 1),
#  ('perks!', 1),
#  ('since', 1),
#  ('realize', 1),
#  ('takes', 1),
#  ('competitive', 1),
#  ('compensation', 1),
#  ('culture', 1),
#  ('thrives', 1),
#  ('individuality.', 1),
#  ('EA,', 1),
#  ('“work', 1),
#  ('hard/play', 1),
#  ('hard”', 1),
#  ('credo', 1),
#  ('every', 1),
#  ('day.', 1),
#  ('More', 1),
#  ('location:https://www.ea.com/careers/careers-overview/austinElectronic', 1),
#  ('Arts', 1),
#  ('Inc.', 1),
#  ('leading', 1),
#  ('global', 1),
#  ('interactive', 1),
#  ('entertainment', 1),
#  ('software', 1),
#  ('company.', 1),
#  ('delivers', 1),
#  ('content', 1),
#  ('online', 1),
#  ('Internet-connected', 1),
#  ('consoles,', 1),
#  ('personal', 1),
#  ('computers,', 1),
#  ('mobile', 1),
#  ('tablets.', 1)]
